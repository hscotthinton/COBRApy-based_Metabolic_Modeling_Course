# %% [markdown]
# # COBRApy Gene Overview
#
# This tutorial will focus on how to access the gene information stored in a COBRApy model.
#
# ## Gene Objects

# %% [markdown]
# A Gene in a COBRA model includes the folling attributes
#
# 1. **id (string)** – The identifier to associate the gene with
# 2. **name (string)** – A longer human readable name for the gene
# 3. **functional (bool)** – Indicates whether the gene is functional. If it is not functional then it cannot be used in an enzyme complex nor can its products be used.
#
# Examples of retrieving information available with a reaction object through it's index number is shown below.

# %%
import cobra.test
import pandas as pd
model = cobra.test.create_test_model("textbook")

model.genes[0] # Get the reaction object from it's index number
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-10-10
# <Gene b1241 at 0x2170a687430>

# %% [markdown]
# Finding the gene information based on the gene identifier

# %%
model.genes.b1241
# Out:
# <Gene b1241 at 0x2170a687430>

# %% [markdown]
# Listing the gene name

# %%
model.genes.b1241.name
# Out:
# 'adhE'

# %% [markdown]
# Determining if the gene is functional

# %%
model.genes.b1241.functional
# Out:
# True

# %% [markdown]
# Identifying the reactions associated with a gene

# %%
model.genes.b1241.reactions
# Out:
# frozenset({<Reaction ACALD at 0x2170a6a3b50>,
#            <Reaction ALCD2x at 0x2170a6b5fd0>})

# %% [markdown]
# Another approach to get the same information

# %%
b1241 = model.genes.b1241
b1241
# Out:
# <Gene b1241 at 0x2170a687430>

# %%
b1241.reactions
# Out:
# frozenset({<Reaction ACALD at 0x2170a6a3b50>,
#            <Reaction ALCD2x at 0x2170a6b5fd0>})

# %% [markdown]
# # Gene Table
#
# Below is the code to create a table of all the genes in a model and their associated attributes

# %%
gene_names = [m.name for m in model.genes]
gene_ids = [m.id for m in model.genes]
gene_functional = [m.functional for m in model.genes]
gene_reactions = [m.reactions for m in model.genes]
geneList = {'Gene ID': gene_ids,
            'Gene Name': gene_names,
            'Gene Functional': gene_functional,
            'Gene Reactions': gene_reactions
            }

df = pd.DataFrame(geneList, columns= ['Gene ID','Gene Name', 'Gene Functional', 'Gene Reactions'])
pd.set_option('display.max_rows', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)
df
# Out:
#     Gene ID Gene Name  Gene Functional                                                                                                                                       Gene Reactions
# 0     b1241      adhE             True                                       (ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c, ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c)
# 1     b0351      mhpF             True                                                                                          (ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c)
# 2     s0001   G_s0001             True                               (CO2t: co2_e <=> co2_c, ACALDt: acald_e <=> acald_c, O2t: o2_e <=> o2_c, H2Ot: h2o_e <=> h2o_c, NH4t: nh4_e <=> nh4_c)
# 3     b3115      tdcD             True                                                                                                              (ACKr: ac_c + atp_c <=> actp_c + adp_c)
# 4     b1849      purT             True                                                                                                              (ACKr: ac_c + atp_c <=> actp_c + adp_c)
# 5     b2296      ackA             True                                                                                                              (ACKr: ac_c + atp_c <=> actp_c + adp_c)
# 6     b1276      acnA             True                                                                            (ACONTa: cit_c <=> acon_C_c + h2o_c, ACONTb: acon_C_c + h2o_c <=> icit_c)
# 7     b0118      acnB             True                                                                            (ACONTa: cit_c <=> acon_C_c + h2o_c, ACONTb: acon_C_c + h2o_c <=> icit_c)
# 8     b0474       adk             True                                                                                                                  (ADK1: amp_c + atp_c <=> 2.0 adp_c)
# 9     b0116       lpd             True                                (PDH: coa_c + nad_c + pyr_c --> accoa_c + co2_c + nadh_c, AKGDH: akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c)
# 10    b0726      sucA             True                                                                                         (AKGDH: akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c)
# 11    b0727      sucB             True                                                                                         (AKGDH: akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c)
# 12    b2587      kgtP             True                                                                                                                (AKGt2r: akg_e + h_e <=> akg_c + h_c)
# 13    b0356      frmA             True                                                                                                  (ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c)
# 14    b1478      adhP             True                                                                                                  (ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c)
# 15    b3735      atpH             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 16    b3733      atpG             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 17    b3734      atpA             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 18    b3732      atpD             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 19    b3736      atpF             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 20    b3738      atpB             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 21    b3731      atpC             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 22    b3737      atpE             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 23    b3739      atpI             True                                                                                         (ATPS4r: adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c)
# 24    b0720      gltA             True                                                                                                (CS: accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c)
# 25    b0733      cydA             True                                                                                      (CYTBD: 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c)
# 26    b0979      cbdB             True                                                                                      (CYTBD: 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c)
# 27    b0978      cbdA             True                                                                                      (CYTBD: 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c)
# 28    b0734      cydB             True                                                                                      (CYTBD: 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c)
# 29    b2975      glcA             True                                                                                                         (D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c)
# 30    b3603      lldP             True                                                                                                         (D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c)
# 31    b2779       eno             True                                                                                                                       (ENO: 2pg_c <=> h2o_c + pep_c)
# 32    b1773      ydjI             True                                                                                                                      (FBA: fdp_c <=> dhap_c + g3p_c)
# 33    b2925      fbaA             True                                                                                                                      (FBA: fdp_c <=> dhap_c + g3p_c)
# 34    b2097      fbaB             True                                                                                                                      (FBA: fdp_c <=> dhap_c + g3p_c)
# 35    b4232       fbp             True                                                                                                                (FBP: fdp_c + h2o_c --> f6p_c + pi_c)
# 36    b3925      glpX             True                                                                                                                (FBP: fdp_c + h2o_c --> f6p_c + pi_c)
# 37    b0904      focA             True                                                                                         (FORti: for_c --> for_e, FORt2: for_e + h_e --> for_c + h_c)
# 38    b2492      focB             True                                                                                         (FORti: for_c --> for_e, FORt2: for_e + h_e --> for_c + h_c)
# 39    b4154      frdA             True                                                                                                             (FRD7: fum_c + q8h2_c --> q8_c + succ_c)
# 40    b4152      frdC             True                                                                                                             (FRD7: fum_c + q8h2_c --> q8_c + succ_c)
# 41    b4153      frdB             True                                                                                                             (FRD7: fum_c + q8h2_c --> q8_c + succ_c)
# 42    b4151      frdD             True                                                                                                             (FRD7: fum_c + q8h2_c --> q8_c + succ_c)
# 43    b1819      manZ             True                                                               (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c, FRUpts2: fru_e + pep_c --> f6p_c + pyr_c)
# 44    b1817      manX             True                                                               (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c, FRUpts2: fru_e + pep_c --> f6p_c + pyr_c)
# 45    b2415      ptsH             True                                                               (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c, FRUpts2: fru_e + pep_c --> f6p_c + pyr_c)
# 46    b1818      manY             True                                                               (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c, FRUpts2: fru_e + pep_c --> f6p_c + pyr_c)
# 47    b2416      ptsI             True                                                               (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c, FRUpts2: fru_e + pep_c --> f6p_c + pyr_c)
# 48    b1611      fumC             True                                                                                                                    (FUM: fum_c + h2o_c <=> mal__L_c)
# 49    b4122      fumB             True                                                                                                                    (FUM: fum_c + h2o_c <=> mal__L_c)
# 50    b1612      fumA             True                                                                                                                    (FUM: fum_c + h2o_c <=> mal__L_c)
# 51    b3528      dctA             True  (SUCCt2_2: 2.0 h_e + succ_e --> 2.0 h_c + succ_c, FUMt2_2: fum_e + 2.0 h_e --> fum_c + 2.0 h_c, MALt2_2: 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c)
# 52    b1852       zwf             True                                                                                                 (G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c)
# 53    b1779      gapA             True                                                                                              (GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c)
# 54    b1621      malX             True                                                                                                         (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c)
# 55    b1101      ptsG             True                                                                                                         (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c)
# 56    b2417       crr             True                                                                                                         (GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c)
# 57    b3870      glnA             True                                                                                   (GLNS: atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c)
# 58    b1297      puuA             True                                                                                   (GLNS: atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c)
# 59    b0809      glnQ             True                                                                                 (GLNabc: atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c)
# 60    b0810      glnP             True                                                                                 (GLNabc: atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c)
# 61    b0811      glnH             True                                                                                 (GLNabc: atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c)
# 62    b1761      gdhA             True                                                                                 (GLUDy: glu__L_c + h2o_c + nadp_c <=> akg_c + h_c + nadph_c + nh4_c)
# 63    b1524      glsB             True                                                                                                        (GLUN: gln__L_c + h2o_c --> glu__L_c + nh4_c)
# 64    b1812      pabB             True                                                                                                        (GLUN: gln__L_c + h2o_c --> glu__L_c + nh4_c)
# 65    b0485      glsA             True                                                                                                        (GLUN: gln__L_c + h2o_c --> glu__L_c + nh4_c)
# 66    b3213      gltD             True                                                                                  (GLUSy: akg_c + gln__L_c + h_c + nadph_c --> 2.0 glu__L_c + nadp_c)
# 67    b3212      gltB             True                                                                                  (GLUSy: akg_c + gln__L_c + h_c + nadph_c --> 2.0 glu__L_c + nadp_c)
# 68    b4077      gltP             True                                                                                                          (GLUt2r: glu__L_e + h_e <=> glu__L_c + h_c)
# 69    b2029       gnd             True                                                                                               (GND: 6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c)
# 70    b0875      aqpZ             True                                                                                                                              (H2Ot: h2o_e <=> h2o_c)
# 71    b1136       icd             True                                                                                                (ICDHyr: icit_c + nadp_c <=> akg_c + co2_c + nadph_c)
# 72    b4015      aceA             True                                                                                                                     (ICL: icit_c --> glx_c + succ_c)
# 73    b2133       dld             True                                                                                                   (LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c)
# 74    b1380      ldhA             True                                                                                                   (LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c)
# 75    b4014      aceB             True                                                                                           (MALS: accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c)
# 76    b2976      glcB             True                                                                                           (MALS: accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c)
# 77    b3236       mdh             True                                                                                                     (MDH: mal__L_c + nad_c <=> h_c + nadh_c + oaa_c)
# 78    b1479      maeA             True                                                                                                   (ME1: mal__L_c + nad_c --> co2_c + nadh_c + pyr_c)
# 79    b2463      maeB             True                                                                                                 (ME2: mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c)
# 80    b2286      nuoC             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 81    b2279      nuoK             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 82    b2276      nuoN             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 83    b2280      nuoJ             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 84    b2288      nuoA             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 85    b2284      nuoF             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 86    b2287      nuoB             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 87    b2281      nuoI             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 88    b2277      nuoM             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 89    b2285      nuoE             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 90    b2282      nuoH             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 91    b2278      nuoL             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 92    b2283      nuoG             True                                                                                       (NADH16: 4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c)
# 93    b3962      sthA             True                                                                                                       (NADTRHD: nad_c + nadph_c --> nadh_c + nadp_c)
# 94    b1602      pntB             True                                        (THD2: 2.0 h_e + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c, NADTRHD: nad_c + nadph_c --> nadh_c + nadp_c)
# 95    b1603      pntA             True                                        (THD2: 2.0 h_e + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c, NADTRHD: nad_c + nadph_c --> nadh_c + nadp_c)
# 96    b0451      amtB             True                                                                                                                              (NH4t: nh4_e <=> nh4_c)
# 97    b0114      aceE             True                                                                                            (PDH: coa_c + nad_c + pyr_c --> accoa_c + co2_c + nadh_c)
# 98    b0115      aceF             True                                                                                            (PDH: coa_c + nad_c + pyr_c --> accoa_c + co2_c + nadh_c)
# 99    b3916      pfkA             True                                                                                                         (PFK: atp_c + f6p_c --> adp_c + fdp_c + h_c)
# 100   b1723      pfkB             True                                                                                                         (PFK: atp_c + f6p_c --> adp_c + fdp_c + h_c)
# 101   b0902      pflA             True                                                                                                             (PFL: coa_c + pyr_c --> accoa_c + for_c)
# 102   b0903      pflB             True                                                                                                             (PFL: coa_c + pyr_c --> accoa_c + for_c)
# 103   b2579      grcA             True                                                                                                             (PFL: coa_c + pyr_c --> accoa_c + for_c)
# 104   b3114      tdcE             True                                                                                                             (PFL: coa_c + pyr_c --> accoa_c + for_c)
# 105   b3952      pflC             True                                                                                                             (PFL: coa_c + pyr_c --> accoa_c + for_c)
# 106   b3951      pflD             True                                                                                                             (PFL: coa_c + pyr_c --> accoa_c + for_c)
# 107   b4025       pgi             True                                                                                                                               (PGI: g6p_c <=> f6p_c)
# 108   b2926       pgk             True                                                                                                             (PGK: 3pg_c + atp_c <=> 13dpg_c + adp_c)
# 109   b0767       pgl             True                                                                                                               (PGL: 6pgl_c + h2o_c --> 6pgc_c + h_c)
# 110   b0755      gpmA             True                                                                                                                               (PGM: 2pg_c <=> 3pg_c)
# 111   b3612      gpmM             True                                                                                                                               (PGM: 2pg_c <=> 3pg_c)
# 112   b4395      ytjC             True                                                                                                                               (PGM: 2pg_c <=> 3pg_c)
# 113   b3493      pitA             True                                                                                                                   (PIt2r: h_e + pi_e <=> h_c + pi_c)
# 114   b2987      pitB             True                                                                                                                   (PIt2r: h_e + pi_e <=> h_c + pi_c)
# 115   b3956       ppc             True                                                                                                  (PPC: co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c)
# 116   b3403       pck             True                                                                                                      (PPCK: atp_c + oaa_c --> adp_c + co2_c + pep_c)
# 117   b1702      ppsA             True                                                                                      (PPS: atp_c + h2o_c + pyr_c --> amp_c + 2.0 h_c + pep_c + pi_c)
# 118   b2297       pta             True                                                                                                            (PTAr: accoa_c + pi_c <=> actp_c + coa_c)
# 119   b2458      eutD             True                                                                                                            (PTAr: accoa_c + pi_c <=> actp_c + coa_c)
# 120   b1676      pykF             True                                                                                                         (PYK: adp_c + h_c + pep_c --> atp_c + pyr_c)
# 121   b1854      pykA             True                                                                                                         (PYK: adp_c + h_c + pep_c --> atp_c + pyr_c)
# 122   b4301      sgcE             True                                                                                                                       (RPE: ru5p__D_c <=> xu5p__D_c)
# 123   b3386       rpe             True                                                                                                                       (RPE: ru5p__D_c <=> xu5p__D_c)
# 124   b2914      rpiA             True                                                                                                                           (RPI: r5p_c <=> ru5p__D_c)
# 125   b4090      rpiB             True                                                                                                                           (RPI: r5p_c <=> ru5p__D_c)
# 126   b0722      sdhD             True                                                                                                            (SUCDi: q8_c + succ_c --> fum_c + q8h2_c)
# 127   b0724      sdhB             True                                                                                                            (SUCDi: q8_c + succ_c --> fum_c + q8h2_c)
# 128   b0721      sdhC             True                                                                                                            (SUCDi: q8_c + succ_c --> fum_c + q8h2_c)
# 129   b0723      sdhA             True                                                                                                            (SUCDi: q8_c + succ_c --> fum_c + q8h2_c)
# 130   b0728      sucC             True                                                                                         (SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c)
# 131   b0729      sucD             True                                                                                         (SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c)
# 132   b2464      talA             True                                                                                                              (TALA: g3p_c + s7p_c <=> e4p_c + f6p_c)
# 133   b0008      talB             True                                                                                                              (TALA: g3p_c + s7p_c <=> e4p_c + f6p_c)
# 134   b2935      tktA             True                                                               (TKT1: r5p_c + xu5p__D_c <=> g3p_c + s7p_c, TKT2: e4p_c + xu5p__D_c <=> f6p_c + g3p_c)
# 135   b2465      tktB             True                                                               (TKT1: r5p_c + xu5p__D_c <=> g3p_c + s7p_c, TKT2: e4p_c + xu5p__D_c <=> f6p_c + g3p_c)
# 136   b3919      tpiA             True                                                                                                                              (TPI: dhap_c <=> g3p_c)
