# %% [markdown]
# # COBRA Models Overview
#
# This tutorial will reveiw the basic atributes of a COBRApy model.

# %% [markdown]
# ## Loading COBRA models
#
# There are several built-in models associated with the COBRApy module. They include
#
# 1. textbook_model ("textbook"): A simplified model of the metabolic core of *E.coli*[1]
# 2. ecoli_model ("ecoli"): The iJO1366 model of *E.coli* [2]
# 3. salmonella_model ("salmonella"): The consensus model of Salmonella [3]

# %% [markdown]
# The COBRApy code to load the "textbook model" is

# %%
import cobra.test
textbook_model = cobra.test.create_test_model("textbook")
textbook_model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-10-10
# <Model e_coli_core at 0x20766f99ac0>

# %% [markdown]
# The python code to load the "iJO1366 model" is

# %%
import cobra.test
iJO1366_model = cobra.test.create_test_model("ecoli")
iJO1366_model
# Out:
# <Model iJO1366 at 0x20743cee640>

# %% [markdown]
# The python code to load the consensus model of Salmonella is

# %%
import cobra.test
salmonella_model = cobra.test.create_test_model("salmonella")
salmonella_model
# Out:
# <Model Salmonella_consensus_build_1 at 0x2076e5de910>

# %% [markdown]
# To load an "SBML" model from the current directory, use can use the following Python code

# %%
model = cobra.io.read_sbml_model('e_coli_core.xml')
model
# Out:
# <Model e_coli_core at 0x2076fda2fa0>

# %% [markdown]
# To load a matlab ("mat") model from the current directory, use can use the following Python code

# %%
model = cobra.io.load_matlab_model('e_coli_core.mat') # the file cannot include that .mat extension
model
# Out:
# <Model e_coli_core at 0x207683aa250>

# %% [markdown]
# To load an "JSON" model from the current directory, use can use the following Python code. JSON files are preferred in COBRApy!

# %%
model = cobra.io.load_json_model('e_coli_core.json')
model
# Out:
# <Model e_coli_core at 0x20770e26cd0>

# %% [markdown]
# Other examples of reading and writing COBRA models can be found at https://cobrapy.readthedocs.io/en/latest/io.html.

# %% [markdown]
# The Cameo tools can also be used to load models from the current directory. The Cameo tools are a set of python tools that have been created to enhance, and in some cases simpliify, the COBRApy toolset. (https://cameo.bio/index.html).
#
# To load a model

# %%
from cameo import load_model
model = load_model('e_coli_core.xml')
model
# Out:
# <Model e_coli_core at 0x20772731be0>

# %% [markdown]
# ## Loading Models from External Databases
# Models can also be downloaded from the BIGG directory. There are two options; COBRApy and Cameo.
#
# The COBRApy option allows JSON models to be downloaded from the BIGG database.

# %%
from cobrapy_bigg_client import client
model_iJN678 = client.download_model('iJN678', save=False) # Synechocystis sp. PCC 6803
model_iJN678
# Out:
# <Model iJN678 at 0x207732cfbb0>

# %% [markdown]
# You can also save a BIGG model to a file in the current directory

# %%
import os
client.download_model('iAB_RBC_283', save=True) # saving the model to the current directory
os.listdir(".") # look at the contents of the current directory
# Out:
# ['.ipynb_checkpoints',
#  'Escher_Introduction.ipynb',
#  'e_coli_core.json',
#  'e_coli_core.mat',
#  'e_coli_core.xml',
#  'Gene_Overview.ipynb',
#  'iAB_RBC_283.json',
#  'iAB_RBC_283.metabolism.json',
#  'Metabolite_Overview.ipynb',
#  'Model_Overview.ipynb',
#  'Reaction_Overview.ipynb',
#  'Untitled.ipynb']

# %% [markdown]
# Notice that the file 'iAB_RBC_283.json' has been created in this current directory.
#
# Downloading a list of BIGG models (https://cameo.bio/02-import-models.html) that are available to download

# %%
from cameo import models
import pandas as pd
pd.set_option('display.max_rows', 1000) # Allow up to 1000 rows in output
models.index_models_bigg() # Saccharomyces cerevisiae S288C
# Out:
#                    bigg_id  gene_count  reaction_count  \
# 0              e_coli_core         137              95
# 1              iAB_RBC_283         346             469
# 2                  iAF1260        1261            2382
# 3                 iAF1260b        1261            2388
# 4                   iAF692         692             690
# 5                   iAF987         987            1285
# 6                iAM_Pb448         448            1067
# 7                iAM_Pc455         455            1074
# 8                iAM_Pf480         480            1083
# 9                iAM_Pk459         459            1079
# 10               iAM_Pv461         461            1078
# 11            iAPECO1_1312        1313            2735
# 12             iAT_PLT_636         636            1008
# 13               iB21_1397        1337            2741
# 14               iBWG_1329        1329            2741
# 15                 ic_1306        1307            2726
# 16                  iCHOv1        1766            6663
# 17             iCHOv1_DG44        1184            3942
# 18                  iCN718         709            1015
# 19                  iCN900         900            1229
# 20            iE2348C_1286        1287            2703
# 21             iEC042_1314        1314            2714
# 22               iEC1344_C        1344            2726
# 23          iEC1349_Crooks        1349            2756
# 24         iEC1356_Bl21DE3        1356            2740
# 25               iEC1364_W        1364            2764
# 26            iEC1368_DH5a        1368            2779
# 27           iEC1372_W3110        1372            2758
# 28           iEC55989_1330        1330            2756
# 29            iECABU_c1320        1320            2731
# 30               iECB_1328        1329            2748
# 31              iECBD_1354        1354            2748
# 32               iECD_1391        1333            2741
# 33           iECDH10B_1368        1327            2742
# 34             iEcDH1_1363        1363            2750
# 35       iECDH1ME8569_1439        1439            2755
# 36          iEcE24377_1341        1341            2763
# 37             iECED1_1282        1279            2706
# 38          iECH74115_1262        1262            2694
# 39              iEcHS_1320        1321            2753
# 40            iECIAI1_1343        1343            2765
# 41           iECIAI39_1322        1321            2721
# 42           iECNA114_1301        1301            2718
# 43            iECO103_1326        1327            2758
# 44            iECO111_1330        1328            2760
# 45             iECO26_1355        1355            2780
# 46             iECOK1_1307        1304            2729
# 47             iEcolC_1368        1368            2768
# 48               iECP_1309        1309            2739
# 49               iECs_1301        1301            2720
# 50             iECS88_1305        1305            2729
# 51              iECSE_1348        1348            2768
# 52              iECSF_1327        1327            2742
# 53           iEcSMS35_1347        1347            2746
# 54              iECSP_1301        1299            2712
# 55             iECUMN_1333        1332            2740
# 56               iECW_1372        1372            2782
# 57                 iEK1008        1008            1226
# 58             iEKO11_1354        1354            2778
# 59              iETEC_1333        1333            2756
# 60             iG2583_1286        1283            2704
# 61                  iHN637         637             785
# 62                  iIS312         312             519
# 63       iIS312_Amastigote         312             519
# 64     iIS312_Epimastigote         312             519
# 65   iIS312_Trypomastigote         312             520
# 66                  iIT341         339             554
# 67                  iJB785         785             849
# 68                 iJN1463        1462            2927
# 69                  iJN678         622             863
# 70                  iJN746         746            1054
# 71                 iJO1366        1367            2583
# 72                  iJR904         904            1075
# 73           iLB1027_lipid        1027            4456
# 74              iLF82_1304        1302            2726
# 75                  iLJ478         482             652
# 76                 iML1515        1516            2712
# 77                 iMM1415        1375            3726
# 78                  iMM904         905            1577
# 79                  iND750         750            1266
# 80                  iNF517         516             754
# 81                  iNJ661         661            1025
# 82            iNRG857_1313        1311            2735
# 83                  iPC815         815            1961
# 84                 iRC1080        1086            2191
# 85                 iS_1188        1188            2619
# 86                  iSB619         619             743
# 87           iSbBS512_1146        1147            2591
# 88               iSBO_1134        1134            2591
# 89               iSDY_1059        1059            2539
# 90                iSF_1195        1195            2630
# 91               iSFV_1184        1184            2621
# 92              iSFxv_1172        1169            2638
# 93              iSSON_1240        1240            2693
# 94               iSynCJ816         816            1044
# 95            iUMN146_1321        1319            2735
# 96            iUMNK88_1353        1353            2777
# 97             iUTI89_1310        1310            2725
# 98               iWFL_1372        1372            2782
# 99               iY75_1357        1358            2759
# 100                iYL1228        1229            2262
# 101                 iYO844         844            1250
# 102                iYS1720        1707            3357
# 103                 iYS854         866            1455
# 104                iZ_1308        1308            2721
# 105                 RECON1        1905            3741
# 106                Recon3D        2248           10600
# 107               STM_v1_0        1271            2545
#
#                                               organism  metabolite_count
# 0            Escherichia coli str. K-12 substr. MG1655                72
# 1                                         Homo sapiens               342
# 2            Escherichia coli str. K-12 substr. MG1655              1668
# 3            Escherichia coli str. K-12 substr. MG1655              1668
# 4                   Methanosarcina barkeri str. Fusaro               628
# 5                      Geobacter metallireducens GS-15              1109
# 6                                   Plasmodium berghei               903
# 7                        Plasmodium cynomolgi strain B               907
# 8                            Plasmodium falciparum 3D7               909
# 9                         Plasmodium knowlesi strain H               909
# 10                              Plasmodium vivax Sal-1               909
# 11                            Escherichia coli APEC O1              1942
# 12                                        Homo sapiens               738
# 13                          Escherichia coli BL21(DE3)              1943
# 14                             Escherichia coli BW2952              1949
# 15                             Escherichia coli CFT073              1936
# 16                                  Cricetulus griseus              4456
# 17                                  Cricetulus griseus              2751
# 18                         Acinetobacter baumannii AYE               888
# 19                        Clostridioides difficile 630               885
# 20              Escherichia coli O127:H6 str. E2348/69              1919
# 21                                Escherichia coli 042              1926
# 22                                  Escherichia coli C              1934
# 23                          Escherichia coli ATCC 8739              1946
# 24                          Escherichia coli BL21(DE3)              1918
# 25                                  Escherichia coli W              1927
# 26                         Escherichia coli DH5[alpha]              1951
# 27            Escherichia coli str. K-12 substr. W3110              1918
# 28                              Escherichia coli 55989              1953
# 29                          Escherichia coli ABU 83972              1942
# 30                      Escherichia coli B str. REL606              1951
# 31           Escherichia coli 'BL21-Gold(DE3)pLysS AG'              1952
# 32                          Escherichia coli BL21(DE3)              1943
# 33            Escherichia coli str. K-12 substr. DH10B              1947
# 34                                Escherichia coli DH1              1949
# 35                                Escherichia coli DH1              1950
# 36              Escherichia coli O139:H28 str. E24377A              1972
# 37                               Escherichia coli ED1a              1929
# 38                Escherichia coli O157:H7 str. EC4115              1918
# 39                                 Escherichia coli HS              1963
# 40                               Escherichia coli IAI1              1968
# 41                              Escherichia coli IAI39              1953
# 42                              Escherichia coli NA114              1927
# 43                 Escherichia coli O103:H2 str. 12009              1958
# 44                 Escherichia coli O111:H- str. 11128              1959
# 45                 Escherichia coli O26:H11 str. 11368              1965
# 46                            Escherichia coli IHE3034              1941
# 47                          Escherichia coli ATCC 8739              1969
# 48                                Escherichia coli 536              1941
# 49                 Escherichia coli O157:H7 str. Sakai              1923
# 50                                Escherichia coli S88              1942
# 51                               Escherichia coli SE11              1957
# 52                               Escherichia coli SE15              1951
# 53                            Escherichia coli SMS-3-5              1947
# 54               Escherichia coli O157:H7 str. TW14359              1920
# 55                             Escherichia coli UMN026              1935
# 56                                  Escherichia coli W              1973
# 57                    Mycobacterium tuberculosis H37Rv               998
# 58                             Escherichia coli KO11FL              1972
# 59                        Escherichia coli ETEC H10407              1962
# 60                 Escherichia coli O55:H7 str. CB9615              1919
# 61                   Clostridium ljungdahlii DSM 13528               698
# 62                             Trypanosoma cruzi Dm28c               606
# 63                             Trypanosoma cruzi Dm28c               606
# 64                             Trypanosoma cruzi Dm28c               606
# 65                             Trypanosoma cruzi Dm28c               606
# 66                           Helicobacter pylori 26695               485
# 67                    Synechococcus elongatus PCC 7942               768
# 68                           Pseudomonas putida KT2440              2153
# 69                          Synechocystis sp. PCC 6803               795
# 70                           Pseudomonas putida KT2440               907
# 71           Escherichia coli str. K-12 substr. MG1655              1805
# 72           Escherichia coli str. K-12 substr. MG1655               761
# 73               Phaeodactylum tricornutum CCAP 1055/1              2172
# 74                               Escherichia coli LF82              1938
# 75                            Thermotoga maritima MSB8               570
# 76           Escherichia coli str. K-12 substr. MG1655              1877
# 77                                        Mus musculus              2775
# 78                      Saccharomyces cerevisiae S288C              1226
# 79                      Saccharomyces cerevisiae S288C              1059
# 80           Lactococcus lactis subsp. cremoris MG1363               650
# 81                    Mycobacterium tuberculosis H37Rv               825
# 82               Escherichia coli O83:H1 str. NRG 857C              1943
# 83                                Yersinia pestis CO92              1552
# 84                           Chlamydomonas reinhardtii              1706
# 85                     Shigella flexneri 2a str. 2457T              1914
# 86            Staphylococcus aureus subsp. aureus N315               655
# 87                         Shigella boydii CDC 3083-94              1910
# 88                               Shigella boydii Sb227              1908
# 89                          Shigella dysenteriae Sd197              1888
# 90                       Shigella flexneri 2a str. 301              1917
# 91                       Shigella flexneri 5 str. 8401              1917
# 92                           Shigella flexneri 2002017              1918
# 93                               Shigella sonnei Ss046              1936
# 94                          Synechocystis sp. PCC 6803               928
# 95                              Escherichia coli UM146              1942
# 96                             Escherichia coli UMNK88              1969
# 97                              Escherichia coli UTI89              1940
# 98                                  Escherichia coli W              1973
# 99            Escherichia coli str. K-12 substr. W3110              1953
# 100  Klebsiella pneumoniae subsp. pneumoniae MGH 78578              1658
# 101         Bacillus subtilis subsp. subtilis str. 168               990
# 102                            Salmonella pan-reactome              2436
# 103  Staphylococcus aureus subsp. aureus USA300_TCH...              1335
# 104               Escherichia coli O157:H7 str. EDL933              1923
# 105                                       Homo sapiens              2766
# 106                                       Homo sapiens              5835
# 107  Salmonella enterica subsp. enterica serovar Ty...              1802

# %% [markdown]
# Downloading a specific model

# %%
model_iMM904 = models.bigg.iMM904
model_iMM904
# Out:
# <Model iMM904 at 0x2076823bfd0>

# %% [markdown]
# Models available in the minho database (https://cameo.bio/02-import-models.html) are

# %%
models.index_models_minho()
# Out:
#       id                    name                               doi  \
# 0      1                  iJR904           10.1186/gb-2003-4-9-r54
# 1      2                 iAF1260                10.1038/msb4100155
# 2      3                  iMM904            10.1186/1752-0509-3-37
# 3      4                  iJP815      10.1371/journal.pcbi.1000210
# 4      5                 iMO1056               10.1128/JB.01583-07
# 5      6                  iIN800            10.1186/1752-0509-2-71
# 6      7                  iFF708                 10.1101/gr.234503
# 7      8                 iCA1273            10.1186/1471-2164-12-9
# 8      9                 iJO1366               10.1038/msb.2011.65
# 9     10               yeast 4.0           10.1186/1752-0509-4-145
# 10    11                  iJN746            10.1186/1752-0509-2-79
# 11    12              AbyMBEL891                  10.1039/B916446D
# 12    13                  iJP962      10.1371/journal.pcbi.1001116
# 13    14                 iYL1228               10.1128/JB.01218-10
# 14    15                  iSR432            10.1186/1752-0509-4-31
# 15    16                 iNJ661m           10.1186/1752-0509-4-160
# 16    17                  iCM925           10.1186/1752-0509-5-130
# 17    18                iBsu1103          10.1186/gb-2009-10-6-r69
# 18    19                  iAI549      10.1371/journal.pcbi.1000887
# 19    20                  iAF692                10.1038/msb4100046
# 20    21                  AraGEM        10.1186/1471-2164-12-S4-S5
# 21    22        Ecoli core Model     doi:10.1128/ecosalplus.10.2.1
# 22    23                  iIT341  10.1128/JB.187.16.5818-5830.2005
# 23    24              iMH805/775                   10.1038/nbt1492
# 24    25                  iND750                10.1101/gr.2250904
# 25    26                 iRC1080               10.1038/msb.2011.52
# 26    27                  iSB619             10.1186/1471-2180-5-8
# 27    28                  iTH366               10.1038/msb.2010.60
# 28    29                  iTZ479           10.1126/science.1174671
# 29    30                  recon2                  10.1038/nbt.2488
# 30    31                  iGB555          10.1186/gb-2007-8-7-r136
# 31    32                  iVM679               10.1128/JB.01123-08
# 32    34             PpuMBEL1071            10.1002/biot.201000124
# 33    35                  iOR363      10.1371/journal.pcbi.0030192
# 34    36             RehMBEL1391           10.1186/1752-0509-5-101
# 35    37              iAbaylyiV4            10.1186/1752-0509-2-85
# 36    38                  iYO844            10.1074/jbc.M703759200
# 37    39                  iGT196            10.1186/1752-0509-3-24
# 38    40                  iOA584            10.1186/1752-0509-5-12
# 39    41                  iRS474                 10.1002/bit.22010
# 40    42                  iJL432         10.1007/s00253-008-1654-4
# 41    43                  iKK411                 10.1002/bit.22067
# 42    44                  iYS432            10.1186/1475-2859-8-43
# 43    45                  iJE660           10.1073/pnas.97.10.5528
# 44    46                  iRS605           10.1186/1752-0509-4-118
# 45    47                  iJS747            10.1186/1752-0509-3-15
# 46    48                  iRM588   10.1128/AEM.72.2.1558-1568.2006
# 47    49                  iJE296          10.1074/jbc.274.25.17410
# 48    50                  iCS400            10.1006/jtbi.2000.1088
# 49    51                  iCS291  10.1128/JB.184.16.4582-4593.2002
# 50    52                  iWZ663     10.1016/j.jbiotec.2012.05.015
# 51    53                  iBT721            10.1074/jbc.M606263200
# 52    54                  iAP358            10.1186/1471-2180-5-39
# 53    55                  iSH335                   10.1038/nbt1010
# 54    56                  iTK425                 10.1002/bit.21433
# 55    57                  iNJ661            10.1186/1752-0509-1-26
# 56    58                 GSMN-TB           10.1186/gb-2007-8-5-r89
# 57    59                  iPS189      10.1371/journal.pcbi.1000285
# 58    60              VvuMBEL943              10.1038/msb.2010.115
# 59    61                 iAN818m                  10.1039/B818710J
# 60    62                  iPC815           10.1186/1752-0509-5-163
# 61    63                  iZM363                 10.1002/bit.22965
# 62    64             ZmobMBEL601            10.1186/1475-2859-9-94
# 63    65                STM_v1.0             10.1186/1752-0509-5-8
# 64    66                  iMA945           10.1074/jbc.M109.005868
# 65    67                 iRR1083            10.1186/1752-0509-3-38
# 66    68                  ICR744          10.1186/1471-2164-10-447
# 67    69                  iSO783      10.1371/journal.pcbi.1000822
# 68    70                  iMH551                 10.1002/bit.20663
# 69    71                  iDL546               10.1128/JB.01743-08
# 70    72                  iMP429              10.1128/AEM.00138-09
# 71    73                  iIB700                10.1101/gr.3364705
# 72    74                  iMA789          10.1186/1471-2164-11-202
# 73    75                  iPF633                 10.1002/jctb.2065
# 74    76                 iSyn669           10.1186/1752-0509-4-156
# 75    77                  iTO977            10.1186/1752-0509-7-36
# 76    78                  iJN678           10.1073/pnas.1117907109
# 77    79              yeast 6.06           10.1093/database/bat059
# 78    80              yeast 7.00             10.1089/ind.2013.0013
# 79    81                  iAM303                10.1038/nmeth.1348
# 80    82                  iMB745               10.1128/JB.06040-11
# 81    83                  iCG238        10.1186/1471-2180-12-S1-S5
# 82    84                  iCG230        10.1186/1471-2180-12-S1-S5
# 83    85                  iBB814           10.1186/1475-2859-11-27
# 84    86                  iTL885            10.1186/1754-6834-5-72
# 85    87                 iSB1139            10.1186/1752-0509-7-19
# 86    88                iRsp1095           10.1186/1752-0509-5-116
# 87    89                  iHD666           10.1186/1471-2164-9-163
# 88    90                  iMA871               10.1038/msb.2008.12
# 89    91                 iWV1314           10.1186/1471-2164-9-245
# 90    93                  iAC560               10.1038/msb.2008.15
# 91    94             PpaMBEL1254            10.1002/biot.201000078
# 92    95                  iVS941            10.1186/1752-0509-5-28
# 93    96                  iLC915            10.1186/1752-0509-6-24
# 94    97                  iPP668            10.1186/1475-2859-9-50
# 95    98                 iMM1415           10.1186/1752-0509-4-140
# 96    99                  iNV213            10.1002/cbdv.200900323
# 97   100                  iLL672                10.1101/gr.3992505
# 98   101                  iMG746            10.1002/biot.201200266
# 99   102             SpoMBEL1693            10.1186/1752-0509-6-49
# 100  103                 iCce806      10.1371/journal.pcbi.1002460
# 101  104                  iHZ565      10.1371/journal.pone.0031287
# 102  105                  iJW145                10.1038/msb.2013.6
# 103  107                 iKF1028            10.1186/1752-0509-5-83
# 104  108                  iRP911           10.1186/1752-0509-5-189
# 105  109                  iSS884            10.1186/1752-0509-6-24
# 106  110                 iAL1006      10.1371/journal.pcbi.1002980
# 107  111                  iVW583                 10.1002/bit.24436
# 108  112                 iMZ1055     10.1016/j.jbiotec.2013.01.019
# 109  113                  iOG654      10.1371/journal.pcbi.1000799
# 110  114              Nmb_iTM560        10.1186/gb-2011-12-12-r127
# 111  115                  iAK692            10.1186/1752-0509-6-71
# 112  116                  iSS352     10.1016/j.jbiotec.2013.01.023
# 113  118                  iOD907            10.1002/biot.201300242
# 114  119                 iCAC490            10.1186/1752-0509-6-42
# 115  120               iTZ479_v2    10.1016/j.ijhydene.2012.06.032
# 116  121                  iAH991                10.4161/gmic.22370
# 117  122                 SPNV1.0           10.1186/1475-2859-13-41
# 118  123                 iCyc792           10.1186/1752-0509-7-142
# 119  124                 iCyn731           10.1186/1752-0509-7-142
# 120  125                 iCyj826           10.1186/1752-0509-7-142
# 121  126                 iCyp752           10.1186/1752-0509-7-142
# 122  127                 iCyh755           10.1186/1752-0509-7-142
# 123  128                  iNF518         10.1007/s00253-013-5140-2
# 124  129                 iJL1454                10.1039/C3MB70090A
# 125  130                 iBif452            10.1186/1752-0509-8-41
# 126  131                 iFap484            10.1186/1752-0509-8-41
# 127  132                  iAM388          10.1186/1471-2164-12-535
# 128  133                  iTT548           10.1186/1475-2859-13-61
# 129  134             EctoGEM-1.0                 10.1111/tpj.12627
# 130  135                  iMF721           10.1111/1462-2920.12513
# 131  136  Arabidopsis core model             10.1104/pp.114.235358
# 132  137                  iHN637          10.1186/1475-2859-12-118
# 133  138                 iCac802         10.1186/s13068-014-0144-4
# 134  139             iMLTC806cdf         10.1186/s12918-014-0117-z
# 135  140                 iCY1106         10.1186/s12918-014-0137-8
# 136  141                  iMM518                10.1039/c3mb70421a
# 137  142                 iPC1209     10.1016/j.febslet.2014.12.010
# 138  143                  iNV706              10.1128/AEM.03279-14
# 139  144              KoxGSC1457           10.1186/1475-2859-12-20
# 140  145                  iJL846        10.1016/j.gene.2014.10.034
# 141  146               yeast 7.6             10.1089/ind.2013.0013
# 142  147                  iJK849                 10.1111/tpj.13081
# 143  148                  iNL895            10.1186/1752-0509-6-35
# 144  149                  iYali4             10.1038/npjsba.2016.5
# 145  150           iLB1027_lipid      10.1371/journal.pone.0155038
# 146  151                 iLB1027      10.1371/journal.pone.0155038
# 147  152                 iMT1174         10.1186/s12918-015-0190-y
# 148  153                  iBP722     doi:10.1186/s12918-018-0585-7
# 149  154                  iDS372          10.3389/fmicb.2019.01283
#
#                     author  year        formats  \
# 0                     Reed  2003         [sbml]
# 1                    Feist  2007         [sbml]
# 2                       Mo  2007         [sbml]
# 3                 Puchalka  2008         [sbml]
# 4                Oberhardt  2008        [excel]
# 5                  Nookaew  2008         [sbml]
# 6                  Förster  2003         [sbml]
# 7                   Archer  2011         [sbml]
# 8                     Orth  2011         [sbml]
# 9                   Dobson  2010             []
# 10                 Nogales  2008         [sbml]
# 11                     Kim  2010         [sbml]
# 12               Oberhardt  2011         [sbml]
# 13                    Liao  2011         [sbml]
# 14                 Roberts  2010         [sbml]
# 15                    Fang  2010         [sbml]
# 16                   Milne  2011         [sbml]
# 17                   Henry  2009         [sbml]
# 18                   Islam  2010         [sbml]
# 19                   Feist  2006         [sbml]
# 20   de Oliveira Dal'Molin  2010         [sbml]
# 21                    Orth  2010         [sbml]
# 22                  Thiele  2005         [sbml]
# 23                Herrgård  2008         [sbml]
# 24                  Duarte  2004         [sbml]
# 25                   Chang  2011         [sbml]
# 26                  Becker  2005         [sbml]
# 27                   Plata  2010         [sbml]
# 28                   Zhang  2009         [sbml]
# 29                  Thiele  2013         [sbml]
# 30                   Baart  2007        [excel]
# 31                Mazumdar  2009        [excel]
# 32                    Sohn  2010         [sbml]
# 33        Resendis-Antonio  2007        [excel]
# 34                    Park  2007             []
# 35                   Durot  2008         [sbml]
# 36                      Oh  2007         [sbml]
# 37                  Thomas  2009         [sbml]
# 38                    Ates  2011        [excel]
# 39                  Senger  2008        [excel]
# 40                     Lee  2008             []
# 41                Kjeldsen  2009        [excel]
# 42                Shinfuku  2009        [excel]
# 43                 Edwards  2000             []
# 44             Raghunathan  2010             []
# 45                     Sun  2009        [excel]
# 46               Mahadevan  2006        [excel]
# 47                 Edwards  1999             []
# 48               Schilling  2000             []
# 49               Schilling  2002        [excel]
# 50                     Zou  2012        [excel]
# 51                 Teusink  2012  [sbml, excel]
# 52                Oliveira  2005         [sbml]
# 53                    Hong  2004             []
# 54                     Kim  2007        [excel]
# 55                Jamshidi  2007        [excel]
# 56                   Beste  2007         [sbml]
# 57                 Suthers  2009         [sbml]
# 58                     Kim  2011         [sbml]
# 59        Navid and Almaas  2009        [excel]
# 60              Charusanti  2011         [sbml]
# 61              Widiastuti  2011        [excel]
# 62                     Lee  2010             []
# 63                  Thiele  2011         [sbml]
# 64                  AbuOun  2009         [sbml]
# 65             Raghunathan  2009         [sbml]
# 66                   Risso  2009        [excel]
# 67                 Pinchuk  2010         [sbml]
# 68               Heinemann  2005        [excel]
# 69                     Lee  2009        [excel]
# 70                 Pastink  2009             []
# 71                Borodina  2005         [sbml]
# 72                    Alam  2010         [sbml]
# 73                      Fu  2008             []
# 74                Montagud  2010        [excel]
# 75               Österlund  2013  [sbml, excel]
# 76          Nogales et al.  2011         [sbml]
# 77                 Heavner  2013         [sbml]
# 78                    Aung  2013         [sbml]
# 79             Manichaikul  2009         [sbml]
# 80                Benedict  2012         [sbml]
# 81       González-Domenech  2012         [sbml]
# 82       González-Domenech  2012         [sbml]
# 83          Balagurunathan  2012        [excel]
# 84                     Liu  2012        [excel]
# 85                  Borgos  2013        [excel]
# 86                    Imam  2011         [sbml]
# 87                   David  2008         [sbml]
# 88                Andersen  2008         [sbml]
# 89             Vongsangnak  2008         [sbml]
# 90                 Chavali  2008         [sbml]
# 91                    Sohn  2010         [sbml]
# 92                   Kumar  2011         [sbml]
# 93                 Caspeta  2012         [sbml]
# 94                   Chung  2010        [excel]
# 95              Sigurdsson  2010        [excel]
# 96                   Vanee  2010             []
# 97                 Kuepfer  2005        [excel]
# 98               Gonnerman  2013         [sbml]
# 99                    Sohn  2012         [sbml]
# 100                     Vu  2012         [sbml]
# 101                   Zhao  2012         [sbml]
# 102                  Wodke  2013         [sbml]
# 103                   Fang  2011         [sbml]
# 104                Peyraud  2011         [sbml]
# 105                Caspeta  2012         [sbml]
# 106                  Agren  2013         [sbml]
# 107            Vongsangnak  2011         [sbml]
# 108                Wei Zou  2013         [sbml]
# 109               Gonzalez  2009         [sbml]
# 110                 Mendum  2011         [sbml]
# 111               Klanchui  2012         [sbml]
# 112         Schatschneider  2013         [sbml]
# 113             Oscar Dias  2013         [sbml]
# 114               McAnulty  2012         [sbml]
# 115                Nogales  2012             []
# 116                Heinken  2012             []
# 117                   Wang  2014        [excel]
# 118                Mueller  2013  [sbml, excel]
# 119                Mueller  2013  [sbml, excel]
# 120                Mueller  2013  [sbml, excel]
# 121                Mueller  2013  [sbml, excel]
# 122                Mueller  2013  [sbml, excel]
# 123                Flahaut  2013         [sbml]
# 124                Jie Liu  2013        [excel]
# 125              El-Semman  2014  [sbml, excel]
# 126              El-Semman  2014  [sbml, excel]
# 127           Aline Metris  2011        [excel]
# 128             Na-Rae Lee  2014  [sbml, excel]
# 129                Prigent  2014         [sbml]
# 130                  Fondi  2014         [sbml]
# 131                 Arnold  2014         [sbml]
# 132       Harish Nagarajan  2013        [excel]
# 133          Satyakam Dash  2014         [sbml]
# 134            M. Larocque  2014  [sbml, excel]
# 135                Chao Ye  2015         [sbml]
# 136               N. Goyal  2014        [excel]
# 137             Cheng Wang  2015             []
# 138               N. Veith  2014             []
# 139                J. Park  2013             []
# 140                Jie Liu  2015             []
# 141         Aung (updated)  2015         [sbml]
# 142              Joomi Kim  2015  [sbml, excel]
# 143          Nicolas Loira  2012         [sbml]
# 144              Kerkhoven  2016         [sbml]
# 145      Jennifer Levering  2016         [sbml]
# 146      Jennifer Levering  2016         [sbml]
# 147     Mohammad Tajparast  2015        [excel]
# 148              B Pereira  2018             []
# 149             Oscar Dias  2019         [sbml]
#
#                                               organism  \
# 0             Escherichia coli str. K12 substr. MG1655
# 1             Escherichia coli str. K12 substr. MG1655
# 2                             Saccharomyces cerevisiae
# 3                       Pseudomonas putida str. KT2440
# 4                     Pseudomonas aeruginosa str. PAO1
# 5                             Saccharomyces cerevisiae
# 6                 Saccharomyces cerevisiae str. Sc288
# 7                                   Escherichia coli W
# 8             Escherichia coli str. K12 substr. MG1655
# 9                                                Yeast
# 10                      Pseudomonas putida str. KT2440
# 11                         Acinetobacter baumannii AYE
# 12                      Pseudomonas putida str. KT2440
# 13                Klebsiella pneumoniae str. MGH 78578
# 14            Clostridium thermocellum str. ATCC 27405
# 15               Mycobacterium tuberculosis str. H37Rv
# 16            Clostridium beijerinckii str. NCIMB 8052
# 17                               Bacillus subtilis 168
# 18               Dehalococcoides ethenogenes str. 2061
# 19                              Methanosarcina barkeri
# 20                                Arabidopsis thaliana
# 21            Escherichia coli str. K12 substr. MG1655
# 22                      Helicobacter pylori str. 26695
# 23                Saccharomyces cerevisiae str. Sc288
# 24                Saccharomyces cerevisiae str. Sc288
# 25                           Chlamydomonas reinhardtii
# 26                               Staphylococcus aureus
# 27                               Plasmodium falciparum
# 28                       Thermotoga maritima str. MSB8
# 29                                        Homo sapiens
# 30                  Neisseria meningitidis serogroup B
# 31                        Porphyromonas gingivalis W83
# 32                      Pseudomonas putida str. KT2440
# 33                               Rhizobium etli CFN 42
# 34                              Ralstonia eutropha H16
# 35                           Acinetobacter baylyi ADP1
# 36                                   Bacillus subtilis
# 37   Buchnera aphidicola str. APS (Acyrthosiphon pi...
# 38                Chromohalobacter salexigens DSM 3043
# 39                 Clostridium acetobutylicum ATCC 824
# 40                 Clostridium acetobutylicum ATCC 824
# 41               Corynebacterium glutamicum ATCC 13032
# 42               Corynebacterium glutamicum ATCC 13032
# 43            Escherichia coli str. K12 substr. MG1655
# 44        Francisella tularensis subsp. holarctica LVS
# 45                           Geobacter metallireducens
# 46                            Geobacter sulfurreducens
# 47                      Haemophilus influenzae Rd KW20
# 48                      Haemophilus influenzae Rd KW20
# 49                      Helicobacter pylori str. 26695
# 50                  Ketogulonicigenium vulgare WSH-001
# 51                       Lactobacillus plantarum WCFS1
# 52             Lactococcus lactis subsp. lactis Il1403
# 53               Mannheimia succiniciproducens MBEL55E
# 54               Mannheimia succiniciproducens MBEL55E
# 55               Mycobacterium tuberculosis str. H37Rv
# 56               Mycobacterium tuberculosis str. H37Rv
# 57                           Mycoplasma genitalium G37
# 58                             Vibrio vulnificus CMCP6
# 59          Yersinia pestis biovar Microtus str. 91001
# 60                                Yersinia pestis CO92
# 61                Zymomonas mobilis subsp. mobilis ZM4
# 62                Zymomonas mobilis subsp. mobilis ZM4
# 63                          Salmonella typhimurium LT2
# 64                          Salmonella typhimurium LT2
# 65                          Salmonella typhimurium LT2
# 66                       Rhodoferax ferrireducens T118
# 67                          Shewanella oneidensis MR-1
# 68                               Staphylococcus aureus
# 69                               Staphylococcus aureus
# 70                Streptococcus thermophilus LMG 18311
# 71                       Streptomyces coelicolor A3(2)
# 72                       Streptomyces coelicolor A3(2)
# 73                          Synechocystis sp. PCC 6803
# 74                          Synechocystis sp. PCC 6803
# 75                            Saccharomyces cerevisiae
# 76                                       Synechocystis
# 77                                               Yeast
# 78                                               Yeast
# 79                           Chlamydomonas reinhardtii
# 80               \tMethanosarcina acetivorans str. C2A
# 81           Blattabacterium sp. (Blattella germanica)
# 82         Blattabacterium sp. (Periplaneta americana)
# 83                            Scheffersomyces stipitis
# 84                            Scheffersomyces stipitis
# 85                       Pseudomonas fluorescens SBW25
# 86                       Rhodobacter sphaeroides 2.4.1
# 87                        Aspergillus nidulans FGSC A4
# 88                        Aspergillus niger CBS 513.88
# 89                            Aspergillus oryzae RIB40
# 90                           Leishmania major Friedlin
# 91                            Pichia pastoris CBS 7435
# 92                      Methanosarcina acetivorans C2A
# 93                               Pichia pastoris GS115
# 94                               Pichia pastoris GS115
# 95                                        Mus musculus
# 96                       Cryptosporidium hominis TU502
# 97                            Saccharomyces cerevisiae
# 98                              Methanosarcina barkeri
# 99                           Schizosaccharomyces pombe
# 100                          Cyanothece sp. ATCC 51142
# 101                        Sinorhizobium meliloti 1021
# 102                              Mycoplasma pneumoniae
# 103                     Burkholderia cenocepacia J2315
# 104                    Methylobacterium extorquens AM1
# 105                                    Pichia stipitis
# 106          Penicillium chrysogenum Wisconsin 54-1255
# 107                          Amycolatopsis balhimycina
# 108                        Bacillus megaterium WSH-002
# 109                    Natronomonas pharaonis DSM 2160
# 110                             Neisseria meningitidis
# 111                             Spirulina platensis C1
# 112    Xanthomonas campestris pv. campestris str. B100
# 113                   Kluyveromyces lactis NRRL Y-1140
# 114                Clostridium acetobutylicum ATCC 824
# 115                                Thermotoga maritima
# 116                       Bacteroides thetaiotaomicron
# 117               Saccharopolyspora spinosa NRRL 18395
# 118                            Cyanothece sp. PCC 7424
# 119                            Cyanothece sp. PCC 7425
# 120                            Cyanothece sp. PCC 7822
# 121                            Cyanothece sp. PCC 8801
# 122                            Cyanothece sp. PCC 8802
# 123          Lactococcus lactis subsp. cremoris MG1363
# 124                        Aspergillus terreus NIH2624
# 125                 Bifidobacterium adolescentis L2-32
# 126                Faecalibacterium prausnitzii A2-165
# 127      Campylobacter jejuni subsp. jejuni NCTC 11168
# 128                               Thermus thermophilus
# 129                             Ectocarpus siliculosus
# 130              Pseudoalteromonas haloplanktis TAC125
# 131                               Arabidopsis thaliana
# 132                            Clostridium ljungdahlii
# 133                Clostridium acetobutylicum ATCC 824
# 134                          Clostridium difficile 630
# 135                                 Mortierella alpina
# 136                       Methanococcus maripaludis S2
# 137  Pectobacterium carotovorum subsp. carotovorum PC1
# 138                         Enterococcus faecalis V583
# 139                                 Klebsiella oxytoca
# 140                           Lactobacillus casei LC2W
# 141                                              Yeast
# 142                          Phaeodactylum tricornutum
# 143                                Yarrowia lipolytica
# 144                                Yarrowia lipolytica
# 145                          Phaeodactylum tricornutum
# 146                          Phaeodactylum tricornutum
# 147                            Rhodococcus jostii RHA1
# 148                   Actinobacillus succinogenes 130Z
# 149                 Streptococcus pneumoniae Strain R6
#
#                                               taxonomy  validated
# 0    Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 1    Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 2    Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...       True
# 3    Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 4    Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 5    Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 6    Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 7    Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 8    Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 9                      Eukaryota; Opisthokonta; Fungi;      False
# 10   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 11   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 12   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 13   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 14    Bacteria; Firmicutes; Clostridia; Clostridial...       True
# 15   Bacteria; Actinobacteria; Actinobacteria; Acti...       True
# 16   Bacteria; Firmicutes; Clostridia; Clostridiale...       True
# 17   Bacteria; Firmicutes; Bacilli; Bacillales; Bac...       True
# 18   Bacteria; Chloroflexi; Dehalococcoidetes; Deha...       True
# 19   Archaea; Euryarchaeota; Methanomicrobia; Metha...       True
# 20   Eukaryota; Viridiplantae; Streptophyta; Strept...       True
# 21   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 22    Bacteria; Proteobacteria; delta/epsilon subdi...       True
# 23   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 24   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...       True
# 25   Eukaryota; Viridiplantae; Chlorophyta; Chlorop...       True
# 26    Bacteria; Firmicutes; Bacilli; Bacillales; St...       True
# 27   Eukaryota; Alveolata; Apicomplexa; Aconoidasid...       True
# 28   Bacteria; Thermotogae; Thermotogae; Thermotoga...       True
# 29   Eukaryota; Opisthokonta; Metazoa; Eumetazoa; B...       True
# 30    Bacteria; Proteobacteria; Betaproteobacteria;...      False
# 31    Bacteria; Bacteroidetes/Chlorobi group; Bacte...      False
# 32   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 33    Bacteria; Proteobacteria; Alphaproteobacteria...      False
# 34   Bacteria; Proteobacteria; Betaproteobacteria; ...      False
# 35   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 36   Bacteria; Firmicutes; Bacilli; Bacillales; Bac...       True
# 37   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 38   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 39   Bacteria; Firmicutes; Clostridia; Clostridiale...      False
# 40   Bacteria; Firmicutes; Clostridia; Clostridiale...      False
# 41   Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 42   Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 43   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 44   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 45   Bacteria; Proteobacteria; delta/epsilon subdiv...      False
# 46   Bacteria; Proteobacteria; delta/epsilon subdiv...      False
# 47   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 48   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 49    Bacteria; Proteobacteria; delta/epsilon subdi...      False
# 50   Bacteria; Proteobacteria; Alphaproteobacteria;...      False
# 51   Bacteria; Firmicutes; Bacilli; Lactobacillales...      False
# 52   Bacteria; Firmicutes; Bacilli; Lactobacillales...       True
# 53   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 54   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 55   Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 56   Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 57   Bacteria; Tenericutes; Mollicutes; Mycoplasmat...      False
# 58   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 59   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 60    Bacteria; Proteobacteria; Gammaproteobacteria...       True
# 61   Bacteria; Proteobacteria; Alphaproteobacteria;...      False
# 62   Bacteria; Proteobacteria; Alphaproteobacteria;...      False
# 63   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 64   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 65   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 66   Bacteria; Proteobacteria; Betaproteobacteria; ...      False
# 67   Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 68    Bacteria; Firmicutes; Bacilli; Bacillales; St...      False
# 69    Bacteria; Firmicutes; Bacilli; Bacillales; St...      False
# 70    Bacteria; Firmicutes; Bacilli; Lactobacillale...      False
# 71   Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 72   Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 73   Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 74   Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 75   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...       True
# 76   Bacteria; Cyanobacteria; Oscillatoriophycideae...       True
# 77                     Eukaryota; Opisthokonta; Fungi;       True
# 78                     Eukaryota; Opisthokonta; Fungi;       True
# 79   Eukaryota; Viridiplantae; Chlorophyta; Chlorop...       True
# 80   Archaea; Euryarchaeota; Methanomicrobia; Metha...       True
# 81   Bacteria; Bacteroidetes/Chlorobi group; Bacter...       True
# 82   Bacteria; Bacteroidetes/Chlorobi group; Bacter...       True
# 83   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 84   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 85   Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 86   Bacteria; Proteobacteria; Alphaproteobacteria;...       True
# 87   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 88   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...       True
# 89   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 90   Eukaryota; Euglenozoa; Kinetoplastida; Trypano...      False
# 91   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 92   Archaea; Euryarchaeota; Methanomicrobia; Metha...      False
# 93   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 94   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 95   Eukaryota; Opisthokonta; Metazoa; Eumetazoa; B...      False
# 96   Eukaryota; Alveolata; Apicomplexa; Conoidasida...      False
# 97   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 98   Archaea; Euryarchaeota; Methanomicrobia; Metha...      False
# 99   Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 100  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 101  Bacteria; Proteobacteria; Alphaproteobacteria;...      False
# 102  Bacteria; Tenericutes; Mollicutes; Mycoplasmat...       True
# 103  Bacteria; Proteobacteria; Betaproteobacteria; ...      False
# 104  Bacteria; Proteobacteria; Alphaproteobacteria;...      False
# 105  Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 106  Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 107  Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 108  Bacteria; Firmicutes; Bacilli; Bacillales; Bac...      False
# 109  Archaea; Euryarchaeota; Halobacteria; Halobact...      False
# 110  Bacteria; Proteobacteria; Betaproteobacteria; ...      False
# 111  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 112  Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 113  Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...       True
# 114  Bacteria; Firmicutes; Clostridia; Clostridiale...       True
# 115  Bacteria; Thermotogae; Thermotogae; Thermotoga...      False
# 116  Bacteria; Bacteroidetes/Chlorobi group; Bacter...      False
# 117  Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 118  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 119  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 120  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 121  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 122  Bacteria; Cyanobacteria; Oscillatoriophycideae...      False
# 123  Bacteria; Firmicutes; Bacilli; Lactobacillales...       True
# 124  Eukaryota; Opisthokonta; Fungi; Dikarya; Ascom...      False
# 125  Bacteria; Actinobacteria; Actinobacteria; Acti...      False
# 126  Bacteria; Firmicutes; Clostridia; Clostridiale...      False
# 127  Bacteria; Proteobacteria; delta/epsilon subdiv...      False
# 128  Bacteria; Deinococcus-Thermus; Deinococci; The...       True
# 129  Eukaryota; Stramenopiles; PX clade; Phaeophyce...      False
# 130  Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 131  Eukaryota; Viridiplantae; Streptophyta; Strept...      False
# 132  Bacteria; Firmicutes; Clostridia; Clostridiale...      False
# 133  Bacteria; Firmicutes; Clostridia; Clostridiale...       True
# 134  Bacteria; Firmicutes; Clostridia; Clostridiale...       True
# 135  Eukaryota; Opisthokonta; Fungi; Fungi incertae...      False
# 136  Archaea; Euryarchaeota; Methanococci; Methanoc...      False
# 137  Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 138  Bacteria; Firmicutes; Bacilli; Lactobacillales...      False
# 139  Bacteria; Proteobacteria; Gammaproteobacteria;...      False
# 140  Bacteria; Firmicutes; Bacilli; Lactobacillales...      False
# 141                    Eukaryota; Opisthokonta; Fungi;      False
# 142  Eukaryota; Stramenopiles; Bacillariophyta; Bac...       True
# 143  Eukaryota; Fungi; Dikarya; Ascomycota; Sacchar...      False
# 144  Eukaryota; Fungi; Dikarya; Ascomycota; Sacchar...      False
# 145  Eukaryota; Stramenopiles; Bacillariophyta; Bac...       True
# 146  Eukaryota; Stramenopiles; Bacillariophyta; Bac...       True
# 147  Bacteria; Terrabacteria group; Actinobacteria;...      False
# 148  Bacteria; Proteobacteria; Gammaproteobacteria;...       True
# 149  cellular organisms; Bacteria; Terrabacteria gr...       True

# %% [markdown]
# Many of these models have not been curated to the level of the BIGG database so care should be taken when using them.

# %% [markdown]
# ## Model Information
#
# The basic infomration stored in a model can be determined with the following COBRApy commands.
#
# The model summary is given as follows

# %%
model
# Out:
# <Model e_coli_core at 0x20772731be0>

# %% [markdown]
# The attributes of a model can be seen with the following

# %%
help(model)
# Out:
# Help on Model in module cobra.core.model object:
#
# class Model(cobra.core.object.Object)
#  |  Model(id_or_model=None, name=None)
#  |
#  |  Class representation for a cobra model
#  |
#  |  Parameters
#  |  ----------
#  |  id_or_model : Model, string
#  |      Either an existing Model object in which case a new model object is
#  |      instantiated with the same properties as the original model,
#  |      or an identifier to associate with the model as a string.
#  |  name : string
#  |      Human readable name for the model
#  |
#  |  Attributes
#  |  ----------
#  |  reactions : DictList
#  |      A DictList where the key is the reaction identifier and the value a
#  |      Reaction
#  |  metabolites : DictList
#  |      A DictList where the key is the metabolite identifier and the value a
#  |      Metabolite
#  |  genes : DictList
#  |      A DictList where the key is the gene identifier and the value a
#  |      Gene
#  |  groups : DictList
#  |      A DictList where the key is the group identifier and the value a
#  |      Group
#  |  solution : Solution
#  |      The last obtained solution from optimizing the model.
#  |
#  |  Method resolution order:
#  |      Model
#  |      cobra.core.object.Object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other_model)
#  |      Add the content of another model to this model (+).
#  |
#  |      The model is copied as a new object, with a new model identifier,
#  |      and copies of all the reactions in the other model are added to this
#  |      model. The objective is the sum of the objective expressions for the
#  |      two models.
#  |
#  |  __enter__(self)
#  |      Record all future changes to the model, undoing them when a call to
#  |      __exit__ is received
#  |
#  |  __exit__(self, type, value, traceback)
#  |      Pop the top context manager and trigger the undo functions
#  |
#  |  __getstate__(self)
#  |      Get state for serialization.
#  |
#  |      Ensures that the context stack is cleared prior to serialization,
#  |      since partial functions cannot be pickled reliably.
#  |
#  |  __iadd__(self, other_model)
#  |      Incrementally add the content of another model to this model (+=).
#  |
#  |      Copies of all the reactions in the other model are added to this
#  |      model. The objective is the sum of the objective expressions for the
#  |      two models.
#  |
#  |  __init__(self, id_or_model=None, name=None)
#  |      A simple object with an identifier
#  |
#  |      Parameters
#  |      ----------
#  |      id: None or a string
#  |          the identifier to associate with the object
#  |
#  |  __setstate__(self, state)
#  |      Make sure all cobra.Objects in the model point to the model.
#  |
#  |  add_boundary(self, metabolite, type='exchange', reaction_id=None, lb=None, ub=None, sbo_term=None)
#  |      Add a boundary reaction for a given metabolite.
#  |
#  |      There are three different types of pre-defined boundary reactions:
#  |      exchange, demand, and sink reactions.
#  |      An exchange reaction is a reversible, unbalanced reaction that adds
#  |      to or removes an extracellular metabolite from the extracellular
#  |      compartment.
#  |      A demand reaction is an irreversible reaction that consumes an
#  |      intracellular metabolite.
#  |      A sink is similar to an exchange but specifically for intracellular
#  |      metabolites, i.e., a reversible reaction that adds or removes an
#  |      intracellular metabolite.
#  |
#  |      If you set the reaction `type` to something else, you must specify the
#  |      desired identifier of the created reaction along with its upper and
#  |      lower bound. The name will be given by the metabolite name and the
#  |      given `type`.
#  |
#  |      Parameters
#  |      ----------
#  |      metabolite : cobra.Metabolite
#  |          Any given metabolite. The compartment is not checked but you are
#  |          encouraged to stick to the definition of exchanges and sinks.
#  |      type : str, {"exchange", "demand", "sink"}
#  |          Using one of the pre-defined reaction types is easiest. If you
#  |          want to create your own kind of boundary reaction choose
#  |          any other string, e.g., 'my-boundary'.
#  |      reaction_id : str, optional
#  |          The ID of the resulting reaction. This takes precedence over the
#  |          auto-generated identifiers but beware that it might make boundary
#  |          reactions harder to identify afterwards when using `model.boundary`
#  |          or specifically `model.exchanges` etc.
#  |      lb : float, optional
#  |          The lower bound of the resulting reaction.
#  |      ub : float, optional
#  |          The upper bound of the resulting reaction.
#  |      sbo_term : str, optional
#  |          A correct SBO term is set for the available types. If a custom
#  |          type is chosen, a suitable SBO term should also be set.
#  |
#  |      Returns
#  |      -------
#  |      cobra.Reaction
#  |          The created boundary reaction.
#  |
#  |      Examples
#  |      --------
#  |      >>> import cobra.test
#  |      >>> model = cobra.test.create_test_model("textbook")
#  |      >>> demand = model.add_boundary(model.metabolites.atp_c, type="demand")
#  |      >>> demand.id
#  |      'DM_atp_c'
#  |      >>> demand.name
#  |      'ATP demand'
#  |      >>> demand.bounds
#  |      (0, 1000.0)
#  |      >>> demand.build_reaction_string()
#  |      'atp_c --> '
#  |
#  |  add_cons_vars(self, what, **kwargs)
#  |      Add constraints and variables to the model's mathematical problem.
#  |
#  |      Useful for variables and constraints that can not be expressed with
#  |      reactions and simple lower and upper bounds.
#  |
#  |      Additions are reversed upon exit if the model itself is used as
#  |      context.
#  |
#  |      Parameters
#  |      ----------
#  |      what : list or tuple of optlang variables or constraints.
#  |         The variables or constraints to add to the model. Must be of
#  |         class `optlang.interface.Variable` or
#  |         `optlang.interface.Constraint`.
#  |      **kwargs : keyword arguments
#  |         Passed to solver.add()
#  |
#  |  add_groups(self, group_list)
#  |      Add groups to the model.
#  |
#  |      Groups with identifiers identical to a group already in the model are
#  |      ignored.
#  |
#  |      If any group contains members that are not in the model, these members
#  |      are added to the model as well. Only metabolites, reactions, and genes
#  |      can have groups.
#  |
#  |      Parameters
#  |      ----------
#  |      group_list : list
#  |          A list of `cobra.Group` objects to add to the model.
#  |
#  |  add_metabolites(self, metabolite_list)
#  |      Will add a list of metabolites to the model object and add new
#  |      constraints accordingly.
#  |
#  |      The change is reverted upon exit when using the model as a context.
#  |
#  |      Parameters
#  |      ----------
#  |      metabolite_list : A list of `cobra.core.Metabolite` objects
#  |
#  |  add_reaction(self, reaction)
#  |      Will add a cobra.Reaction object to the model, if
#  |      reaction.id is not in self.reactions.
#  |
#  |      Parameters
#  |      ----------
#  |      reaction : cobra.Reaction
#  |          The reaction to add
#  |
#  |      Deprecated (0.6). Use `~cobra.Model.add_reactions` instead
#  |
#  |  add_reactions(self, reaction_list)
#  |      Add reactions to the model.
#  |
#  |      Reactions with identifiers identical to a reaction already in the
#  |      model are ignored.
#  |
#  |      The change is reverted upon exit when using the model as a context.
#  |
#  |      Parameters
#  |      ----------
#  |      reaction_list : list
#  |          A list of `cobra.Reaction` objects
#  |
#  |  copy(self)
#  |      Provides a partial 'deepcopy' of the Model.  All of the Metabolite,
#  |      Gene, and Reaction objects are created anew but in a faster fashion
#  |      than deepcopy
#  |
#  |  get_associated_groups(self, element)
#  |      Returns a list of groups that an element (reaction, metabolite, gene)
#  |      is associated with.
#  |
#  |      Parameters
#  |      ----------
#  |      element: `cobra.Reaction`, `cobra.Metabolite`, or `cobra.Gene`
#  |
#  |      Returns
#  |      -------
#  |      list of `cobra.Group`
#  |          All groups that the provided object is a member of
#  |
#  |  get_metabolite_compartments(self)
#  |      Return all metabolites' compartments.
#  |
#  |  merge(self, right, prefix_existing=None, inplace=True, objective='left')
#  |      Merge two models to create a model with the reactions from both
#  |      models.
#  |
#  |      Custom constraints and variables from right models are also copied
#  |      to left model, however note that, constraints and variables are
#  |      assumed to be the same if they have the same name.
#  |
#  |      right : cobra.Model
#  |          The model to add reactions from
#  |      prefix_existing : string
#  |          Prefix the reaction identifier in the right that already exist
#  |          in the left model with this string.
#  |      inplace : bool
#  |          Add reactions from right directly to left model object.
#  |          Otherwise, create a new model leaving the left model untouched.
#  |          When done within the model as context, changes to the models are
#  |          reverted upon exit.
#  |      objective : string
#  |          One of 'left', 'right' or 'sum' for setting the objective of the
#  |          resulting model to that of the corresponding model or the sum of
#  |          both.
#  |
#  |  optimize(self, objective_sense=None, raise_error=False)
#  |      Optimize the model using flux balance analysis.
#  |
#  |      Parameters
#  |      ----------
#  |      objective_sense : {None, 'maximize' 'minimize'}, optional
#  |          Whether fluxes should be maximized or minimized. In case of None,
#  |          the previous direction is used.
#  |      raise_error : bool
#  |          If true, raise an OptimizationError if solver status is not
#  |           optimal.
#  |
#  |      Notes
#  |      -----
#  |      Only the most commonly used parameters are presented here.  Additional
#  |      parameters for cobra.solvers may be available and specified with the
#  |      appropriate keyword argument.
#  |
#  |  remove_cons_vars(self, what)
#  |      Remove variables and constraints from the model's mathematical
#  |      problem.
#  |
#  |      Remove variables and constraints that were added directly to the
#  |      model's underlying mathematical problem. Removals are reversed
#  |      upon exit if the model itself is used as context.
#  |
#  |      Parameters
#  |      ----------
#  |      what : list or tuple of optlang variables or constraints.
#  |         The variables or constraints to add to the model. Must be of
#  |         class `optlang.interface.Variable` or
#  |         `optlang.interface.Constraint`.
#  |
#  |  remove_groups(self, group_list)
#  |      Remove groups from the model.
#  |
#  |      Members of each group are not removed
#  |      from the model (i.e. metabolites, reactions, and genes in the group
#  |      stay in the model after any groups containing them are removed).
#  |
#  |      Parameters
#  |      ----------
#  |      group_list : list
#  |          A list of `cobra.Group` objects to remove from the model.
#  |
#  |  remove_metabolites(self, metabolite_list, destructive=False)
#  |      Remove a list of metabolites from the the object.
#  |
#  |      The change is reverted upon exit when using the model as a context.
#  |
#  |      Parameters
#  |      ----------
#  |      metabolite_list : list
#  |          A list with `cobra.Metabolite` objects as elements.
#  |
#  |      destructive : bool
#  |          If False then the metabolite is removed from all
#  |          associated reactions.  If True then all associated
#  |          reactions are removed from the Model.
#  |
#  |  remove_reactions(self, reactions, remove_orphans=False)
#  |      Remove reactions from the model.
#  |
#  |      The change is reverted upon exit when using the model as a context.
#  |
#  |      Parameters
#  |      ----------
#  |      reactions : list
#  |          A list with reactions (`cobra.Reaction`), or their id's, to remove
#  |
#  |      remove_orphans : bool
#  |          Remove orphaned genes and metabolites from the model as well
#  |
#  |  repair(self, rebuild_index=True, rebuild_relationships=True)
#  |      Update all indexes and pointers in a model
#  |
#  |      Parameters
#  |      ----------
#  |      rebuild_index : bool
#  |          rebuild the indices kept in reactions, metabolites and genes
#  |      rebuild_relationships : bool
#  |           reset all associations between genes, metabolites, model and
#  |           then re-add them.
#  |
#  |  slim_optimize(self, error_value=nan, message=None)
#  |      Optimize model without creating a solution object.
#  |
#  |      Creating a full solution object implies fetching shadow prices and
#  |      flux values for all reactions and metabolites from the solver
#  |      object. This necessarily takes some time and in cases where only one
#  |      or two values are of interest, it is recommended to instead use this
#  |      function which does not create a solution object returning only the
#  |      value of the objective. Note however that the `optimize()` function
#  |      uses efficient means to fetch values so if you need fluxes/shadow
#  |      prices for more than say 4 reactions/metabolites, then the total
#  |      speed increase of `slim_optimize` versus `optimize` is  expected to
#  |      be small or even negative depending on how you fetch the values
#  |      after optimization.
#  |
#  |      Parameters
#  |      ----------
#  |      error_value : float, None
#  |         The value to return if optimization failed due to e.g.
#  |         infeasibility. If None, raise `OptimizationError` if the
#  |         optimization fails.
#  |      message : string
#  |         Error message to use if the model optimization did not succeed.
#  |
#  |      Returns
#  |      -------
#  |      float
#  |          The objective value.
#  |
#  |  summary(self, solution=None, fva=None)
#  |      Create a summary of the exchange fluxes of the model.
#  |
#  |      Parameters
#  |      ----------
#  |      solution : cobra.Solution, optional
#  |          A previous model solution to use for generating the summary. If
#  |          ``None``, the summary method will generate a parsimonious flux
#  |          distribution (default None).
#  |      fva : pandas.DataFrame or float, optional
#  |          Whether or not to include flux variability analysis in the output.
#  |          If given, `fva` should either be a previous FVA solution matching the
#  |          model or a float between 0 and 1 representing the fraction of the
#  |          optimum objective to be searched (default None).
#  |
#  |      Returns
#  |      -------
#  |      cobra.ModelSummary
#  |
#  |      See Also
#  |      --------
#  |      Reaction.summary
#  |      Metabolite.summary
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  boundary
#  |      Boundary reactions in the model.
#  |      Reactions that either have no substrate or product.
#  |
#  |  constraints
#  |      The constraints in the cobra model.
#  |
#  |      In a cobra model, most constraints are metabolites and their
#  |      stoichiometries. However, for specific use cases, it may also be
#  |      useful to have other types of constraints. This property defines all
#  |      constraints currently associated with the model's problem.
#  |
#  |      Returns
#  |      -------
#  |      optlang.container.Container
#  |          A container with all associated constraints.
#  |
#  |  demands
#  |      Demand reactions in model.
#  |      Irreversible reactions that accumulate or consume a metabolite in
#  |      the inside of the model.
#  |
#  |  exchanges
#  |      Exchange reactions in model.
#  |      Reactions that exchange mass with the exterior. Uses annotations
#  |      and heuristics to exclude non-exchanges such as sink reactions.
#  |
#  |  problem
#  |      The interface to the model's underlying mathematical problem.
#  |
#  |      Solutions to cobra models are obtained by formulating a mathematical
#  |      problem and solving it. Cobrapy uses the optlang package to
#  |      accomplish that and with this property you can get access to the
#  |      problem interface directly.
#  |
#  |      Returns
#  |      -------
#  |      optlang.interface
#  |          The problem interface that defines methods for interacting with
#  |          the problem and associated solver directly.
#  |
#  |  sinks
#  |      Sink reactions in model.
#  |      Reversible reactions that accumulate or consume a metabolite in
#  |      the inside of the model.
#  |
#  |  variables
#  |      The mathematical variables in the cobra model.
#  |
#  |      In a cobra model, most variables are reactions. However,
#  |      for specific use cases, it may also be useful to have other types of
#  |      variables. This property defines all variables currently associated
#  |      with the model's problem.
#  |
#  |      Returns
#  |      -------
#  |      optlang.container.Container
#  |          A container with all associated variables.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  compartments
#  |
#  |  description
#  |
#  |  medium
#  |
#  |  objective
#  |      Get or set the solver objective
#  |
#  |      Before introduction of the optlang based problems,
#  |      this function returned the objective reactions as a list. With
#  |      optlang, the objective is not limited a simple linear summation of
#  |      individual reaction fluxes, making that return value ambiguous.
#  |      Henceforth, use `cobra.util.solver.linear_reaction_coefficients` to
#  |      get a dictionary of reactions with their linear coefficients (empty
#  |      if there are none)
#  |
#  |      The set value can be dictionary (reactions as keys, linear
#  |      coefficients as values), string (reaction identifier), int (reaction
#  |      index), Reaction or problem.Objective or sympy expression
#  |      directly interpreted as objectives.
#  |
#  |      When using a `HistoryManager` context, this attribute can be set
#  |      temporarily, reversed when the exiting the context.
#  |
#  |  objective_direction
#  |      Get or set the objective direction.
#  |
#  |      When using a `HistoryManager` context, this attribute can be set
#  |      temporarily, reversed when exiting the context.
#  |
#  |  solver
#  |      Get or set the attached solver instance.
#  |
#  |      The associated the solver object, which manages the interaction with
#  |      the associated solver, e.g. glpk.
#  |
#  |      This property is useful for accessing the optimization problem
#  |      directly and to define additional non-metabolic constraints.
#  |
#  |      Examples
#  |      --------
#  |      >>> import cobra.test
#  |      >>> model = cobra.test.create_test_model("textbook")
#  |      >>> new = model.problem.Constraint(model.objective.expression,
#  |      >>> lb=0.99)
#  |      >>> model.solver.add(new)
#  |
#  |  tolerance
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from cobra.core.object.Object:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from cobra.core.object.Object:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  annotation
#  |
#  |  id

# %% [markdown]
# The reactions, metabolites, genes, and groups are all stored as disctionaries in the model.
#
# ### Reactions Attributes

# %%
help(model.reactions)
# Out:
# Help on DictList in module cobra.core.dictlist object:
#
# class DictList(builtins.list)
#  |  DictList(*args)
#  |
#  |  A combined dict and list
#  |
#  |  This object behaves like a list, but has the O(1) speed
#  |  benefits of a dict when looking up elements by their id.
#  |
#  |  Method resolution order:
#  |      DictList
#  |      builtins.list
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |      x.__add__(y) <==> x + y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's which do not intersect
#  |          with self
#  |
#  |  __contains__(self, object)
#  |      DictList.__contains__(object) <==> object in DictList
#  |
#  |      object: str or :class:`~cobra.core.Object.Object`
#  |
#  |  __copy__(self)
#  |
#  |  __delitem__(self, index)
#  |      Delete self[key].
#  |
#  |  __delslice__(self, i, j)
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __getattr__(self, attr)
#  |
#  |  __getitem__(self, i)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(self, i, j)
#  |
#  |  __getstate__(self)
#  |      gets internal state
#  |
#  |      This is only provided for backwards compatibility so older
#  |      versions of cobrapy can load pickles generated with cobrapy. In
#  |      reality, the "_dict" state is ignored when loading a pickle
#  |
#  |  __iadd__(self, other)
#  |      x.__iadd__(y) <==> x += y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's whcih do not intersect
#  |          with self
#  |
#  |  __init__(self, *args)
#  |      Instantiate a combined dict and list.
#  |
#  |      Parameters
#  |      ----------
#  |      args : iterable
#  |          iterable as single argument to create new DictList from
#  |
#  |  __isub__(self, other)
#  |      x.__sub__(y) <==> x -= y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's present in the list
#  |
#  |  __reduce__(self)
#  |      Helper for pickle.
#  |
#  |  __setitem__(self, i, y)
#  |      Set self[key] to value.
#  |
#  |  __setslice__(self, i, j, y)
#  |
#  |  __setstate__(self, state)
#  |      sets internal state
#  |
#  |      Ignore the passed in state and recalculate it. This is only for
#  |      compatibility with older pickles which did not correctly specify
#  |      the initialization class
#  |
#  |  __sub__(self, other)
#  |      x.__sub__(y) <==> x - y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's present in the list
#  |
#  |  add(self, x)
#  |      Opposite of `remove`. Mirrors set.add
#  |
#  |  append(self, object)
#  |      append object to end
#  |
#  |  extend(self, iterable)
#  |      extend list by appending elements from the iterable
#  |
#  |  get_by_any(self, iterable)
#  |      Get a list of members using several different ways of indexing
#  |
#  |      Parameters
#  |      ----------
#  |      iterable : list (if not, turned into single element list)
#  |          list where each element is either int (referring to an index in
#  |          in this DictList), string (a id of a member in this DictList) or
#  |          member of this DictList for pass-through
#  |
#  |      Returns
#  |      -------
#  |      list
#  |          a list of members
#  |
#  |  get_by_id(self, id)
#  |      return the element with a matching id
#  |
#  |  has_id(self, id)
#  |
#  |  index(self, id, *args)
#  |      Determine the position in the list
#  |
#  |      id: A string or a :class:`~cobra.core.Object.Object`
#  |
#  |  insert(self, index, object)
#  |      insert object before index
#  |
#  |  list_attr(self, attribute)
#  |      return a list of the given attribute for every object
#  |
#  |  pop(self, *args)
#  |      remove and return item at index (default last).
#  |
#  |  query(self, search_function, attribute=None)
#  |      Query the list
#  |
#  |      Parameters
#  |      ----------
#  |      search_function : a string, regular expression or function
#  |          Used to find the matching elements in the list.
#  |          - a regular expression (possibly compiled), in which case the
#  |          given attribute of the object should match the regular expression.
#  |          - a function which takes one argument and returns True for
#  |          desired values
#  |
#  |      attribute : string or None
#  |          the name attribute of the object to passed as argument to the
#  |          `search_function`. If this is None, the object itself is used.
#  |
#  |      Returns
#  |      -------
#  |      DictList
#  |          a new list of objects which match the query
#  |
#  |      Examples
#  |      --------
#  |      >>> import cobra.test
#  |      >>> model = cobra.test.create_test_model('textbook')
#  |      >>> model.reactions.query(lambda x: x.boundary)
#  |      >>> import re
#  |      >>> regex = re.compile('^g', flags=re.IGNORECASE)
#  |      >>> model.metabolites.query(regex, attribute='name')
#  |
#  |  remove(self, x)
#  |      .. warning :: Internal use only
#  |
#  |  reverse(self)
#  |      reverse *IN PLACE*
#  |
#  |  sort(self, cmp=None, key=None, reverse=False)
#  |      stable sort *IN PLACE*
#  |
#  |      cmp(x, y) -> -1, 0, 1
#  |
#  |  union(self, iterable)
#  |      adds elements with id's not already in the model
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.list:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from builtins.list:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from builtins.list:
#  |
#  |  __hash__ = None

# %% [markdown]
# The reaction objects in the dictionary can be shown as follows

# %%
import cobra.test
import pandas as pd
model = cobra.test.create_test_model("textbook")
reaction_ids = [r.id for r in model.reactions]
reactionList = {'Reaction Name': reaction_ids,
               }
df = pd.DataFrame(reactionList, columns= ['Reaction Name'])
print (df)
# Out:
#          Reaction Name
# 0                ACALD
# 1               ACALDt
# 2                 ACKr
# 3               ACONTa
# 4               ACONTb
# 5                ACt2r
# 6                 ADK1
# 7                AKGDH
# 8               AKGt2r
# 9               ALCD2x
# 10                ATPM
# 11              ATPS4r
# 12  Biomass_Ecoli_core
# 13                CO2t
# 14                  CS
# 15               CYTBD
# 16             D_LACt2
# 17                 ENO
# 18             ETOHt2r
# 19             EX_ac_e
# 20          EX_acald_e
# 21            EX_akg_e
# 22            EX_co2_e
# 23           EX_etoh_e
# 24            EX_for_e
# 25            EX_fru_e
# 26            EX_fum_e
# 27         EX_glc__D_e
# 28         EX_gln__L_e
# 29         EX_glu__L_e
# 30              EX_h_e
# 31            EX_h2o_e
# 32         EX_lac__D_e
# 33         EX_mal__L_e
# 34            EX_nh4_e
# 35             EX_o2_e
# 36             EX_pi_e
# 37            EX_pyr_e
# 38           EX_succ_e
# 39                 FBA
# 40                 FBP
# 41               FORt2
# 42               FORti
# 43                FRD7
# 44             FRUpts2
# 45                 FUM
# 46             FUMt2_2
# 47             G6PDH2r
# 48                GAPD
# 49              GLCpts
# 50                GLNS
# 51              GLNabc
# 52               GLUDy
# 53                GLUN
# 54               GLUSy
# 55              GLUt2r
# 56                 GND
# 57                H2Ot
# 58              ICDHyr
# 59                 ICL
# 60               LDH_D
# 61                MALS
# 62             MALt2_2
# 63                 MDH
# 64                 ME1
# 65                 ME2
# 66              NADH16
# 67             NADTRHD
# 68                NH4t
# 69                 O2t
# 70                 PDH
# 71                 PFK
# 72                 PFL
# 73                 PGI
# 74                 PGK
# 75                 PGL
# 76                 PGM
# 77               PIt2r
# 78                 PPC
# 79                PPCK
# 80                 PPS
# 81                PTAr
# 82                 PYK
# 83               PYRt2
# 84                 RPE
# 85                 RPI
# 86            SUCCt2_2
# 87              SUCCt3
# 88               SUCDi
# 89              SUCOAS
# 90                TALA
# 91                THD2
# 92                TKT1
# 93                TKT2
# 94                 TPI

# %% [markdown]
# ### Metabolite Attributes

# %%
help(model.metabolites)
# Out:
# Help on DictList in module cobra.core.dictlist object:
#
# class DictList(builtins.list)
#  |  DictList(*args)
#  |
#  |  A combined dict and list
#  |
#  |  This object behaves like a list, but has the O(1) speed
#  |  benefits of a dict when looking up elements by their id.
#  |
#  |  Method resolution order:
#  |      DictList
#  |      builtins.list
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |      x.__add__(y) <==> x + y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's which do not intersect
#  |          with self
#  |
#  |  __contains__(self, object)
#  |      DictList.__contains__(object) <==> object in DictList
#  |
#  |      object: str or :class:`~cobra.core.Object.Object`
#  |
#  |  __copy__(self)
#  |
#  |  __delitem__(self, index)
#  |      Delete self[key].
#  |
#  |  __delslice__(self, i, j)
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __getattr__(self, attr)
#  |
#  |  __getitem__(self, i)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(self, i, j)
#  |
#  |  __getstate__(self)
#  |      gets internal state
#  |
#  |      This is only provided for backwards compatibility so older
#  |      versions of cobrapy can load pickles generated with cobrapy. In
#  |      reality, the "_dict" state is ignored when loading a pickle
#  |
#  |  __iadd__(self, other)
#  |      x.__iadd__(y) <==> x += y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's whcih do not intersect
#  |          with self
#  |
#  |  __init__(self, *args)
#  |      Instantiate a combined dict and list.
#  |
#  |      Parameters
#  |      ----------
#  |      args : iterable
#  |          iterable as single argument to create new DictList from
#  |
#  |  __isub__(self, other)
#  |      x.__sub__(y) <==> x -= y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's present in the list
#  |
#  |  __reduce__(self)
#  |      Helper for pickle.
#  |
#  |  __setitem__(self, i, y)
#  |      Set self[key] to value.
#  |
#  |  __setslice__(self, i, j, y)
#  |
#  |  __setstate__(self, state)
#  |      sets internal state
#  |
#  |      Ignore the passed in state and recalculate it. This is only for
#  |      compatibility with older pickles which did not correctly specify
#  |      the initialization class
#  |
#  |  __sub__(self, other)
#  |      x.__sub__(y) <==> x - y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's present in the list
#  |
#  |  add(self, x)
#  |      Opposite of `remove`. Mirrors set.add
#  |
#  |  append(self, object)
#  |      append object to end
#  |
#  |  extend(self, iterable)
#  |      extend list by appending elements from the iterable
#  |
#  |  get_by_any(self, iterable)
#  |      Get a list of members using several different ways of indexing
#  |
#  |      Parameters
#  |      ----------
#  |      iterable : list (if not, turned into single element list)
#  |          list where each element is either int (referring to an index in
#  |          in this DictList), string (a id of a member in this DictList) or
#  |          member of this DictList for pass-through
#  |
#  |      Returns
#  |      -------
#  |      list
#  |          a list of members
#  |
#  |  get_by_id(self, id)
#  |      return the element with a matching id
#  |
#  |  has_id(self, id)
#  |
#  |  index(self, id, *args)
#  |      Determine the position in the list
#  |
#  |      id: A string or a :class:`~cobra.core.Object.Object`
#  |
#  |  insert(self, index, object)
#  |      insert object before index
#  |
#  |  list_attr(self, attribute)
#  |      return a list of the given attribute for every object
#  |
#  |  pop(self, *args)
#  |      remove and return item at index (default last).
#  |
#  |  query(self, search_function, attribute=None)
#  |      Query the list
#  |
#  |      Parameters
#  |      ----------
#  |      search_function : a string, regular expression or function
#  |          Used to find the matching elements in the list.
#  |          - a regular expression (possibly compiled), in which case the
#  |          given attribute of the object should match the regular expression.
#  |          - a function which takes one argument and returns True for
#  |          desired values
#  |
#  |      attribute : string or None
#  |          the name attribute of the object to passed as argument to the
#  |          `search_function`. If this is None, the object itself is used.
#  |
#  |      Returns
#  |      -------
#  |      DictList
#  |          a new list of objects which match the query
#  |
#  |      Examples
#  |      --------
#  |      >>> import cobra.test
#  |      >>> model = cobra.test.create_test_model('textbook')
#  |      >>> model.reactions.query(lambda x: x.boundary)
#  |      >>> import re
#  |      >>> regex = re.compile('^g', flags=re.IGNORECASE)
#  |      >>> model.metabolites.query(regex, attribute='name')
#  |
#  |  remove(self, x)
#  |      .. warning :: Internal use only
#  |
#  |  reverse(self)
#  |      reverse *IN PLACE*
#  |
#  |  sort(self, cmp=None, key=None, reverse=False)
#  |      stable sort *IN PLACE*
#  |
#  |      cmp(x, y) -> -1, 0, 1
#  |
#  |  union(self, iterable)
#  |      adds elements with id's not already in the model
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.list:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from builtins.list:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from builtins.list:
#  |
#  |  __hash__ = None

# %% [markdown]
# The metabolite objects in the dictionary can be shown as follows

# %%
import cobra.test
import pandas as pd
model = cobra.test.create_test_model("textbook")
metabolite_ids = [m.id for m in model.metabolites]
metaboliteList = {'Metabolite Name': metabolite_ids,
               }
df = pd.DataFrame(metaboliteList, columns= ['Metabolite Name'])
print (df)
# Out:
#    Metabolite Name
# 0          13dpg_c
# 1            2pg_c
# 2            3pg_c
# 3           6pgc_c
# 4           6pgl_c
# 5             ac_c
# 6             ac_e
# 7          acald_c
# 8          acald_e
# 9          accoa_c
# 10        acon_C_c
# 11          actp_c
# 12           adp_c
# 13           akg_c
# 14           akg_e
# 15           amp_c
# 16           atp_c
# 17           cit_c
# 18           co2_c
# 19           co2_e
# 20           coa_c
# 21          dhap_c
# 22           e4p_c
# 23          etoh_c
# 24          etoh_e
# 25           f6p_c
# 26           fdp_c
# 27           for_c
# 28           for_e
# 29           fru_e
# 30           fum_c
# 31           fum_e
# 32           g3p_c
# 33           g6p_c
# 34        glc__D_e
# 35        gln__L_c
# 36        gln__L_e
# 37        glu__L_c
# 38        glu__L_e
# 39           glx_c
# 40           h2o_c
# 41           h2o_e
# 42             h_c
# 43             h_e
# 44          icit_c
# 45        lac__D_c
# 46        lac__D_e
# 47        mal__L_c
# 48        mal__L_e
# 49           nad_c
# 50          nadh_c
# 51          nadp_c
# 52         nadph_c
# 53           nh4_c
# 54           nh4_e
# 55            o2_c
# 56            o2_e
# 57           oaa_c
# 58           pep_c
# 59            pi_c
# 60            pi_e
# 61           pyr_c
# 62           pyr_e
# 63            q8_c
# 64          q8h2_c
# 65           r5p_c
# 66       ru5p__D_c
# 67           s7p_c
# 68          succ_c
# 69          succ_e
# 70        succoa_c
# 71       xu5p__D_c

# %% [markdown]
# ### Gene Attributes

# %%
help(model.genes)
# Out:
# Help on DictList in module cobra.core.dictlist object:
#
# class DictList(builtins.list)
#  |  DictList(*args)
#  |
#  |  A combined dict and list
#  |
#  |  This object behaves like a list, but has the O(1) speed
#  |  benefits of a dict when looking up elements by their id.
#  |
#  |  Method resolution order:
#  |      DictList
#  |      builtins.list
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |      x.__add__(y) <==> x + y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's which do not intersect
#  |          with self
#  |
#  |  __contains__(self, object)
#  |      DictList.__contains__(object) <==> object in DictList
#  |
#  |      object: str or :class:`~cobra.core.Object.Object`
#  |
#  |  __copy__(self)
#  |
#  |  __delitem__(self, index)
#  |      Delete self[key].
#  |
#  |  __delslice__(self, i, j)
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __getattr__(self, attr)
#  |
#  |  __getitem__(self, i)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(self, i, j)
#  |
#  |  __getstate__(self)
#  |      gets internal state
#  |
#  |      This is only provided for backwards compatibility so older
#  |      versions of cobrapy can load pickles generated with cobrapy. In
#  |      reality, the "_dict" state is ignored when loading a pickle
#  |
#  |  __iadd__(self, other)
#  |      x.__iadd__(y) <==> x += y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's whcih do not intersect
#  |          with self
#  |
#  |  __init__(self, *args)
#  |      Instantiate a combined dict and list.
#  |
#  |      Parameters
#  |      ----------
#  |      args : iterable
#  |          iterable as single argument to create new DictList from
#  |
#  |  __isub__(self, other)
#  |      x.__sub__(y) <==> x -= y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's present in the list
#  |
#  |  __reduce__(self)
#  |      Helper for pickle.
#  |
#  |  __setitem__(self, i, y)
#  |      Set self[key] to value.
#  |
#  |  __setslice__(self, i, j, y)
#  |
#  |  __setstate__(self, state)
#  |      sets internal state
#  |
#  |      Ignore the passed in state and recalculate it. This is only for
#  |      compatibility with older pickles which did not correctly specify
#  |      the initialization class
#  |
#  |  __sub__(self, other)
#  |      x.__sub__(y) <==> x - y
#  |
#  |      Parameters
#  |      ----------
#  |      other : iterable
#  |          other must contain only unique id's present in the list
#  |
#  |  add(self, x)
#  |      Opposite of `remove`. Mirrors set.add
#  |
#  |  append(self, object)
#  |      append object to end
#  |
#  |  extend(self, iterable)
#  |      extend list by appending elements from the iterable
#  |
#  |  get_by_any(self, iterable)
#  |      Get a list of members using several different ways of indexing
#  |
#  |      Parameters
#  |      ----------
#  |      iterable : list (if not, turned into single element list)
#  |          list where each element is either int (referring to an index in
#  |          in this DictList), string (a id of a member in this DictList) or
#  |          member of this DictList for pass-through
#  |
#  |      Returns
#  |      -------
#  |      list
#  |          a list of members
#  |
#  |  get_by_id(self, id)
#  |      return the element with a matching id
#  |
#  |  has_id(self, id)
#  |
#  |  index(self, id, *args)
#  |      Determine the position in the list
#  |
#  |      id: A string or a :class:`~cobra.core.Object.Object`
#  |
#  |  insert(self, index, object)
#  |      insert object before index
#  |
#  |  list_attr(self, attribute)
#  |      return a list of the given attribute for every object
#  |
#  |  pop(self, *args)
#  |      remove and return item at index (default last).
#  |
#  |  query(self, search_function, attribute=None)
#  |      Query the list
#  |
#  |      Parameters
#  |      ----------
#  |      search_function : a string, regular expression or function
#  |          Used to find the matching elements in the list.
#  |          - a regular expression (possibly compiled), in which case the
#  |          given attribute of the object should match the regular expression.
#  |          - a function which takes one argument and returns True for
#  |          desired values
#  |
#  |      attribute : string or None
#  |          the name attribute of the object to passed as argument to the
#  |          `search_function`. If this is None, the object itself is used.
#  |
#  |      Returns
#  |      -------
#  |      DictList
#  |          a new list of objects which match the query
#  |
#  |      Examples
#  |      --------
#  |      >>> import cobra.test
#  |      >>> model = cobra.test.create_test_model('textbook')
#  |      >>> model.reactions.query(lambda x: x.boundary)
#  |      >>> import re
#  |      >>> regex = re.compile('^g', flags=re.IGNORECASE)
#  |      >>> model.metabolites.query(regex, attribute='name')
#  |
#  |  remove(self, x)
#  |      .. warning :: Internal use only
#  |
#  |  reverse(self)
#  |      reverse *IN PLACE*
#  |
#  |  sort(self, cmp=None, key=None, reverse=False)
#  |      stable sort *IN PLACE*
#  |
#  |      cmp(x, y) -> -1, 0, 1
#  |
#  |  union(self, iterable)
#  |      adds elements with id's not already in the model
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.list:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from builtins.list:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from builtins.list:
#  |
#  |  __hash__ = None

# %% [markdown]
# The gene objects in the dictionary can be shown as follows

# %%
import cobra.test
import pandas as pd
model = cobra.test.create_test_model("textbook")
gene_ids = [g.id for g in model.genes]
geneList = {'Gene Name': gene_ids,
               }
df = pd.DataFrame(geneList, columns= ['Gene Name'])
print (df)
# Out:
#     Gene Name
# 0       b1241
# 1       b0351
# 2       s0001
# 3       b3115
# 4       b1849
# 5       b2296
# 6       b1276
# 7       b0118
# 8       b0474
# 9       b0116
# 10      b0726
# 11      b0727
# 12      b2587
# 13      b0356
# 14      b1478
# 15      b3735
# 16      b3733
# 17      b3734
# 18      b3732
# 19      b3736
# 20      b3738
# 21      b3731
# 22      b3737
# 23      b3739
# 24      b0720
# 25      b0733
# 26      b0979
# 27      b0978
# 28      b0734
# 29      b2975
# 30      b3603
# 31      b2779
# 32      b1773
# 33      b2925
# 34      b2097
# 35      b4232
# 36      b3925
# 37      b0904
# 38      b2492
# 39      b4154
# 40      b4152
# 41      b4153
# 42      b4151
# 43      b1819
# 44      b1817
# 45      b2415
# 46      b1818
# 47      b2416
# 48      b1611
# 49      b4122
# 50      b1612
# 51      b3528
# 52      b1852
# 53      b1779
# 54      b1621
# 55      b1101
# 56      b2417
# 57      b3870
# 58      b1297
# 59      b0809
# 60      b0810
# 61      b0811
# 62      b1761
# 63      b1524
# 64      b1812
# 65      b0485
# 66      b3213
# 67      b3212
# 68      b4077
# 69      b2029
# 70      b0875
# 71      b1136
# 72      b4015
# 73      b2133
# 74      b1380
# 75      b4014
# 76      b2976
# 77      b3236
# 78      b1479
# 79      b2463
# 80      b2286
# 81      b2279
# 82      b2276
# 83      b2280
# 84      b2288
# 85      b2284
# 86      b2287
# 87      b2281
# 88      b2277
# 89      b2285
# 90      b2282
# 91      b2278
# 92      b2283
# 93      b3962
# 94      b1602
# 95      b1603
# 96      b0451
# 97      b0114
# 98      b0115
# 99      b3916
# 100     b1723
# 101     b0902
# 102     b0903
# 103     b2579
# 104     b3114
# 105     b3952
# 106     b3951
# 107     b4025
# 108     b2926
# 109     b0767
# 110     b0755
# 111     b3612
# 112     b4395
# 113     b3493
# 114     b2987
# 115     b3956
# 116     b3403
# 117     b1702
# 118     b2297
# 119     b2458
# 120     b1676
# 121     b1854
# 122     b4301
# 123     b3386
# 124     b2914
# 125     b4090
# 126     b0722
# 127     b0724
# 128     b0721
# 129     b0723
# 130     b0728
# 131     b0729
# 132     b2464
# 133     b0008
# 134     b2935
# 135     b2465
# 136     b3919

# %% [markdown]
# ### General Model Information

# %% [markdown]
# The compartments included in the model

# %%
model.compartments
# Out:
# {'c': 'cytosol', 'e': 'extracellular'}

# %% [markdown]
# The lower limits of exchange reactions that allow access from the extracellular space (These lower limits are normally represented as negative numbers)

# %%
model.medium
# Out:
# {'EX_co2_e': 1000.0,
#  'EX_glc__D_e': 10.0,
#  'EX_h_e': 1000.0,
#  'EX_h2o_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0}

# %% [markdown]
# Print the active objective function

# %%
print(model.objective)
# Out:
# Maximize
# 1.0*Biomass_Ecoli_core - 1.0*Biomass_Ecoli_core_reverse_2cdba

# %% [markdown]
# Listing model sink reactions

# %%
model.sinks
# Out:
# []

# %% [markdown]
# Listing model demand reactions

# %%
model.demands
# Out:
# []

# %% [markdown]
# Listing model demand reactions

# %%
model.exchanges
# Out:
# [<Reaction EX_ac_e at 0x207778adb80>,
#  <Reaction EX_acald_e at 0x207778adca0>,
#  <Reaction EX_akg_e at 0x20775f0dee0>,
#  <Reaction EX_co2_e at 0x20775f0dac0>,
#  <Reaction EX_etoh_e at 0x20775f0df40>,
#  <Reaction EX_for_e at 0x207778adbe0>,
#  <Reaction EX_fru_e at 0x207778adbb0>,
#  <Reaction EX_fum_e at 0x20775f0df10>,
#  <Reaction EX_glc__D_e at 0x20775f0de20>,
#  <Reaction EX_gln__L_e at 0x20775f153d0>,
#  <Reaction EX_glu__L_e at 0x20775f155b0>,
#  <Reaction EX_h_e at 0x20775f152b0>,
#  <Reaction EX_h2o_e at 0x20775f15700>,
#  <Reaction EX_lac__D_e at 0x20775f157c0>,
#  <Reaction EX_mal__L_e at 0x20775f15880>,
#  <Reaction EX_nh4_e at 0x20775f15940>,
#  <Reaction EX_o2_e at 0x20775f15a00>,
#  <Reaction EX_pi_e at 0x20775f15ac0>,
#  <Reaction EX_pyr_e at 0x20775f15b80>,
#  <Reaction EX_succ_e at 0x20775f15c40>]

# %% [markdown]
# Listing the boundary reactions

# %%
model.boundary
# Out:
# [<Reaction EX_ac_e at 0x207778adb80>,
#  <Reaction EX_acald_e at 0x207778adca0>,
#  <Reaction EX_akg_e at 0x20775f0dee0>,
#  <Reaction EX_co2_e at 0x20775f0dac0>,
#  <Reaction EX_etoh_e at 0x20775f0df40>,
#  <Reaction EX_for_e at 0x207778adbe0>,
#  <Reaction EX_fru_e at 0x207778adbb0>,
#  <Reaction EX_fum_e at 0x20775f0df10>,
#  <Reaction EX_glc__D_e at 0x20775f0de20>,
#  <Reaction EX_gln__L_e at 0x20775f153d0>,
#  <Reaction EX_glu__L_e at 0x20775f155b0>,
#  <Reaction EX_h_e at 0x20775f152b0>,
#  <Reaction EX_h2o_e at 0x20775f15700>,
#  <Reaction EX_lac__D_e at 0x20775f157c0>,
#  <Reaction EX_mal__L_e at 0x20775f15880>,
#  <Reaction EX_nh4_e at 0x20775f15940>,
#  <Reaction EX_o2_e at 0x20775f15a00>,
#  <Reaction EX_pi_e at 0x20775f15ac0>,
#  <Reaction EX_pyr_e at 0x20775f15b80>,
#  <Reaction EX_succ_e at 0x20775f15c40>]

# %% [markdown]
# ## Copying Models
#
# Since models are classes they are considered mutable so if you try copying a model like "model_new = model" you have just assigned the location of the existing model to the new model so any changes that are made to the new model will also be included in the old model. To copy a model it is best to use the copy method as follows.

# %%
new_model = model.copy()
new_model
# Out:
# Read LP format model from file C:\Users\hinton\AppData\Local\Temp\tmpctdze8pq.lp
# Reading time = 0.01 seconds
# : 72 rows, 190 columns, 720 nonzeros
# <Model e_coli_core at 0x20770f4e5e0>

# %% [markdown]
# ## Searching the model
# One can use .query('search term', 'attribute_to_search_in') to search in model metabolites, reactions, and genes. For example, one can search the reactions that contain the term glucose in their name.

# %%
for reaction in model.reactions.query('glucose', 'name'):
    print(reaction.name)
# Out:
# glucose 6-phosphate dehydrogenase
# D-glucose transport via PEP:Pyr PTS
# glucose-6-phosphate isomerase

# %% [markdown]
# ## Model Solution

# %% [markdown]
# The model solution from optimizing the model.

# %%
model = cobra.test.create_test_model("textbook")
solution = model.optimize()
solution
# Out:
# <Solution 0.874 at 0x2077577af10>

# %% [markdown]
# # Model Visualization
# A simple way to visualize a model is to use the Escher (https://escher.github.io/#/) tools. The Escher website discusses how to load different COBRA models and their maps. An example of the *E.coli* core model map is shown below

# %%
import escher
from escher import Builder

builder = Builder(
    map_name='e_coli_core.Core metabolism',
    model_name='e_coli_core',
)
builder
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/e_coli_core.Core%20metabolism.json
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/e_coli_core.json
# Builder()

# %% [markdown]
# ## References
# 1. Ebrahim, A., Lerman, J.A., Palsson, B.O. et al. COBRApy: COnstraints-Based Reconstruction and Analysis for Python. BMC Syst Biol 7, 74 (2013). https://doi.org/10.1186/1752-0509-7-74
# 2. https://cobrapy.readthedocs.io/en/latest/index.html
