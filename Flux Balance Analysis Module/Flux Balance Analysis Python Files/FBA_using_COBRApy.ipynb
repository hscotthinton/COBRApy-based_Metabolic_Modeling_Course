# %% [markdown]
# # Flux Balance Analysis using COBRApy
#
# Simulations using flux balance analysis can be solved using COBRApy model.optimize() command. This module will maximize or minimize (maximizing is the default) flux based on the objective reactions.
#
# To start with, import the *E.coli* core model from the BIGG database.

# %%
import cobra.test
from cobrapy_bigg_client import client
model = client.download_model('e_coli_core', save=False) # Load model from BIGG database
model.solver = 'glpk'
# Out:
# Academic license - for non-commercial use only - expires 2022-12-07
# Using license file C:\Users\scott\gurobi.lic

# %% [markdown]
# ## Running a FBA simulation
#
# Place the results of the simulation in an object called "solution" and then print the result of the simulation which is the numerical value of the objective function which in the case corresponds to the growth rate

# %%
solution = model.optimize()
print(solution)
# Out:
# <Solution 0.874 at 0x129468075e0>

# %% [markdown]
# The **model.optimize()** function will return a Solution object. A solution object has several attributes:
#
# - objective_value: the objective value
# - status: the status from the linear programming solver
# - fluxes: a pandas series with flux indexed by reaction identifier. The flux for a reaction variable is the difference of the primal values for the forward and reverse reaction variables.
# - shadow_prices: a pandas series with shadow price indexed by the metabolite identifier.
#
# For example, after the last call to model.optimize(), if the optimization succeeds it's status will be optimal. In case the model is infeasible an error is raised.

# %% [markdown]
# The objective value can also be found through either

# %%
solution.objective_value
# Out:
# 0.8739215069684303

# %% [markdown]
# or

# %%
model.optimize().objective_value
# Out:
# 0.8739215069684303

# %% [markdown]
# The solvers that can be used with COBRApy are so fast that for many small to mid-size models computing the solution can be even faster than it takes to collect the values from the solver and convert to them python objects. With model.optimize, COBRApy gathers values for all reactions and metabolites and that can take a significant amount of time if done repeatedly. If only the flux value of a single reaction or the objective, it is faster to use **model.slim_optimize()** which only does the optimization and returns the objective value leaving it up to you to fetch other values that you may need.
#
# This can be seen below in the following examples

# %%
# %%time
model.optimize().objective_value
# Out:
# Wall time: 2.01 ms
# 0.8739215069684303

# %%
# %%time
model.slim_optimize()
# Out:
# Wall time: 0 ns
# 0.8739215069684303

# %% [markdown]
# ## Analyzing FBA solutions
# Models solved using FBA can be further analyzed by using summary methods, which produce printed text that gives a quick representation of optimized model behavior. Calling the summary method on the entire model produces information on the input and output behavior of the model, along with the optimized objective.

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.8739215069684297</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-22.81</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-29.18</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-17.53</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As can be seen, this summary produces the optimized objective plus all the flux values of all the exchange reactions that are actively uptaking flux into the cell as well as the flux values of the exhange reactions that are secreting flux into the  extracellular space.

# %% [markdown]
# ### Individual Reaction Flux Values
#
# The flux though a given reaction can be determined as follows.

# %%
model.reactions.PYK.flux # This does not work with the Gurobi solver
# Out:
# 1.7581774441067866

# %% [markdown]
# or

# %%
solution.fluxes.PYK
# Out:
# 1.7581774441068045

# %% [markdown]
# The reduced cost of a given reaction is given by

# %%
from cobra import Solution
model.reactions.PYK.reduced_cost # This does not work with the gurobi solver
# Out:
# -1.9999999999999991

# %% [markdown]
# Printing all the flux values

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
solution.fluxes
# Out:
# PFK                          7.477382
# PFL                          0.000000
# PGI                          4.860861
# PGK                        -16.023526
# PGL                          4.959985
# ACALD                        0.000000
# AKGt2r                       0.000000
# PGM                        -14.716140
# PIt2r                        3.214895
# ALCD2x                       0.000000
# ACALDt                       0.000000
# ACKr                         0.000000
# PPC                          2.504309
# ACONTa                       6.007250
# ACONTb                       6.007250
# ATPM                         8.390000
# PPCK                         0.000000
# ACt2r                        0.000000
# PPS                          0.000000
# ADK1                         0.000000
# AKGDH                        5.064376
# ATPS4r                      45.514010
# PTAr                         0.000000
# PYK                          1.758177
# BIOMASS_Ecoli_core_w_GAM     0.873922
# PYRt2                        0.000000
# CO2t                       -22.809833
# RPE                          2.678482
# CS                           6.007250
# RPI                         -2.281503
# SUCCt2_2                     0.000000
# CYTBD                       43.598985
# D_LACt2                      0.000000
# ENO                         14.716140
# SUCCt3                       0.000000
# ETOHt2r                      0.000000
# SUCDi                        5.064376
# SUCOAS                      -5.064376
# TALA                         1.496984
# THD2                         0.000000
# TKT1                         1.496984
# TKT2                         1.181498
# TPI                          7.477382
# EX_ac_e                      0.000000
# EX_acald_e                   0.000000
# EX_akg_e                     0.000000
# EX_co2_e                    22.809833
# EX_etoh_e                    0.000000
# EX_for_e                     0.000000
# EX_fru_e                     0.000000
# EX_fum_e                     0.000000
# EX_glc__D_e                -10.000000
# EX_gln__L_e                  0.000000
# EX_glu__L_e                  0.000000
# EX_h_e                      17.530865
# EX_h2o_e                    29.175827
# EX_lac__D_e                  0.000000
# EX_mal__L_e                  0.000000
# EX_nh4_e                    -4.765319
# EX_o2_e                    -21.799493
# EX_pi_e                     -3.214895
# EX_pyr_e                     0.000000
# EX_succ_e                    0.000000
# FBA                          7.477382
# FBP                          0.000000
# FORt2                        0.000000
# FORt                         0.000000
# FRD7                         0.000000
# FRUpts2                      0.000000
# FUM                          5.064376
# FUMt2_2                      0.000000
# G6PDH2r                      4.959985
# GAPD                        16.023526
# GLCpts                      10.000000
# GLNS                         0.223462
# GLNabc                       0.000000
# GLUDy                       -4.541857
# GLUN                         0.000000
# GLUSy                        0.000000
# GLUt2r                       0.000000
# GND                          4.959985
# H2Ot                       -29.175827
# ICDHyr                       6.007250
# ICL                          0.000000
# LDH_D                        0.000000
# MALS                         0.000000
# MALt2_2                      0.000000
# MDH                          5.064376
# ME1                          0.000000
# ME2                          0.000000
# NADH16                      38.534610
# NADTRHD                      0.000000
# NH4t                         4.765319
# O2t                         21.799493
# PDH                          9.282533
# Name: fluxes, dtype: float64

# %% [markdown]
# Printing all the reduced costs

# %%
solution.reduced_costs
# Out:
# PFK                        -1.257675e-17
# PFL                         2.081668e-17
# PGI                         0.000000e+00
# PGK                         6.938894e-18
# PGL                         1.528725e-17
# ACALD                      -1.431147e-17
# AKGt2r                      8.673617e-18
# PGM                        -0.000000e+00
# PIt2r                      -7.806256e-18
# ALCD2x                     -2.125036e-17
# ACALDt                      0.000000e+00
# ACKr                        0.000000e+00
# PPC                         2.222614e-17
# ACONTa                      1.376937e-17
# ACONTb                      1.084202e-19
# ATPM                       -1.018497e-02
# PPCK                       -1.018497e-02
# ACt2r                      -1.734723e-18
# PPS                        -1.018497e-02
# ADK1                       -0.000000e+00
# AKGDH                      -1.734723e-18
# ATPS4r                      1.192622e-18
# PTAr                        1.647987e-17
# PYK                         5.637851e-18
# BIOMASS_Ecoli_core_w_GAM    4.857226e-17
# PYRt2                       1.561251e-17
# CO2t                       -0.000000e+00
# RPE                        -4.996004e-16
# CS                          1.409463e-18
# RPI                        -0.000000e+00
# SUCCt2_2                    2.428613e-17
# CYTBD                      -1.409463e-18
# D_LACt2                     1.734723e-18
# ENO                        -1.084202e-19
# SUCCt3                     -7.638729e-03
# ETOHt2r                     1.734723e-18
# SUCDi                      -2.168404e-18
# SUCOAS                     -2.602085e-18
# TALA                        2.220446e-16
# THD2                       -2.546243e-03
# TKT1                        8.049117e-16
# TKT2                       -6.106227e-16
# TPI                         0.000000e+00
# EX_ac_e                    -4.583237e-02
# EX_acald_e                 -6.874856e-02
# EX_akg_e                   -1.222197e-01
# EX_co2_e                    0.000000e+00
# EX_etoh_e                  -7.893353e-02
# EX_for_e                   -1.527746e-02
# EX_fru_e                   -1.833295e-01
# EX_fum_e                   -9.166475e-02
# EX_glc__D_e                -1.833295e-01
# EX_gln__L_e                -1.400434e-01
# EX_glu__L_e                -1.374971e-01
# EX_h_e                      4.336809e-19
# EX_h2o_e                    1.084202e-19
# EX_lac__D_e                -8.147977e-02
# EX_mal__L_e                -9.166475e-02
# EX_nh4_e                   -1.387779e-17
# EX_o2_e                     0.000000e+00
# EX_pi_e                    -4.163336e-17
# EX_pyr_e                   -6.874856e-02
# EX_succ_e                  -9.675723e-02
# FBA                         0.000000e+00
# FBP                        -1.018497e-02
# FORt2                      -2.546243e-03
# FORt                       -0.000000e+00
# FRD7                        4.336809e-18
# FRUpts2                     6.938894e-18
# FUM                         1.084202e-19
# FUMt2_2                     3.122502e-17
# G6PDH2r                     9.844556e-17
# GAPD                       -4.336809e-19
# GLCpts                      0.000000e+00
# GLNS                       -2.914335e-16
# GLNabc                     -6.938894e-17
# GLUDy                       4.163336e-17
# GLUN                       -1.018497e-02
# GLUSy                      -1.018497e-02
# GLUt2r                     -2.775558e-17
# GND                         9.714451e-17
# H2Ot                       -0.000000e+00
# ICDHyr                      2.775558e-17
# ICL                        -2.546243e-03
# LDH_D                      -1.951564e-17
# MALS                       -1.387779e-17
# MALt2_2                     3.122502e-17
# MDH                        -1.257675e-17
# ME1                        -1.018497e-02
# ME2                        -7.638729e-03
# NADH16                      0.000000e+00
# NADTRHD                    -2.546243e-03
# NH4t                       -1.387779e-17
# O2t                         0.000000e+00
# PDH                        -1.561251e-17
# Name: reduced_costs, dtype: float64

# %% [markdown]
# Creating a table that includes the reaction IDs, reaction names, reaction flux, and reduced costs.

# %%
import pandas as pd
reaction_names = [r.name for r in model.reactions]
reaction_ids = [r.id for r in model.reactions]
reaction_flux = [r.flux for r in model.reactions]
reaction_RC = [r.reduced_cost for r in model.reactions]
reactionList = {'Reaction ID': reaction_ids,
                'Reaction Name': reaction_names,
                'Reaction Flux': reaction_flux,
                'Reaction Reduced Cost': reaction_RC,
               }

df = pd.DataFrame(reactionList, columns= ['Reaction ID','Reaction Name','Reaction Flux','Reaction Reduced Cost'])
pd.set_option('display.max_rows', 500)
df
# Out:
#                  Reaction ID  \
# 0                        PFK
# 1                        PFL
# 2                        PGI
# 3                        PGK
# 4                        PGL
# 5                      ACALD
# 6                     AKGt2r
# 7                        PGM
# 8                      PIt2r
# 9                     ALCD2x
# 10                    ACALDt
# 11                      ACKr
# 12                       PPC
# 13                    ACONTa
# 14                    ACONTb
# 15                      ATPM
# 16                      PPCK
# 17                     ACt2r
# 18                       PPS
# 19                      ADK1
# 20                     AKGDH
# 21                    ATPS4r
# 22                      PTAr
# 23                       PYK
# 24  BIOMASS_Ecoli_core_w_GAM
# 25                     PYRt2
# 26                      CO2t
# 27                       RPE
# 28                        CS
# 29                       RPI
# 30                  SUCCt2_2
# 31                     CYTBD
# 32                   D_LACt2
# 33                       ENO
# 34                    SUCCt3
# 35                   ETOHt2r
# 36                     SUCDi
# 37                    SUCOAS
# 38                      TALA
# 39                      THD2
# 40                      TKT1
# 41                      TKT2
# 42                       TPI
# 43                   EX_ac_e
# 44                EX_acald_e
# 45                  EX_akg_e
# 46                  EX_co2_e
# 47                 EX_etoh_e
# 48                  EX_for_e
# 49                  EX_fru_e
# 50                  EX_fum_e
# 51               EX_glc__D_e
# 52               EX_gln__L_e
# 53               EX_glu__L_e
# 54                    EX_h_e
# 55                  EX_h2o_e
# 56               EX_lac__D_e
# 57               EX_mal__L_e
# 58                  EX_nh4_e
# 59                   EX_o2_e
# 60                   EX_pi_e
# 61                  EX_pyr_e
# 62                 EX_succ_e
# 63                       FBA
# 64                       FBP
# 65                     FORt2
# 66                      FORt
# 67                      FRD7
# 68                   FRUpts2
# 69                       FUM
# 70                   FUMt2_2
# 71                   G6PDH2r
# 72                      GAPD
# 73                    GLCpts
# 74                      GLNS
# 75                    GLNabc
# 76                     GLUDy
# 77                      GLUN
# 78                     GLUSy
# 79                    GLUt2r
# 80                       GND
# 81                      H2Ot
# 82                    ICDHyr
# 83                       ICL
# 84                     LDH_D
# 85                      MALS
# 86                   MALt2_2
# 87                       MDH
# 88                       ME1
# 89                       ME2
# 90                    NADH16
# 91                   NADTRHD
# 92                      NH4t
# 93                       O2t
# 94                       PDH
#
#                                         Reaction Name  Reaction Flux  \
# 0                                 Phosphofructokinase   7.477382e+00
# 1                              Pyruvate formate lyase   0.000000e+00
# 2                       Glucose-6-phosphate isomerase   4.860861e+00
# 3                             Phosphoglycerate kinase  -1.602353e+01
# 4                           6-phosphogluconolactonase   4.959985e+00
# 5            Acetaldehyde dehydrogenase (acetylating)   0.000000e+00
# 6     2 oxoglutarate reversible transport via symport   0.000000e+00
# 7                             Phosphoglycerate mutase  -1.471614e+01
# 8          Phosphate reversible transport via symport   3.214895e+00
# 9                     Alcohol dehydrogenase (ethanol)   0.000000e+00
# 10                  Acetaldehyde reversible transport   0.000000e+00
# 11                                     Acetate kinase  -1.937884e-14
# 12                    Phosphoenolpyruvate carboxylase   2.504309e+00
# 13   Aconitase (half-reaction A, Citrate hydro-lyase)   6.007250e+00
# 14  Aconitase (half-reaction B, Isocitrate hydro-l...   6.007250e+00
# 15                        ATP maintenance requirement   8.390000e+00
# 16                  Phosphoenolpyruvate carboxykinase   0.000000e+00
# 17    Acetate reversible transport via proton symport  -1.937884e-14
# 18                       Phosphoenolpyruvate synthase   0.000000e+00
# 19                                   Adenylate kinase   0.000000e+00
# 20                       2-Oxogluterate dehydrogenase   5.064376e+00
# 21            ATP synthase (four protons for one ATP)   4.551401e+01
# 22                              Phosphotransacetylase   1.937884e-14
# 23                                    Pyruvate kinase   1.758177e+00
# 24                Biomass Objective Function with GAM   8.739215e-01
# 25           Pyruvate transport in via proton symport   0.000000e+00
# 26                      CO2 transporter via diffusion  -2.280983e+01
# 27                   Ribulose 5-phosphate 3-epimerase   2.678482e+00
# 28                                   Citrate synthase   6.007250e+00
# 29                       Ribose-5-phosphate isomerase  -2.281503e+00
# 30       Succinate transport via proton symport (2 H)   0.000000e+00
# 31     Cytochrome oxidase bd (ubiquinol-8: 2 protons)   4.359899e+01
# 32             D lactate transport via proton symport   0.000000e+00
# 33                                            Enolase   1.471614e+01
# 34        Succinate transport out via proton antiport   0.000000e+00
# 35    Ethanol reversible transport via proton symport   0.000000e+00
# 36             Succinate dehydrogenase (irreversible)   5.064376e+00
# 37              Succinyl-CoA synthetase (ADP-forming)  -5.064376e+00
# 38                                      Transaldolase   1.496984e+00
# 39                            NAD(P) transhydrogenase   0.000000e+00
# 40                                      Transketolase   1.496984e+00
# 41                                      Transketolase   1.181498e+00
# 42                         Triose-phosphate isomerase   7.477382e+00
# 43                                   Acetate exchange   1.937884e-14
# 44                              Acetaldehyde exchange   0.000000e+00
# 45                            2-Oxoglutarate exchange   0.000000e+00
# 46                                       CO2 exchange   2.280983e+01
# 47                                   Ethanol exchange   0.000000e+00
# 48                                   Formate exchange   0.000000e+00
# 49                                D-Fructose exchange   0.000000e+00
# 50                                  Fumarate exchange   0.000000e+00
# 51                                 D-Glucose exchange  -1.000000e+01
# 52                               L-Glutamine exchange   0.000000e+00
# 53                               L-Glutamate exchange   0.000000e+00
# 54                                        H+ exchange   1.753087e+01
# 55                                       H2O exchange   2.917583e+01
# 56                                 D-lactate exchange   0.000000e+00
# 57                                  L-Malate exchange   0.000000e+00
# 58                                   Ammonia exchange  -4.765319e+00
# 59                                        O2 exchange  -2.179949e+01
# 60                                 Phosphate exchange  -3.214895e+00
# 61                                  Pyruvate exchange   0.000000e+00
# 62                                 Succinate exchange   0.000000e+00
# 63                     Fructose-bisphosphate aldolase   7.477382e+00
# 64                            Fructose-bisphosphatase   0.000000e+00
# 65            Formate transport in via proton symport   0.000000e+00
# 66                    Formate transport via diffusion   0.000000e+00
# 67                                 Fumarate reductase   0.000000e+00
# 68  Fructose transport via PEP:Pyr PTS (f6p genera...   0.000000e+00
# 69                                           Fumarase   5.064376e+00
# 70        Fumarate transport via proton symport (2 H)   0.000000e+00
# 71                  Glucose 6-phosphate dehydrogenase   4.959985e+00
# 72           Glyceraldehyde-3-phosphate dehydrogenase   1.602353e+01
# 73                D-glucose transport via PEP:Pyr PTS   1.000000e+01
# 74                               Glutamine synthetase   2.234617e-01
# 75               L-glutamine transport via ABC system   0.000000e+00
# 76                     Glutamate dehydrogenase (NADP)  -4.541857e+00
# 77                                        Glutaminase   0.000000e+00
# 78                         Glutamate synthase (NADPH)   0.000000e+00
# 79  L glutamate transport via proton symport  reve...   0.000000e+00
# 80                     Phosphogluconate dehydrogenase   4.959985e+00
# 81                        H2O transport via diffusion  -2.917583e+01
# 82                    Isocitrate dehydrogenase (NADP)   6.007250e+00
# 83                                   Isocitrate lyase   0.000000e+00
# 84                            D-lactate dehydrogenase   0.000000e+00
# 85                                    Malate synthase   0.000000e+00
# 86          Malate transport via proton symport (2 H)   0.000000e+00
# 87                               Malate dehydrogenase   5.064376e+00
# 88                                 Malic enzyme (NAD)   0.000000e+00
# 89                                Malic enzyme (NADP)   0.000000e+00
# 90      NADH dehydrogenase (ubiquinone-8 & 3 protons)   3.853461e+01
# 91                               NAD transhydrogenase   0.000000e+00
# 92                       Ammonia reversible transport   4.765319e+00
# 93                           O2 transport  diffusion    2.179949e+01
# 94                             Pyruvate dehydrogenase   9.282533e+00
#
#     Reaction Reduced Cost
# 0               -2.000000
# 1               -2.000000
# 2               -2.000000
# 3                2.000000
# 4               -2.000000
# 5               -2.000000
# 6               -2.000000
# 7                2.000000
# 8               -2.000000
# 9               -2.000000
# 10              -2.000000
# 11               2.000000
# 12              -2.000000
# 13              -2.000000
# 14              -2.000000
# 15              12.488889
# 16              14.488889
# 17               2.000000
# 18              12.488889
# 19               2.000000
# 20              -2.000000
# 21              -2.000000
# 22              -2.000000
# 23              -2.000000
# 24              -2.000000
# 25              -2.000000
# 26               2.000000
# 27              -2.000000
# 28              -2.000000
# 29               2.000000
# 30              -2.000000
# 31              -2.000000
# 32              -2.000000
# 33              -2.000000
# 34               9.866667
# 35              -2.000000
# 36              -2.000000
# 37               2.000000
# 38              -2.000000
# 39               3.822222
# 40              -2.000000
# 41              -2.000000
# 42              -2.000000
# 43              -2.000000
# 44               5.600000
# 45              26.666667
# 46              -2.000000
# 47               4.088889
# 48               5.733333
# 49              12.400000
# 50              17.200000
# 51              10.400000
# 52              53.822222
# 53              41.200000
# 54              -2.000000
# 55              -2.000000
# 56               4.711111
# 57              15.200000
# 58               2.000000
# 59               2.000000
# 60               2.000000
# 61               3.600000
# 62              12.444444
# 63              -2.000000
# 64              14.488889
# 65               4.622222
# 66               2.000000
# 67               2.000000
# 68              -2.000000
# 69              -2.000000
# 70              -2.000000
# 71              -2.000000
# 72              -2.000000
# 73              -2.000000
# 74              -2.000000
# 75              -2.000000
# 76               2.000000
# 77              14.488889
# 78              12.488889
# 79              -2.000000
# 80              -2.000000
# 81               2.000000
# 82              -2.000000
# 83               1.422222
# 84              -2.000000
# 85              -2.000000
# 86              -2.000000
# 87              -2.000000
# 88              10.488889
# 89               9.066667
# 90              -2.000000
# 91               1.422222
# 92              -2.000000
# 93              -2.000000
# 94              -2.000000

# %% [markdown]
# ### Individual Metabolite Flux Values
#
# In addition, the input-output behavior of individual metabolites can also be inspected using summary methods. For example, the following commands can be used to examine the flux associated with the reactions that are both producing and consuming the given metabolite.

# %%
model.metabolites.nadh_c.summary()
# Out:
# <h3>nadh_c</h3><p>C21H27N7O14P2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>13.14%</td>
#       <td>5.064</td>
#       <td>AKGDH</td>
#       <td>akg_c + coa_c + nad_c --&gt; co2_c + nadh_c + succoa_c</td>
#     </tr>
#     <tr>
#       <td>8.04%</td>
#       <td>3.1</td>
#       <td>BIOMASS_Ecoli_core_w_GAM</td>
#       <td>1.496 3pg_c + 3.7478 accoa_c + 59.81 atp_c + 0.361 e4p_c + 0.0709 f6p_c + 0.129 g3p_c + 0.205 g6p_c + 0.2557 gln__L_c + 4.9414 glu__L_c + 59.81 h2o_c + 3.547 nad_c + 13.0279 nadph_c + 1.7867 oaa_c + 0.5191 pep_c + 2.8328 pyr_c + 0.8977 r5p_c --&gt; 59.81 adp_c + 4.1182 akg_c + 3.7478 coa_c + 59.81 h_c + 3.547 nadh_c + 13.0279 nadp_c + 59.81 pi_c</td>
#     </tr>
#     <tr>
#       <td>41.58%</td>
#       <td>16.02</td>
#       <td>GAPD</td>
#       <td>g3p_c + nad_c + pi_c &lt;=&gt; 13dpg_c + h_c + nadh_c</td>
#     </tr>
#     <tr>
#       <td>13.14%</td>
#       <td>5.064</td>
#       <td>MDH</td>
#       <td>mal__L_c + nad_c &lt;=&gt; h_c + nadh_c + oaa_c</td>
#     </tr>
#     <tr>
#       <td>24.09%</td>
#       <td>9.283</td>
#       <td>PDH</td>
#       <td>coa_c + nad_c + pyr_c --&gt; accoa_c + co2_c + nadh_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-38.53</td>
#       <td>NADH16</td>
#       <td>4.0 h_c + nadh_c + q8_c --&gt; 3.0 h_e + nad_c + q8h2_c</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This will be helpful in determining the main energy production and consumption reactions

# %%
model.metabolites.atp_c.summary()
# Out:
# <h3>atp_c</h3><p>C10H12N5O13P3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>66.58%</td>
#       <td>45.51</td>
#       <td>ATPS4r</td>
#       <td>adp_c + 4.0 h_e + pi_c &lt;=&gt; atp_c + h2o_c + 3.0 h_c</td>
#     </tr>
#     <tr>
#       <td>23.44%</td>
#       <td>16.02</td>
#       <td>PGK</td>
#       <td>3pg_c + atp_c &lt;=&gt; 13dpg_c + adp_c</td>
#     </tr>
#     <tr>
#       <td>2.57%</td>
#       <td>1.758</td>
#       <td>PYK</td>
#       <td>adp_c + h_c + pep_c --&gt; atp_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>7.41%</td>
#       <td>5.064</td>
#       <td>SUCOAS</td>
#       <td>atp_c + coa_c + succ_c &lt;=&gt; adp_c + pi_c + succoa_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>12.27%</td>
#       <td>-8.39</td>
#       <td>ATPM</td>
#       <td>atp_c + h2o_c --&gt; adp_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>76.46%</td>
#       <td>-52.27</td>
#       <td>BIOMASS_Ecoli_core_w_GAM</td>
#       <td>1.496 3pg_c + 3.7478 accoa_c + 59.81 atp_c + 0.361 e4p_c + 0.0709 f6p_c + 0.129 g3p_c + 0.205 g6p_c + 0.2557 gln__L_c + 4.9414 glu__L_c + 59.81 h2o_c + 3.547 nad_c + 13.0279 nadph_c + 1.7867 oaa_c + 0.5191 pep_c + 2.8328 pyr_c + 0.8977 r5p_c --&gt; 59.81 adp_c + 4.1182 akg_c + 3.7478 coa_c + 59.81 h_c + 3.547 nadh_c + 13.0279 nadp_c + 59.81 pi_c</td>
#     </tr>
#     <tr>
#       <td>0.33%</td>
#       <td>-0.2235</td>
#       <td>GLNS</td>
#       <td>atp_c + glu__L_c + nh4_c --&gt; adp_c + gln__L_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>10.94%</td>
#       <td>-7.477</td>
#       <td>PFK</td>
#       <td>atp_c + f6p_c --&gt; adp_c + fdp_c + h_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.metabolites.atp_c
# Out:
# <Metabolite atp_c at 0x1294543e1c0>

# %% [markdown]
# Note that not all of the thirteen reactions associated with atp_c are carrying flux in this optimization.
#
# The shadow prices for each metabolite can be determined through the following command

# %%
model.metabolites.nadh_c.shadow_price
# Out:
# 3.866666666666667

# %% [markdown]
# LIsting all the metabolite shadow prices

# %%
solution.shadow_prices
# Out:
# glc__D_e    -9.166475e-02
# gln__L_c    -7.511417e-02
# gln__L_e    -7.002168e-02
# glu__L_c    -7.002168e-02
# glu__L_e    -6.874856e-02
# glx_c       -1.909682e-02
# h2o_c        1.084202e-19
# h2o_e        1.084202e-19
# h_c          1.273121e-03
# h_e          4.336809e-19
# icit_c      -7.129480e-02
# lac__D_c    -4.201301e-02
# lac__D_e    -4.073989e-02
# mal__L_c    -4.837862e-02
# mal__L_e    -4.583237e-02
# nad_c        7.638729e-03
# nadh_c       0.000000e+00
# nadp_c       8.911850e-03
# nadph_c      0.000000e+00
# nh4_c       -0.000000e+00
# 13dpg_c     -4.710549e-02
# nh4_e       -1.387779e-17
# o2_c        -0.000000e+00
# 2pg_c       -4.201301e-02
# o2_e        -0.000000e+00
# 3pg_c       -4.201301e-02
# oaa_c       -4.201301e-02
# pep_c       -4.201301e-02
# 6pgc_c      -9.166475e-02
# pi_c        -1.273121e-03
# 6pgl_c      -9.039162e-02
# pi_e        -4.163336e-17
# ac_c        -2.418931e-02
# pyr_c       -3.564740e-02
# pyr_e       -3.437428e-02
# q8_c         2.546243e-03
# q8h2_c       0.000000e+00
# r5p_c       -8.275290e-02
# ru5p__D_c   -8.275290e-02
# ac_e        -2.291619e-02
# acald_c     -3.437428e-02
# s7p_c       -1.133078e-01
# acald_e     -3.437428e-02
# accoa_c     -2.800867e-02
# succ_c      -5.092486e-02
# succ_e      -4.837862e-02
# succoa_c    -5.474422e-02
# acon_C_c    -7.129480e-02
# xu5p__D_c   -8.275290e-02
# actp_c      -2.928179e-02
# adp_c        5.092486e-03
# akg_c       -6.238295e-02
# akg_e       -6.110983e-02
# amp_c        1.018497e-02
# atp_c        0.000000e+00
# cit_c       -7.129480e-02
# co2_c       -0.000000e+00
# co2_e       -0.000000e+00
# coa_c        0.000000e+00
# dhap_c      -5.219798e-02
# e4p_c       -6.747544e-02
# etoh_c      -4.073989e-02
# etoh_e      -3.946677e-02
# f6p_c       -9.803035e-02
# fdp_c       -1.043960e-01
# for_c       -7.638729e-03
# for_e       -7.638729e-03
# fru_e       -9.166475e-02
# fum_c       -4.837862e-02
# fum_e       -4.583237e-02
# g3p_c       -5.219798e-02
# g6p_c       -9.803035e-02
# Name: shadow_prices, dtype: float64

# %% [markdown]
# Creating a table that includes the shadow prices of all the metabolites

# %%
metabolite_names = [m.name for m in model.metabolites]
metabolite_ids = [m.id for m in model.metabolites]
metabolite_compartment = [m.compartment for m in model.metabolites]
metabolite_formula = [m.formula for m in model.metabolites]
metabolite_charge = [m.charge for m in model.metabolites]
metabolite_SP = [m.shadow_price for m in model.metabolites]
metaboliteList = {'Metabolite ID': metabolite_ids,
                  'Metabolite Name': metabolite_names,
                  'Metabolite Formula': metabolite_formula,
                  'Metabolite Compartment': metabolite_compartment,
                  'Metabolite Charge': metabolite_charge,
                  'Metabolite Shadow Price': metabolite_SP
                 }

df = pd.DataFrame(metaboliteList, columns= ['Metabolite ID','Metabolite Name', 'Metabolite Formula', 'Metabolite Compartment','Metabolite Charge','Metabolite Shadow Price'])
pd.set_option('display.max_rows', 500)
df
# Out:
#    Metabolite ID                                    Metabolite Name  \
# 0       glc__D_e                                          D-Glucose
# 1       gln__L_c                                        L-Glutamine
# 2       gln__L_e                                        L-Glutamine
# 3       glu__L_c                                        L-Glutamate
# 4       glu__L_e                                        L-Glutamate
# 5          glx_c                                         Glyoxylate
# 6          h2o_c                                            H2O H2O
# 7          h2o_e                                            H2O H2O
# 8            h_c                                                 H+
# 9            h_e                                                 H+
# 10        icit_c                                         Isocitrate
# 11      lac__D_c                                          D-Lactate
# 12      lac__D_e                                          D-Lactate
# 13      mal__L_c                                           L-Malate
# 14      mal__L_e                                           L-Malate
# 15         nad_c                  Nicotinamide adenine dinucleotide
# 16        nadh_c        Nicotinamide adenine dinucleotide - reduced
# 17        nadp_c        Nicotinamide adenine dinucleotide phosphate
# 18       nadph_c  Nicotinamide adenine dinucleotide phosphate - ...
# 19         nh4_c                                           Ammonium
# 20       13dpg_c                    3-Phospho-D-glyceroyl phosphate
# 21         nh4_e                                           Ammonium
# 22          o2_c                                              O2 O2
# 23         2pg_c                            D-Glycerate 2-phosphate
# 24          o2_e                                              O2 O2
# 25         3pg_c                              3-Phospho-D-glycerate
# 26         oaa_c                                       Oxaloacetate
# 27         pep_c                                Phosphoenolpyruvate
# 28        6pgc_c                              6-Phospho-D-gluconate
# 29          pi_c                                          Phosphate
# 30        6pgl_c                    6-phospho-D-glucono-1,5-lactone
# 31          pi_e                                          Phosphate
# 32          ac_c                                            Acetate
# 33         pyr_c                                           Pyruvate
# 34         pyr_e                                           Pyruvate
# 35          q8_c                                       Ubiquinone-8
# 36        q8h2_c                                        Ubiquinol-8
# 37         r5p_c                         Alpha-D-Ribose 5-phosphate
# 38     ru5p__D_c                             D-Ribulose 5-phosphate
# 39          ac_e                                            Acetate
# 40       acald_c                                       Acetaldehyde
# 41         s7p_c                          Sedoheptulose 7-phosphate
# 42       acald_e                                       Acetaldehyde
# 43       accoa_c                                         Acetyl-CoA
# 44        succ_c                                          Succinate
# 45        succ_e                                          Succinate
# 46      succoa_c                                       Succinyl-CoA
# 47      acon_C_c                                      Cis-Aconitate
# 48     xu5p__D_c                             D-Xylulose 5-phosphate
# 49        actp_c                                   Acetyl phosphate
# 50         adp_c                                  ADP C10H12N5O10P2
# 51         akg_c                                     2-Oxoglutarate
# 52         akg_e                                     2-Oxoglutarate
# 53         amp_c                                    AMP C10H12N5O7P
# 54         atp_c                                  ATP C10H12N5O13P3
# 55         cit_c                                            Citrate
# 56         co2_c                                            CO2 CO2
# 57         co2_e                                            CO2 CO2
# 58         coa_c                                         Coenzyme A
# 59        dhap_c                         Dihydroxyacetone phosphate
# 60         e4p_c                            D-Erythrose 4-phosphate
# 61        etoh_c                                            Ethanol
# 62        etoh_e                                            Ethanol
# 63         f6p_c                             D-Fructose 6-phosphate
# 64         fdp_c                        D-Fructose 1,6-bisphosphate
# 65         for_c                                            Formate
# 66         for_e                                            Formate
# 67         fru_e                                         D-Fructose
# 68         fum_c                                           Fumarate
# 69         fum_e                                           Fumarate
# 70         g3p_c                         Glyceraldehyde 3-phosphate
# 71         g6p_c                              D-Glucose 6-phosphate
#
#    Metabolite Formula Metabolite Compartment  Metabolite Charge  \
# 0             C6H12O6                      e                  0
# 1           C5H10N2O3                      c                  0
# 2           C5H10N2O3                      e                  0
# 3             C5H8NO4                      c                 -1
# 4             C5H8NO4                      e                 -1
# 5              C2H1O3                      c                 -1
# 6                 H2O                      c                  0
# 7                 H2O                      e                  0
# 8                   H                      c                  1
# 9                   H                      e                  1
# 10             C6H5O7                      c                 -3
# 11             C3H5O3                      c                 -1
# 12             C3H5O3                      e                 -1
# 13             C4H4O5                      c                 -2
# 14             C4H4O5                      e                 -2
# 15      C21H26N7O14P2                      c                 -1
# 16      C21H27N7O14P2                      c                 -2
# 17      C21H25N7O17P3                      c                 -3
# 18      C21H26N7O17P3                      c                 -4
# 19                H4N                      c                  1
# 20          C3H4O10P2                      c                 -4
# 21                H4N                      e                  1
# 22                 O2                      c                  0
# 23            C3H4O7P                      c                 -3
# 24                 O2                      e                  0
# 25            C3H4O7P                      c                 -3
# 26             C4H2O5                      c                 -2
# 27            C3H2O6P                      c                 -3
# 28          C6H10O10P                      c                 -3
# 29               HO4P                      c                 -2
# 30            C6H9O9P                      c                 -2
# 31               HO4P                      e                 -2
# 32             C2H3O2                      c                 -1
# 33             C3H3O3                      c                 -1
# 34             C3H3O3                      e                 -1
# 35           C49H74O4                      c                  0
# 36           C49H76O4                      c                  0
# 37            C5H9O8P                      c                 -2
# 38            C5H9O8P                      c                 -2
# 39             C2H3O2                      e                 -1
# 40              C2H4O                      c                  0
# 41          C7H13O10P                      c                 -2
# 42              C2H4O                      e                  0
# 43     C23H34N7O17P3S                      c                 -4
# 44             C4H4O4                      c                 -2
# 45             C4H4O4                      e                 -2
# 46     C25H35N7O19P3S                      c                 -5
# 47             C6H3O6                      c                 -3
# 48            C5H9O8P                      c                 -2
# 49            C2H3O5P                      c                 -2
# 50      C10H12N5O10P2                      c                 -3
# 51             C5H4O5                      c                 -2
# 52             C5H4O5                      e                 -2
# 53        C10H12N5O7P                      c                 -2
# 54      C10H12N5O13P3                      c                 -4
# 55             C6H5O7                      c                 -3
# 56                CO2                      c                  0
# 57                CO2                      e                  0
# 58     C21H32N7O16P3S                      c                 -4
# 59            C3H5O6P                      c                 -2
# 60            C4H7O7P                      c                 -2
# 61              C2H6O                      c                  0
# 62              C2H6O                      e                  0
# 63           C6H11O9P                      c                 -2
# 64         C6H10O12P2                      c                 -4
# 65              CH1O2                      c                 -1
# 66              CH1O2                      e                 -1
# 67            C6H12O6                      e                  0
# 68             C4H2O4                      c                 -2
# 69             C4H2O4                      e                 -2
# 70            C3H5O6P                      c                 -2
# 71           C6H11O9P                      c                 -2
#
#     Metabolite Shadow Price
# 0                  5.200000
# 1                 34.155556
# 2                 26.911111
# 3                 22.911111
# 4                 22.600000
# 5                  8.377778
# 6                 -2.000000
# 7                 -1.000000
# 8                 -2.311111
# 9                 -1.000000
# 10                17.222222
# 11                 4.666667
# 12                 2.355556
# 13                11.222222
# 14                 7.600000
# 15                 0.000000
# 16                 3.866667
# 17                 0.000000
# 18                 4.577778
# 19                 2.000000
# 20                18.911111
# 21                 1.000000
# 22                 2.000000
# 23                11.666667
# 24                 1.000000
# 25                10.666667
# 26                10.666667
# 27                14.666667
# 28                16.800000
# 29                 3.311111
# 30                15.488889
# 31                 1.000000
# 32                -0.688889
# 33                 4.111111
# 34                 1.800000
# 35                 1.377778
# 36                 0.000000
# 37                16.222222
# 38                15.222222
# 39                -1.000000
# 40                 3.800000
# 41                17.288889
# 42                 2.800000
# 43                 0.000000
# 44                 9.844444
# 45                 6.222222
# 46                11.533333
# 47                18.222222
# 48                16.222222
# 49                 7.555556
# 50                -9.244444
# 51                15.644444
# 52                13.333333
# 53               -17.488889
# 54                 0.000000
# 55                15.222222
# 56                -2.000000
# 57                -1.000000
# 58                -3.244444
# 59                15.155556
# 60                16.688889
# 61                 4.355556
# 62                 2.044444
# 63                17.755556
# 64                30.311111
# 65                -2.000000
# 66                -1.000000
# 67                 6.200000
# 68                12.222222
# 69                 8.600000
# 70                16.155556
# 71                16.755556

# %% [markdown]
# ## Changing the Objective Function
# The objective function is determined from the objective_coefficient attribute of the objective reaction(s). For most cases, a “biomass” function which describes the composition of metabolites which make up a cell is used. The objective function can be change to a single or multiple reactions.
#
# The objective function for a given model can be determined using the **model.summary()** or the **linear_reaction_coefficients(model)** commands.

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.8739215069684312</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-22.81</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-29.18</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-17.53</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# or

# %%
from cobra.util.solver import linear_reaction_coefficients
linear_reaction_coefficients(model)
# Out:
# {<Reaction BIOMASS_Ecoli_core_w_GAM at 0x1294548f6d0>: 1.0}

# %% [markdown]
# The details of the objective function can be found by using the following code(the default objective function for the *E.coli* core model is the biomass function)

# %%
biomass_rxn = model.reactions.get_by_id("BIOMASS_Ecoli_core_w_GAM")
biomass_rxn
# Out:
# <Reaction BIOMASS_Ecoli_core_w_GAM at 0x1294548f6d0>

# %% [markdown]
# Currently in the model, there is only one reaction in the objective (the biomass reaction), with an linear coefficient of 1.

# %% [markdown]
# The objective function can be changed by assigning model.objective, which can be a reaction object (or just it’s name), or a dict of {Reaction: objective_coefficient}.

# %%
# change the objective to ATPM
model.objective = "ATPM"

# The upper bound should be 1000, so that we get
# the actual optimal value
model.reactions.get_by_id("ATPM").upper_bound = 1000.

# %% [markdown]
# Verifying this change to the objective function

# %%
linear_reaction_coefficients(model)
# Out:
# {<Reaction ATPM at 0x12945471430>: 1.0}

# %% [markdown]
# The characteristics of the new objective function

# %%
objectiveFunction = model.reactions.get_by_id("ATPM")
objectiveFunction
# Out:
# <Reaction ATPM at 0x12945471430>

# %% [markdown]
# The numerical value of the new ATPM objective function is given below. Notice that the model is no longer optimizing for cell growth but now it is maximizing the production of ATP.

# %%
model.optimize().objective_value
# Out:
# 175.0000000000001

# %% [markdown]
# ## Running Geometric FBA
# Geometric FBA finds a unique optimal flux distribution which is central to the range of possible fluxes. For more details on geometric FBA, please see K Smallbone, E Simeonidis (2009).

# %%
model.objective = "BIOMASS_Ecoli_core_w_GAM"
geometric_fba_sol = cobra.flux_analysis.geometric_fba(model)
geometric_fba_sol
# Out:
# <Solution 0.000 at 0x12946818880>

# %% [markdown]
# ## Plotting the Fluxes on an Escher Map

# %%
import cobra
import escher
from escher import Builder

# %% [markdown]
# To plot the maps of the different models requires a Jupyter widget called "Builder." This widget will execute in a Jupyter cell to embed an Escher map. Two names are required for the widget to operate properly; 1) the "map_name" is the name of the map file (different from the model file) that contains all the information to plot a map of the organism, 2) the "model_name" is the name of a genome-scale metabolic network reconstruction or COBRA model. The maps and models that are supported by the Escher website include the following.

# %%
escher.list_available_maps()
# Out:
# [{'organism': 'Saccharomyces cerevisiae',
#   'map_name': 'iMM904.Central carbon metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Inositol retinol metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Glycolysis TCA PPP'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Tryptophan metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Carbohydrate metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Amino acid metabolism (partial)'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Nucleotide metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid biosynthesis (saturated)'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Nucleotide and histidine biosynthesis'},
#  {'organism': 'Escherichia coli', 'map_name': 'e_coli_core.Core metabolism'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Central metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid beta-oxidation'}]

# %%
escher.list_available_models()
# Out:
# [{'organism': 'Saccharomyces cerevisiae', 'model_name': 'iMM904'},
#  {'organism': 'Homo sapiens', 'model_name': 'RECON1'},
#  {'organism': 'Escherichia coli', 'model_name': 'e_coli_core'},
#  {'organism': 'Escherichia coli', 'model_name': 'iJO1366'}]

# %% [markdown]
# To load a map and model into the Builder widget can be done as follows

# %%
builder = Builder(
    map_name='e_coli_core.Core metabolism', 
    model_name='e_coli_core', # This loads the model name into Escher but does not change the model in the COBRApy simulation
)
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/e_coli_core.Core%20metabolism.json
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/e_coli_core.json

# %% [markdown]
# This sets the model and map name for the Escher package. The model name that is downloaded does not replace the model used in the COBRApy simulations.

# %%
builder
# Out:
# Builder()

# %% [markdown]
# Note that the flux data is overlayed on the map that was created by the Builder widget. Plotting the flux data from an FBA simulation (model.optimize()) onto the map. If you zoom in on the map and click the arrow to the left you can put the arrow over a reaction or metabolite and see the flux value(reactions).

# %%
solution = model.optimize()
builder.reaction_data = solution.fluxes

# %% [markdown]
# Now lets create a new map that also includes the shadow prices of the metabolites.

# %%
builder = Builder(
    map_name='e_coli_core.Core metabolism', 
    model_name='e_coli_core', 
)
builder
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/e_coli_core.Core%20metabolism.json
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/e_coli_core.json
# Builder()

# %% [markdown]
# If you zoom in on the map and click the arrow to the left you can move the arrow over a metabolite's name and the shadow price information for the metabolite will be shown.

# %%
solution = model.optimize()
builder.reaction_data = solution.fluxes
builder.metabolite_data = solution.shadow_prices

# %% [markdown]
# More information on how to use Escher can be found at https://escher.readthedocs.io/en/latest/index.html

# %% [markdown]
# ## Map Animation
#
# Animations are relatively easy with an Escher map. Here's a simple example where flux predictions are swept across and range to update the map of *E. coli* core metabolism.

# %%
builder = Builder(
    height=600, 
    map_name='e_coli_core.Core metabolism', 
    model_name='e_coli_core',
)
builder
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/e_coli_core.Core%20metabolism.json
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/e_coli_core.json
# Builder(height=600)

# %%
from time import sleep
timestep = 0.5
lim = [0, 0.5]
for lb in range(-30,1,1):
    model.reactions.EX_o2_e.lower_bound = lb
    solution = model.optimize()
    builder.reaction_data = solution.fluxes
    sleep(timestep)

# %% [markdown]
# In this simulation, the o2 level starts at -30 mmol/gDW-hr which puts the organism in an aerobic state. As the o2 level drops to 0 mmol/gDW-hr, the organism passes through an anoxic state on it's way to an anaerobic state

# %% [markdown]
# ## Saving Maps as HTML
#
# The Escher Builder can also be saved as a standalone HTML file, which you can view by opening in a browser. Just provide a filepath, and the map will be bundled along with all the current options.

# %%
builder.save_html('example_map.html')

# %% [markdown]
# ## References
#
# 1. https://cobrapy.readthedocs.io/en/latest/simulating.html#
# 2. https://escher.readthedocs.io/en/latest/index.html
