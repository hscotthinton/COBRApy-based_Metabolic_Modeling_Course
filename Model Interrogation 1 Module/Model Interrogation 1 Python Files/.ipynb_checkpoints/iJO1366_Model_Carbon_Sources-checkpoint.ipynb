# %% [markdown]
# # Carbon Sources in the *E.coli* iJO1366 Model

# %%
import cobra.test
from cobra.test import create_test_model
import escher
from escher import Builder
import numpy as np
import pandas as pd
from cobrapy_bigg_client import client
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)

model_orig = client.download_model('iJO1366', save=False)

# %% [markdown]
# ## Exchange Reactions (Carbon Sources) That Allow Aerobic Growth
#
# Find the exchange reactions that allow growth in an aerobic environment.

# %%
model = model_orig.copy()
exchange_ids = []
growth_rate = []
exchange_ids = [r.id for r in model.exchanges]
model.reactions.EX_o2_e.lower_bound = -1000
model.reactions.EX_glc__D_e.lower_bound = -0
for i in range(len(exchange_ids)):
    temp = model.reactions.get_by_id(exchange_ids[i]).lower_bound 
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = -20
    x = model.slim_optimize()
    growth_rate.append(x)
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = temp
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %% [markdown]
# Create and print a Pandas DataFrame of the results

# %%
Aerobic_carbon_growth_rate = {'Exchange Reaction': exchange_ids,
                     'Aerobic Growth Rate': growth_rate}
Aerobic_df = pd.DataFrame(Aerobic_carbon_growth_rate, columns = ['Exchange Reaction','Aerobic Growth Rate'])
df1 = Aerobic_df
df1 = df1.round(4) # Round to 4 digits
df1 = df1.replace(0, np.nan) # Replace zeros with NaN
df1 = df1.dropna() # Remove rows with NaN values
df1 = df1.reset_index(drop=True) # Reset index values
df1
# Out:
#          Exchange Reaction  Aerobic Growth Rate
# 0                 EX_cmp_e               1.7826
# 1              EX_glc__D_e               1.9778
# 2                EX_glcn_e               1.8077
# 3                EX_glcr_e               1.3900
# 4               EX_glcur_e               1.5958
# 5             EX_glcur1p_e               1.5958
# 6              EX_gln__L_e               1.4104
# 7              EX_glu__L_e               1.4077
# 8                 EX_gly_e               0.4358
# 9              EX_glyald_e               0.9896
# 10               EX_glyc_e               1.1390
# 11           EX_12ppd__S_e               1.0848
# 12           EX_14glucan_e              12.0981
# 13            EX_glyc__R_e               0.7511
# 14             EX_glyc2p_e               1.1390
# 15             EX_23camp_e               2.6012
# 16             EX_23ccmp_e               1.7826
# 17             EX_23cgmp_e               2.4671
# 18             EX_23cump_e               1.7591
# 19            EX_23dappa_e               0.7321
# 20             EX_glyc3p_e               1.2199
# 21             EX_glyclt_e               0.3831
# 22                EX_gmp_e               2.4671
# 23                EX_gsn_e               2.4671
# 24              EX_gthrd_e               2.6529
# 25                EX_gua_e               0.6904
# 26               EX_hdca_e               4.8379
# 27              EX_hdcea_e               4.9770
# 28            EX_2ddglcn_e               1.7373
# 29               EX_3amp_e               2.6012
# 30               EX_3cmp_e               1.7826
# 31               EX_3gmp_e               2.4671
# 32            EX_3hcinnm_e               2.3093
# 33             EX_3hpppn_e               2.3894
# 34                EX_hxa_e               1.7567
# 35               EX_hxan_e               0.7860
# 36            EX_idon__L_e               1.7912
# 37               EX_3ump_e               1.7591
# 38              EX_4abut_e               1.3000
# 39             EX_5dglcn_e               1.6460
# 40           EX_LalaDglu_e               2.3552
# 41                EX_imp_e               2.5777
# 42                EX_ins_e               2.5777
# 43       EX_LalaDgluMdap_e               2.3964
# 44   EX_LalaDgluMdapDala_e               3.3637
# 45           EX_LalaLglu_e               2.3552
# 46                 EX_ac_e               0.5075
# 47               EX_acac_e               1.1068
# 48              EX_acald_e               0.7209
# 49             EX_lac__D_e               0.8693
# 50             EX_lac__L_e               0.8105
# 51               EX_lcts_e               3.9479
# 52              EX_acgam_e               2.5363
# 53            EX_acgam1p_e               2.5363
# 54             EX_acmana_e               2.5363
# 55              EX_acmum_e               3.4536
# 56              EX_acnam_e               3.3064
# 57                EX_ade_e               0.7871
# 58                EX_adn_e               2.6012
# 59             EX_lyx__L_e               1.6253
# 60             EX_mal__D_e               0.8693
# 61                EX_agm_e               1.5512
# 62                EX_akg_e               1.2485
# 63             EX_ala__D_e               0.8824
# 64             EX_ala__L_e               0.8824
# 65             EX_alaala_e               1.8195
# 66             EX_all__D_e               1.8949
# 67              EX_alltn_e               0.3623
# 68                EX_amp_e               2.6012
# 69              EX_anhgm_e               6.0034
# 70            EX_arab__L_e               1.6253
# 71             EX_mal__L_e               0.9124
# 72               EX_malt_e               3.9687
# 73             EX_malthx_e              12.0981
# 74             EX_maltpt_e              10.0243
# 75             EX_malttr_e               5.9596
# 76            EX_maltttr_e               7.9504
# 77                EX_man_e               1.9778
# 78              EX_man6p_e               2.0400
# 79            EX_manglyc_e               2.7659
# 80              EX_melib_e               3.9479
# 81             EX_cys__D_e               0.6810
# 82             EX_cys__L_e               0.6831
# 83             EX_arg__L_e               1.6420
# 84            EX_ascb__L_e               1.6434
# 85             EX_asn__L_e               0.9349
# 86             EX_asp__L_e               0.9339
# 87                EX_but_e               1.1404
# 88                EX_mnl_e               2.1225
# 89             EX_butso3_e               0.5505
# 90               EX_cytd_e               1.7826
# 91               EX_cgly_e               1.1678
# 92              EX_ocdca_e               5.4541
# 93             EX_ocdcea_e               5.5933
# 94               EX_octa_e               2.3729
# 95                EX_orn_e               1.5814
# 96             EX_pacald_e               2.4953
# 97              EX_peamn_e               2.4953
# 98              EX_chtbs_e               5.0905
# 99                EX_cit_e               1.4077
# 100             EX_dad_2_e               2.7035
# 101               EX_ppa_e               0.8693
# 102              EX_damp_e               2.7035
# 103              EX_ppal_e               1.0282
# 104               EX_dca_e               2.9892
# 105              EX_pppn_e               2.5295
# 106              EX_dcmp_e               1.8694
# 107            EX_pro__L_e               1.4390
# 108              EX_dcyt_e               1.8694
# 109            EX_progly_e               1.8904
# 110            EX_psclys_e               2.0227
# 111              EX_ddca_e               3.6054
# 112           EX_pser__L_e               0.7446
# 113              EX_ptrc_e               1.5512
# 114              EX_dgmp_e               2.5609
# 115              EX_dgsn_e               2.5609
# 116               EX_xan_e               0.6700
# 117               EX_dha_e               0.9824
# 118               EX_xmp_e               2.4397
# 119              EX_dimp_e               2.6783
# 120               EX_din_e               2.6783
# 121              EX_xtsn_e               2.4397
# 122            EX_xyl__D_e               1.6253
# 123           EX_xylu__L_e               1.6253
# 124               EX_pyr_e               0.7321
# 125               EX_r5p_e               1.5630
# 126            EX_rib__D_e               1.5630
# 127               EX_rmn_e               1.9394
# 128            EX_sbt__D_e               2.1225
# 129            EX_ser__D_e               0.7446
# 130            EX_ser__L_e               0.7446
# 131              EX_succ_e               0.9985
# 132              EX_sucr_e               3.9687
# 133          EX_tartr__D_e               0.7401
# 134          EX_tartr__L_e               0.7617
# 135            EX_thr__L_e               1.2051
# 136              EX_dtmp_e               1.7810
# 137              EX_thrp_e               1.2051
# 138              EX_dump_e               1.8492
# 139             EX_thymd_e               1.7810
# 140              EX_duri_e               1.8492
# 141               EX_tre_e               3.9687
# 142            EX_trp__L_e               0.7597
# 143             EX_ttdca_e               4.2216
# 144            EX_ttdcea_e               4.3608
# 145              EX_etha_e               0.7016
# 146            EX_ethso3_e               0.0054
# 147            EX_uacgam_e               4.3562
# 148          EX_udpacgal_e               1.7591
# 149              EX_udpg_e               3.7847
# 150            EX_udpgal_e               3.7636
# 151              EX_etoh_e               0.8560
# 152          EX_udpglcur_e               3.4049
# 153               EX_ump_e               1.7591
# 154               EX_f6p_e               2.0400
# 155              EX_fald_e               0.1651
# 156               EX_uri_e               1.7591
# 157           EX_fe3dcit_e               2.6892
# 158               EX_for_e               0.0323
# 159               EX_fru_e               1.9778
# 160            EX_frulys_e               2.0227
# 161             EX_fruur_e               1.5958
# 162            EX_fuc__L_e               1.9394
# 163               EX_fum_e               0.9124
# 164               EX_g1p_e               1.9778
# 165              EX_g3pc_e               1.2199
# 166              EX_g3pe_e               1.9641
# 167              EX_g3pg_e               2.3769
# 168              EX_g3pi_e               1.2199
# 169              EX_g3ps_e               2.0000
# 170               EX_g6p_e               2.0400
# 171               EX_gal_e               1.9571
# 172            EX_gal_bD_e               1.9571
# 173             EX_gal1p_e               1.9571
# 174          EX_galct__D_e               1.3900
# 175         EX_galctn__D_e               1.7373
# 176         EX_galctn__L_e               1.7373
# 177              EX_galt_e               2.1009
# 178             EX_galur_e               1.5958
# 179               EX_gam_e               1.9786
# 180             EX_gam6p_e               2.0408

# %% [markdown]
# The total number of metabolites (exhange reactions) that can grow in aerobic conditions is 181!

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exchange Reaction    181 non-null    object
#  1   Aerobic Growth Rate  181 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# A histogram of the aerobic growth rates from the different exchange reactions

# %%
df1.hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Aerobic Growth Rate'}>]],
#       dtype=object)

# %% [markdown]
# ## Exchange Reactions (Carbon Sources) That Allow Anaerobic Growth
#
# Find the exchange reactions that allow growth in an anaerobic environment.

# %%
model = model_orig.copy()
exchange_ids = []
growth_rate = []
exchange_ids = [r.id for r in model.exchanges]
model.reactions.EX_o2_e.lower_bound = 0
model.reactions.EX_glc__D_e.lower_bound = -0
for i in range(len(exchange_ids)):
    temp = model.reactions.get_by_id(exchange_ids[i]).lower_bound 
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = -20
    x = model.slim_optimize()
    growth_rate.append(x)
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = temp

# %% [markdown]
# Create and print a Pandas DataFrame of the anaerobic carbon sources.

# %%
Anaerobic_carbon_growth_rate = {'Exchange Reaction': exchange_ids,
                     'Anaerobic Growth Rate': growth_rate}
Anaerobic_df = pd.DataFrame(Anaerobic_carbon_growth_rate, columns = ['Exchange Reaction','Anaerobic Growth Rate'])
df2 = Anaerobic_df
df2 = df2.round(4) # Round to 4 digits
df2 = df2.replace(0, np.nan) # Replace zero with NaN
df2 = df2.dropna() # Remove rows with NaN
df2 = df2.reset_index(drop=True) # Reset index values
df2
# Out:
#          Exchange Reaction  Anaerobic Growth Rate
# 0                 EX_cmp_e                 0.7177
# 1              EX_glc__D_e                 0.5178
# 2                EX_glcn_e                 0.4119
# 3                EX_glcr_e                 0.3866
# 4               EX_glcur_e                 0.4915
# 5             EX_glcur1p_e                 0.4915
# 6              EX_gln__L_e                 0.1997
# 7              EX_glu__L_e                 0.1986
# 8              EX_glyald_e                 0.3039
# 9                EX_glyc_e                 0.1923
# 10           EX_14glucan_e                 3.7231
# 11            EX_glyc__R_e                 0.1243
# 12             EX_glyc2p_e                 0.1923
# 13             EX_23camp_e                 0.7100
# 14             EX_23ccmp_e                 0.7177
# 15             EX_23cgmp_e                 0.8323
# 16             EX_23cump_e                 0.6588
# 17            EX_23dappa_e                 0.1145
# 18             EX_glyc3p_e                 0.4174
# 19                EX_gmp_e                 0.8323
# 20                EX_gsn_e                 0.8323
# 21              EX_gthrd_e                 0.3255
# 22                EX_gua_e                 0.1328
# 23            EX_2ddglcn_e                 0.4034
# 24               EX_3amp_e                 0.7100
# 25               EX_3cmp_e                 0.7177
# 26               EX_3gmp_e                 0.8323
# 27            EX_idon__L_e                 0.3152
# 28               EX_3ump_e                 0.6588
# 29             EX_5dglcn_e                 0.4257
# 30           EX_LalaDglu_e                 0.3754
# 31                EX_imp_e                 0.6487
# 32                EX_ins_e                 0.6487
# 33       EX_LalaDgluMdap_e                 0.2014
# 34   EX_LalaDgluMdapDala_e                 0.3806
# 35           EX_LalaLglu_e                 0.3754
# 36               EX_acac_e                 0.1285
# 37              EX_acald_e                 0.0669
# 38             EX_lac__D_e                 0.0186
# 39               EX_lcts_e                 1.0152
# 40              EX_acgam_e                 0.5737
# 41            EX_acgam1p_e                 0.5737
# 42             EX_acmana_e                 0.5737
# 43              EX_acmum_e                 0.6843
# 44              EX_acnam_e                 0.7396
# 45                EX_adn_e                 0.7100
# 46             EX_lyx__L_e                 0.3704
# 47             EX_mal__D_e                 0.0186
# 48                EX_akg_e                 0.1955
# 49             EX_ala__D_e                 0.0703
# 50             EX_ala__L_e                 0.0703
# 51             EX_alaala_e                 0.2757
# 52             EX_all__D_e                 0.2968
# 53              EX_alltn_e                 0.2175
# 54                EX_amp_e                 0.7100
# 55              EX_anhgm_e                 1.2375
# 56            EX_arab__L_e                 0.3704
# 57             EX_mal__L_e                 0.0787
# 58               EX_malt_e                 1.0705
# 59             EX_malthx_e                 3.7231
# 60             EX_maltpt_e                 2.9494
# 61             EX_malttr_e                 1.6231
# 62            EX_maltttr_e                 2.1757
# 63                EX_man_e                 0.5178
# 64              EX_man6p_e                 0.6836
# 65            EX_manglyc_e                 0.7389
# 66              EX_melib_e                 1.0152
# 67             EX_arg__L_e                 0.0207
# 68            EX_ascb__L_e                 0.4257
# 69             EX_asn__L_e                 0.1383
# 70             EX_asp__L_e                 0.1379
# 71                EX_mnl_e                 0.4073
# 72               EX_cytd_e                 0.7177
# 73               EX_cgly_e                 0.0461
# 74                EX_orn_e                 0.0161
# 75              EX_chtbs_e                 1.1822
# 76                EX_cit_e                 0.2265
# 77              EX_dad_2_e                 0.6311
# 78               EX_damp_e                 0.6311
# 79               EX_dcmp_e                 0.6342
# 80               EX_dcyt_e                 0.6342
# 81             EX_psclys_e                 0.4152
# 82            EX_pser__L_e                 0.1193
# 83               EX_dgmp_e                 0.7467
# 84               EX_dgsn_e                 0.7467
# 85                EX_xan_e                 0.0760
# 86                EX_dha_e                 0.2415
# 87                EX_xmp_e                 0.7656
# 88               EX_dimp_e                 0.5701
# 89                EX_din_e                 0.5701
# 90               EX_xtsn_e                 0.7656
# 91             EX_xyl__D_e                 0.3704
# 92            EX_xylu__L_e                 0.3704
# 93                EX_pyr_e                 0.1145
# 94                EX_r5p_e                 0.2047
# 95             EX_rib__D_e                 0.2047
# 96                EX_rmn_e                 0.2817
# 97             EX_sbt__D_e                 0.4073
# 98             EX_ser__D_e                 0.1193
# 99             EX_ser__L_e                 0.1193
# 100              EX_sucr_e                 1.0705
# 101          EX_tartr__D_e                 0.0797
# 102          EX_tartr__L_e                 0.1683
# 103            EX_thr__L_e                 0.1004
# 104              EX_dtmp_e                 0.4592
# 105              EX_thrp_e                 0.1004
# 106              EX_dump_e                 0.5784
# 107             EX_thymd_e                 0.4592
# 108              EX_duri_e                 0.5784
# 109               EX_tre_e                 1.0705
# 110            EX_trp__L_e                 0.1641
# 111              EX_etha_e                 0.0181
# 112            EX_uacgam_e                 1.2794
# 113          EX_udpacgal_e                 0.6588
# 114              EX_udpg_e                 1.2217
# 115            EX_udpgal_e                 1.1654
# 116          EX_udpglcur_e                 1.2217
# 117               EX_ump_e                 0.6588
# 118               EX_f6p_e                 0.6836
# 119               EX_uri_e                 0.6588
# 120           EX_fe3dcit_e                 0.2870
# 121               EX_fru_e                 0.5178
# 122            EX_frulys_e                 0.4152
# 123             EX_fruur_e                 0.4915
# 124            EX_fuc__L_e                 0.2817
# 125               EX_fum_e                 0.0787
# 126               EX_g1p_e                 0.5178
# 127              EX_g3pc_e                 0.4174
# 128              EX_g3pe_e                 0.4740
# 129              EX_g3pg_e                 0.6487
# 130              EX_g3pi_e                 0.4174
# 131              EX_g3ps_e                 0.6015
# 132               EX_g6p_e                 0.6836
# 133               EX_gal_e                 0.4626
# 134            EX_gal_bD_e                 0.4626
# 135             EX_gal1p_e                 0.4626
# 136          EX_galct__D_e                 0.3866
# 137         EX_galctn__D_e                 0.4034
# 138         EX_galctn__L_e                 0.4034
# 139              EX_galt_e                 0.4034
# 140             EX_galur_e                 0.4915
# 141               EX_gam_e                 0.5184
# 142             EX_gam6p_e                 0.6843

# %% [markdown]
# The total number of metabolites (exhange reactions) that can grow in anaerobic conditions is 143!

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Exchange Reaction      143 non-null    object
#  1   Anaerobic Growth Rate  143 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# A histogram of the anaerobic growth rates from the different exchange reactions

# %%
df2.hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Anaerobic Growth Rate'}>]],
#       dtype=object)

# %% [markdown]
# ## Growth Rate Table for Exchange Reactions
# Create a table showing the growth rates of the exchange reactions in both aerobic and anaerobic conditions.

# %%
df3 = Aerobic_df.join(Anaerobic_df.set_index('Exchange Reaction'), on='Exchange Reaction')
df3 = df3.round(4) # Round to four digits
df3 = df3.replace(0, np.nan) # Replace zero with NaN
df3 = df3.dropna(how = 'all', subset=['Aerobic Growth Rate', 'Anaerobic Growth Rate']) # Remove NaN's found in both columns
df3 = df3.replace(np.nan, 0)
df3 = df3.reset_index(drop=True)
df3
# Out:
#          Exchange Reaction  Aerobic Growth Rate  Anaerobic Growth Rate
# 0                 EX_cmp_e               1.7826                 0.7177
# 1              EX_glc__D_e               1.9778                 0.5178
# 2                EX_glcn_e               1.8077                 0.4119
# 3                EX_glcr_e               1.3900                 0.3866
# 4               EX_glcur_e               1.5958                 0.4915
# 5             EX_glcur1p_e               1.5958                 0.4915
# 6              EX_gln__L_e               1.4104                 0.1997
# 7              EX_glu__L_e               1.4077                 0.1986
# 8                 EX_gly_e               0.4358                 0.0000
# 9              EX_glyald_e               0.9896                 0.3039
# 10               EX_glyc_e               1.1390                 0.1923
# 11           EX_12ppd__S_e               1.0848                 0.0000
# 12           EX_14glucan_e              12.0981                 3.7231
# 13            EX_glyc__R_e               0.7511                 0.1243
# 14             EX_glyc2p_e               1.1390                 0.1923
# 15             EX_23camp_e               2.6012                 0.7100
# 16             EX_23ccmp_e               1.7826                 0.7177
# 17             EX_23cgmp_e               2.4671                 0.8323
# 18             EX_23cump_e               1.7591                 0.6588
# 19            EX_23dappa_e               0.7321                 0.1145
# 20             EX_glyc3p_e               1.2199                 0.4174
# 21             EX_glyclt_e               0.3831                 0.0000
# 22                EX_gmp_e               2.4671                 0.8323
# 23                EX_gsn_e               2.4671                 0.8323
# 24              EX_gthrd_e               2.6529                 0.3255
# 25                EX_gua_e               0.6904                 0.1328
# 26               EX_hdca_e               4.8379                 0.0000
# 27              EX_hdcea_e               4.9770                 0.0000
# 28            EX_2ddglcn_e               1.7373                 0.4034
# 29               EX_3amp_e               2.6012                 0.7100
# 30               EX_3cmp_e               1.7826                 0.7177
# 31               EX_3gmp_e               2.4671                 0.8323
# 32            EX_3hcinnm_e               2.3093                 0.0000
# 33             EX_3hpppn_e               2.3894                 0.0000
# 34                EX_hxa_e               1.7567                 0.0000
# 35               EX_hxan_e               0.7860                 0.0000
# 36            EX_idon__L_e               1.7912                 0.3152
# 37               EX_3ump_e               1.7591                 0.6588
# 38              EX_4abut_e               1.3000                 0.0000
# 39             EX_5dglcn_e               1.6460                 0.4257
# 40           EX_LalaDglu_e               2.3552                 0.3754
# 41                EX_imp_e               2.5777                 0.6487
# 42                EX_ins_e               2.5777                 0.6487
# 43       EX_LalaDgluMdap_e               2.3964                 0.2014
# 44   EX_LalaDgluMdapDala_e               3.3637                 0.3806
# 45           EX_LalaLglu_e               2.3552                 0.3754
# 46                 EX_ac_e               0.5075                 0.0000
# 47               EX_acac_e               1.1068                 0.1285
# 48              EX_acald_e               0.7209                 0.0669
# 49             EX_lac__D_e               0.8693                 0.0186
# 50             EX_lac__L_e               0.8105                 0.0000
# 51               EX_lcts_e               3.9479                 1.0152
# 52              EX_acgam_e               2.5363                 0.5737
# 53            EX_acgam1p_e               2.5363                 0.5737
# 54             EX_acmana_e               2.5363                 0.5737
# 55              EX_acmum_e               3.4536                 0.6843
# 56              EX_acnam_e               3.3064                 0.7396
# 57                EX_ade_e               0.7871                 0.0000
# 58                EX_adn_e               2.6012                 0.7100
# 59             EX_lyx__L_e               1.6253                 0.3704
# 60             EX_mal__D_e               0.8693                 0.0186
# 61                EX_agm_e               1.5512                 0.0000
# 62                EX_akg_e               1.2485                 0.1955
# 63             EX_ala__D_e               0.8824                 0.0703
# 64             EX_ala__L_e               0.8824                 0.0703
# 65             EX_alaala_e               1.8195                 0.2757
# 66             EX_all__D_e               1.8949                 0.2968
# 67              EX_alltn_e               0.3623                 0.2175
# 68                EX_amp_e               2.6012                 0.7100
# 69              EX_anhgm_e               6.0034                 1.2375
# 70            EX_arab__L_e               1.6253                 0.3704
# 71             EX_mal__L_e               0.9124                 0.0787
# 72               EX_malt_e               3.9687                 1.0705
# 73             EX_malthx_e              12.0981                 3.7231
# 74             EX_maltpt_e              10.0243                 2.9494
# 75             EX_malttr_e               5.9596                 1.6231
# 76            EX_maltttr_e               7.9504                 2.1757
# 77                EX_man_e               1.9778                 0.5178
# 78              EX_man6p_e               2.0400                 0.6836
# 79            EX_manglyc_e               2.7659                 0.7389
# 80              EX_melib_e               3.9479                 1.0152
# 81             EX_cys__D_e               0.6810                 0.0000
# 82             EX_cys__L_e               0.6831                 0.0000
# 83             EX_arg__L_e               1.6420                 0.0207
# 84            EX_ascb__L_e               1.6434                 0.4257
# 85             EX_asn__L_e               0.9349                 0.1383
# 86             EX_asp__L_e               0.9339                 0.1379
# 87                EX_but_e               1.1404                 0.0000
# 88                EX_mnl_e               2.1225                 0.4073
# 89             EX_butso3_e               0.5505                 0.0000
# 90               EX_cytd_e               1.7826                 0.7177
# 91               EX_cgly_e               1.1678                 0.0461
# 92              EX_ocdca_e               5.4541                 0.0000
# 93             EX_ocdcea_e               5.5933                 0.0000
# 94               EX_octa_e               2.3729                 0.0000
# 95                EX_orn_e               1.5814                 0.0161
# 96             EX_pacald_e               2.4953                 0.0000
# 97              EX_peamn_e               2.4953                 0.0000
# 98              EX_chtbs_e               5.0905                 1.1822
# 99                EX_cit_e               1.4077                 0.2265
# 100             EX_dad_2_e               2.7035                 0.6311
# 101               EX_ppa_e               0.8693                 0.0000
# 102              EX_damp_e               2.7035                 0.6311
# 103              EX_ppal_e               1.0282                 0.0000
# 104               EX_dca_e               2.9892                 0.0000
# 105              EX_pppn_e               2.5295                 0.0000
# 106              EX_dcmp_e               1.8694                 0.6342
# 107            EX_pro__L_e               1.4390                 0.0000
# 108              EX_dcyt_e               1.8694                 0.6342
# 109            EX_progly_e               1.8904                 0.0000
# 110            EX_psclys_e               2.0227                 0.4152
# 111              EX_ddca_e               3.6054                 0.0000
# 112           EX_pser__L_e               0.7446                 0.1193
# 113              EX_ptrc_e               1.5512                 0.0000
# 114              EX_dgmp_e               2.5609                 0.7467
# 115              EX_dgsn_e               2.5609                 0.7467
# 116               EX_xan_e               0.6700                 0.0760
# 117               EX_dha_e               0.9824                 0.2415
# 118               EX_xmp_e               2.4397                 0.7656
# 119              EX_dimp_e               2.6783                 0.5701
# 120               EX_din_e               2.6783                 0.5701
# 121              EX_xtsn_e               2.4397                 0.7656
# 122            EX_xyl__D_e               1.6253                 0.3704
# 123           EX_xylu__L_e               1.6253                 0.3704
# 124               EX_pyr_e               0.7321                 0.1145
# 125               EX_r5p_e               1.5630                 0.2047
# 126            EX_rib__D_e               1.5630                 0.2047
# 127               EX_rmn_e               1.9394                 0.2817
# 128            EX_sbt__D_e               2.1225                 0.4073
# 129            EX_ser__D_e               0.7446                 0.1193
# 130            EX_ser__L_e               0.7446                 0.1193
# 131              EX_succ_e               0.9985                 0.0000
# 132              EX_sucr_e               3.9687                 1.0705
# 133          EX_tartr__D_e               0.7401                 0.0797
# 134          EX_tartr__L_e               0.7617                 0.1683
# 135            EX_thr__L_e               1.2051                 0.1004
# 136              EX_dtmp_e               1.7810                 0.4592
# 137              EX_thrp_e               1.2051                 0.1004
# 138              EX_dump_e               1.8492                 0.5784
# 139             EX_thymd_e               1.7810                 0.4592
# 140              EX_duri_e               1.8492                 0.5784
# 141               EX_tre_e               3.9687                 1.0705
# 142            EX_trp__L_e               0.7597                 0.1641
# 143             EX_ttdca_e               4.2216                 0.0000
# 144            EX_ttdcea_e               4.3608                 0.0000
# 145              EX_etha_e               0.7016                 0.0181
# 146            EX_ethso3_e               0.0054                 0.0000
# 147            EX_uacgam_e               4.3562                 1.2794
# 148          EX_udpacgal_e               1.7591                 0.6588
# 149              EX_udpg_e               3.7847                 1.2217
# 150            EX_udpgal_e               3.7636                 1.1654
# 151              EX_etoh_e               0.8560                 0.0000
# 152          EX_udpglcur_e               3.4049                 1.2217
# 153               EX_ump_e               1.7591                 0.6588
# 154               EX_f6p_e               2.0400                 0.6836
# 155              EX_fald_e               0.1651                 0.0000
# 156               EX_uri_e               1.7591                 0.6588
# 157           EX_fe3dcit_e               2.6892                 0.2870
# 158               EX_for_e               0.0323                 0.0000
# 159               EX_fru_e               1.9778                 0.5178
# 160            EX_frulys_e               2.0227                 0.4152
# 161             EX_fruur_e               1.5958                 0.4915
# 162            EX_fuc__L_e               1.9394                 0.2817
# 163               EX_fum_e               0.9124                 0.0787
# 164               EX_g1p_e               1.9778                 0.5178
# 165              EX_g3pc_e               1.2199                 0.4174
# 166              EX_g3pe_e               1.9641                 0.4740
# 167              EX_g3pg_e               2.3769                 0.6487
# 168              EX_g3pi_e               1.2199                 0.4174
# 169              EX_g3ps_e               2.0000                 0.6015
# 170               EX_g6p_e               2.0400                 0.6836
# 171               EX_gal_e               1.9571                 0.4626
# 172            EX_gal_bD_e               1.9571                 0.4626
# 173             EX_gal1p_e               1.9571                 0.4626
# 174          EX_galct__D_e               1.3900                 0.3866
# 175         EX_galctn__D_e               1.7373                 0.4034
# 176         EX_galctn__L_e               1.7373                 0.4034
# 177              EX_galt_e               2.1009                 0.4034
# 178             EX_galur_e               1.5958                 0.4915
# 179               EX_gam_e               1.9786                 0.5184
# 180             EX_gam6p_e               2.0408                 0.6843

# %% [markdown]
# The total number of metabolites (exhange reactions) that can grow in either aerobic or anaerobic conditions

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Exchange Reaction      181 non-null    object
#  1   Aerobic Growth Rate    181 non-null    float64
#  2   Anaerobic Growth Rate  181 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.4+ KB
