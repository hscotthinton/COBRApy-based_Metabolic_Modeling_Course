# %% [markdown]
# # Essential Genes/Reactions: Simulating Single Deletions in iJO1366

# %%
import pandas as pd
from pandas import DataFrame
import cobra.test
from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)
pd.set_option('display.max_rows', 1000)

from cobrapy_bigg_client import client
model_orig = client.download_model('iJO1366', save=False) # Download model from the BIGG database
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-10-10

# %% [markdown]
# ## Essential Genes
#
# **An essential gene is a gene that when knocked out prevents cell growth!**
#
# First let's review how many genes and reactions are included in the iJO1366 model.

# %%
print('The number of genes in the iJO1366 model = ',len(model_orig.genes))
print('The number of reactions in the iJO1366 model = ',len(model_orig.reactions))
print('The number of metabolites in the iJO1366 model = ',len(model_orig.metabolites))
# Out:
# The number of genes in the iJO1366 model =  1367
# The number of reactions in the iJO1366 model =  2583
# The number of metabolites in the iJO1366 model =  1805

# %% [markdown]
# Perform all single gene deletions on a model

# %%
model = model_orig.copy()
deletion_results = single_gene_deletion(model)
deletion_results[0:20]
# Out:
# Read LP format model from file C:\Users\hinton\AppData\Local\Temp\tmpp7ls_1sb.lp
# Reading time = 0.02 seconds
# : 1805 rows, 5166 columns, 20366 nonzeros
#         ids    growth   status
# 0   {b3991}  0.000000  optimal
# 1   {b2836}  0.972037  optimal
# 2   {b3115}  0.982372  optimal
# 3   {b3599}  0.982372  optimal
# 4   {b3990}  0.000000  optimal
# 5   {b0088}  0.000000  optimal
# 6   {b2286}  0.873595  optimal
# 7   {b2022}  0.000000  optimal
# 8   {b1387}  0.982372  optimal
# 9   {b2874}  0.982372  optimal
# 10  {b1300}  0.982372  optimal
# 11  {b3770}  0.000000  optimal
# 12  {b2682}  0.982372  optimal
# 13  {b0596}  0.982372  optimal
# 14  {b0386}  0.000000  optimal
# 15  {b2239}  0.982372  optimal
# 16  {b2103}  0.000000  optimal
# 17  {b1854}  0.982372  optimal
# 18  {b0433}  0.982372  optimal
# 19  {b1662}  0.000000  optimal

# %% [markdown]
# Let's create a histogram plot of the growth-rates. The ones with zero growth-rate are teh essential reactions.

# %%
deletion_results.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Let's plot the values of the growth-rate starting from zero to the largest value.

# %%
deletion_results = deletion_results.sort_values('growth') # Sorting the growth-rate values
ax = deletion_results.plot.bar().axes
ax.figure.set_size_inches(16, 9)

# %% [markdown]
# Essential genes are genes that if knocked out will inhibit growth. The essential genes can be found by

# %%
essentialGenes = deletion_results.loc[deletion_results['growth'] < 0.00001] # Low growth-rate determines essential genes
essentialGenes = essentialGenes.reset_index() # Renumber the rows
essentialGenes.round(4)
# Out:
#      index      ids  growth   status
# 0      234  {b3974}    -0.0  optimal
# 1       87  {b0103}    -0.0  optimal
# 2      556  {b3639}    -0.0  optimal
# 3        0  {b3991}     0.0  optimal
# 4      858  {b2762}     0.0  optimal
# 5      863  {b1288}     0.0  optimal
# 6      868  {b1093}     0.0  optimal
# 7      871  {b2020}     0.0  optimal
# 8      238  {b1092}     0.0  optimal
# 9      876  {b0908}     0.0  optimal
# 10     879  {b3997}     0.0  optimal
# 11     886  {b0475}     0.0  optimal
# 12     889  {b2557}     0.0  optimal
# 13     890  {b0524}     0.0  optimal
# 14     901  {b0928}     0.0  optimal
# 15     237  {b0091}     0.0  optimal
# 16     857  {b3198}     0.0  optimal
# 17     856  {b2585}     0.0  optimal
# 18     853  {b2763}     0.0  optimal
# 19     276  {b4262}     0.0  optimal
# 20     782  {b2499}     0.0  optimal
# 21     272  {b3774}     0.0  optimal
# 22     270  {b0720}     0.0  optimal
# 23     791  {b0784}     0.0  optimal
# 24     800  {b0781}     0.0  optimal
# 25     906  {b3256}     0.0  optimal
# 26     815  {b3199}     0.0  optimal
# 27     256  {b4039}     0.0  optimal
# 28     846  {b3939}     0.0  optimal
# 29     849  {b2530}     0.0  optimal
# 30     253  {b1069}     0.0  optimal
# 31     252  {b0175}     0.0  optimal
# 32     850  {b2478}     0.0  optimal
# 33     819  {b1098}     0.0  optimal
# 34     910  {b2780}     0.0  optimal
# 35     219  {b3634}     0.0  optimal
# 36     932  {b0031}     0.0  optimal
# 37    1108  {b2615}     0.0  optimal
# 38    1106  {b0827}     0.0  optimal
# 39     152  {b0421}     0.0  optimal
# 40    1093  {b3804}     0.0  optimal
# 41    1084  {b3177}     0.0  optimal
# 42    1081  {b3642}     0.0  optimal
# 43     171  {b2329}     0.0  optimal
# 44    1070  {b0072}     0.0  optimal
# 45    1069  {b2750}     0.0  optimal
# 46     182  {b0185}     0.0  optimal
# 47    1067  {b2827}     0.0  optimal
# 48    1065  {b4214}     0.0  optimal
# 49    1061  {b3960}     0.0  optimal
# 50    1054  {b1210}     0.0  optimal
# 51    1045  {b2400}     0.0  optimal
# 52    1044  {b2687}     0.0  optimal
# 53    1036  {b0750}     0.0  optimal
# 54     216  {b3957}     0.0  optimal
# 55     938  {b0639}     0.0  optimal
# 56     940  {b3360}     0.0  optimal
# 57     211  {b0179}     0.0  optimal
# 58     953  {b0025}     0.0  optimal
# 59     959  {b2021}     0.0  optimal
# 60     779  {b0522}     0.0  optimal
# 61     970  {b1693}     0.0  optimal
# 62     979  {b0523}     0.0  optimal
# 63     983  {b3041}     0.0  optimal
# 64    1000  {b3368}     0.0  optimal
# 65    1022  {b0029}     0.0  optimal
# 66    1024  {b2515}     0.0  optimal
# 67    1027  {b3857}     0.0  optimal
# 68     971  {b3959}     0.0  optimal
# 69     279  {b3771}     0.0  optimal
# 70     285  {b2564}     0.0  optimal
# 71     774  {b3433}     0.0  optimal
# 72     364  {b0417}     0.0  optimal
# 73     568  {b2023}     0.0  optimal
# 74     368  {b2312}     0.0  optimal
# 75     549  {b4177}     0.0  optimal
# 76     548  {b0914}     0.0  optimal
# 77     374  {b2476}     0.0  optimal
# 78     375  {b0003}     0.0  optimal
# 79     542  {b0090}     0.0  optimal
# 80     540  {b3994}     0.0  optimal
# 81     378  {b0133}     0.0  optimal
# 82     539  {b0086}     0.0  optimal
# 83     380  {b3967}     0.0  optimal
# 84     537  {b0907}     0.0  optimal
# 85     519  {b1096}     0.0  optimal
# 86     514  {b1281}     0.0  optimal
# 87     502  {b3412}     0.0  optimal
# 88     391  {b0774}     0.0  optimal
# 89     414  {b2942}     0.0  optimal
# 90     431  {b1262}     0.0  optimal
# 91     412  {b2026}     0.0  optimal
# 92     436  {b0087}     0.0  optimal
# 93     446  {b0775}     0.0  optimal
# 94     447  {b0009}     0.0  optimal
# 95     576  {b0423}     0.0  optimal
# 96     453  {b1136}     0.0  optimal
# 97     475  {b0414}     0.0  optimal
# 98     477  {b1812}     0.0  optimal
# 99     485  {b1094}     0.0  optimal
# 100    396  {b0154}     0.0  optimal
# 101    394  {b0142}     0.0  optimal
# 102    490  {b0173}     0.0  optimal
# 103    457  {b3809}     0.0  optimal
# 104    580  {b4013}     0.0  optimal
# 105    358  {b0783}     0.0  optimal
# 106    356  {b2323}     0.0  optimal
# 107    320  {b3648}     0.0  optimal
# 108    672  {b2507}     0.0  optimal
# 109    685  {b3058}     0.0  optimal
# 110    694  {b2599}     0.0  optimal
# 111    702  {b4261}     0.0  optimal
# 112    706  {b2751}     0.0  optimal
# 113    671  {b0180}     0.0  optimal
# 114    709  {b4006}     0.0  optimal
# 115    729  {b4040}     0.0  optimal
# 116    293  {b0134}     0.0  optimal
# 117    735  {b0915}     0.0  optimal
# 118    756  {b2316}     0.0  optimal
# 119    768  {b3040}     0.0  optimal
# 120    769  {b0182}     0.0  optimal
# 121    723  {b3958}     0.0  optimal
# 122   1109  {b0071}     0.0  optimal
# 123    330  {b1260}     0.0  optimal
# 124    334  {b3941}     0.0  optimal
# 125    583  {b1091}     0.0  optimal
# 126    353  {b0159}     0.0  optimal
# 127    585  {b1263}     0.0  optimal
# 128    591  {b0918}     0.0  optimal
# 129    599  {b0420}     0.0  optimal
# 130    600  {b2153}     0.0  optimal
# 131    333  {b3359}     0.0  optimal
# 132    611  {b2320}     0.0  optimal
# 133    629  {b0415}     0.0  optimal
# 134    340  {b2747}     0.0  optimal
# 135    630  {b0777}     0.0  optimal
# 136    633  {b1264}     0.0  optimal
# 137    649  {b0052}     0.0  optimal
# 138    650  {b0369}     0.0  optimal
# 139    621  {b0826}     0.0  optimal
# 140   1118  {b3992}     0.0  optimal
# 141    941  {b3607}     0.0  optimal
# 142    428  {b3850}     0.0  optimal
# 143   1211  {b3730}     0.0  optimal
# 144   1203  {b0074}     0.0  optimal
# 145   1305  {b0085}     0.0  optimal
# 146    111  {b1277}     0.0  optimal
# 147   1198  {b0181}     0.0  optimal
# 148   1189  {b3255}     0.0  optimal
# 149   1181  {b0785}     0.0  optimal
# 150   1286  {b3807}     0.0  optimal
# 151   1174  {b2315}     0.0  optimal
# 152   1311  {b3189}     0.0  optimal
# 153     46  {b1208}     0.0  optimal
# 154    123  {b2574}     0.0  optimal
# 155     34  {b0778}     0.0  optimal
# 156   1321  {b0166}     0.0  optimal
# 157   1160  {b3172}     0.0  optimal
# 158    127  {b3176}     0.0  optimal
# 159   1168  {b0004}     0.0  optimal
# 160    129  {b2472}     0.0  optimal
# 161   1283  {b1062}     0.0  optimal
# 162   1225  {b3389}     0.0  optimal
# 163     71  {b2838}     0.0  optimal
# 164     81  {b2019}     0.0  optimal
# 165     68  {b4005}     0.0  optimal
# 166   1246  {b0776}     0.0  optimal
# 167   1247  {b2818}     0.0  optimal
# 168     64  {b3729}     0.0  optimal
# 169   1235  {b2764}     0.0  optimal
# 170   1273  {b2600}     0.0  optimal
# 171     88  {b3805}     0.0  optimal
# 172   1233  {b3608}     0.0  optimal
# 173   1259  {b2752}     0.0  optimal
# 174   1261  {b3993}     0.0  optimal
# 175   1267  {b1415}     0.0  optimal
# 176   1229  {b3201}     0.0  optimal
# 177   1227  {b1131}     0.0  optimal
# 178   1268  {b1261}     0.0  optimal
# 179     89  {b4407}     0.0  optimal
# 180   1151  {b3200}     0.0  optimal
# 181   1191  {b0073}     0.0  optimal
# 182   1327  {b0174}     0.0  optimal
# 183     14  {b0386}     0.0  optimal
# 184   1326  {b4245}     0.0  optimal
# 185   1344  {b3843}     0.0  optimal
# 186     11  {b3770}     0.0  optimal
# 187   1354  {b2746}     0.0  optimal
# 188   1339  {b2024}     0.0  optimal
# 189   1337  {b3196}     0.0  optimal
# 190     19  {b1662}     0.0  optimal
# 191   1129  {b3187}     0.0  optimal
# 192   1355  {b3972}     0.0  optimal
# 193   1333  {s0001}     0.0  optimal
# 194     16  {b2103}     0.0  optimal
# 195    134  {b2311}     0.0  optimal
# 196      7  {b2022}     0.0  optimal
# 197   1125  {b0096}     0.0  optimal
# 198      5  {b0088}     0.0  optimal
# 199      4  {b3990}     0.0  optimal
# 200     21  {b3018}     0.0  optimal
# 201   1332  {b1215}     0.0  optimal
# 202    137  {b0109}     0.0  optimal
# 203   1123  {b0131}     0.0  optimal
# 204     25  {b2025}     0.0  optimal
# 205   1122  {b4160}     0.0  optimal
# 206   1362  {b3633}     0.0  optimal
# 207    430  {b1740}     0.0  optimal

# %% [markdown]
# For the iJO1366 *E. coli* model under default conditions there are 207 essential genes. Note that the essential genes will change with the inital conditions of the model. A different carbon source, nitrogen source, oxygen level, etc. will each have different essential genes.

# %% [markdown]
# ## Essential Reactions
#
# An essential reaction is a reactions that when knocked out prevents cell growth!
#
# As with genes, this can also be done for reactions

# %%
SingleReactionDeletions = single_reaction_deletion(model, model.reactions)
SingleReactionDeletions = SingleReactionDeletions.sort_values('growth') # Sorting the growth-rate values
SingleReactionDeletions = SingleReactionDeletions.reset_index() # Renumbering the rows
SingleReactionDeletions.round(4)[0:100]
# Out:
#     index             ids  growth   status
# 0    2491        {DPCOAK}    -0.0  optimal
# 1     879          {PNTK}    -0.0  optimal
# 2       0         {SHCHF}     0.0  optimal
# 3    2130      {OPMEACPD}     0.0  optimal
# 4     731        {EX_k_e}     0.0  optimal
# 5    2119          {HMBS}     0.0  optimal
# 6     735         {PSCVT}     0.0  optimal
# 7     737        {UAGAAT}     0.0  optimal
# 8     743         {UAPGR}     0.0  optimal
# 9     751   {DM_4crsol_c}     0.0  optimal
# 10    728      {EX_ca2_e}     0.0  optimal
# 11    755         {DHAD2}     0.0  optimal
# 12    810        {AOXSr2}     0.0  optimal
# 13    817        {LPADSS}     0.0  optimal
# 14    826        {OCTDPS}     0.0  optimal
# 15   2098        {AICART}     0.0  optimal
# 16   2103        {IPPMIb}     0.0  optimal
# 17   2467         {MOAT2}     0.0  optimal
# 18    719          {ASPK}     0.0  optimal
# 19   2141      {EX_mg2_e}     0.0  optimal
# 20    670   {K2L4Aabctex}     0.0  optimal
# 21    235           {HSK}     0.0  optimal
# 22   2163      {OGMEACPR}     0.0  optimal
# 23    676            {CS}     0.0  optimal
# 24    694         {UAMAS}     0.0  optimal
# 25    695         {HPPK2}     0.0  optimal
# 26    696       {MOBDtex}     0.0  optimal
# 27   2157      {OPMEACPS}     0.0  optimal
# 28   2411          {TYRL}     0.0  optimal
# 29    705       {BMOGDS2}     0.0  optimal
# 30   2419          {ALAR}     0.0  optimal
# 31   2426     {EX_meoh_e}     0.0  optimal
# 32   2148       {AHCYSNS}     0.0  optimal
# 33   2142      {EX_nh4_e}     0.0  optimal
# 34   2448      {MECDPDH5}     0.0  optimal
# 35   2137         {METAT}     0.0  optimal
# 36    870      {MEOHtrpp}     0.0  optimal
# 37    871         {SDPDS}     0.0  optimal
# 38   2086        {ACCOAC}     0.0  optimal
# 39   1975         {PRAIS}     0.0  optimal
# 40   1969         {ANPRT}     0.0  optimal
# 41   1000        {HBZOPT}     0.0  optimal
# 42   1961          {SULR}     0.0  optimal
# 43   1013         {ARGSL}     0.0  optimal
# 44   1959     {MOBDabcpp}     0.0  optimal
# 45    987  {EX_cobalt2_e}     0.0  optimal
# 46   2322       {MEOHtex}     0.0  optimal
# 47    161          {ADSS}     0.0  optimal
# 48   1952         {PPNDH}     0.0  optimal
# 49   1027        {MTHFR2}     0.0  optimal
# 50   1052         {PRAIi}     0.0  optimal
# 51   1935       {GTPCII2}     0.0  optimal
# 52   1933    {COBALT2tex}     0.0  optimal
# 53   1019   {DM_mththf_c}     0.0  optimal
# 54    976        {CU2tpp}     0.0  optimal
# 55   1986          {RBFK}     0.0  optimal
# 56    961         {KARA2}     0.0  optimal
# 57   2078         {MOCOS}     0.0  optimal
# 58    193        {CU2tex}     0.0  optimal
# 59    881    {COBALT2tpp}     0.0  optimal
# 60    890         {GMPS2}     0.0  optimal
# 61    891       {PSSA161}     0.0  optimal
# 62   2050         {OMPDC}     0.0  optimal
# 63   2042         {CHRPL}     0.0  optimal
# 64    920         {KDOPP}     0.0  optimal
# 65    927        {AMPMS2}     0.0  optimal
# 66   2029       {U23GAAT}     0.0  optimal
# 67   2016          {P5CR}     0.0  optimal
# 68   2014         {ASPCT}     0.0  optimal
# 69   2003         {DHAD1}     0.0  optimal
# 70    942         {ASPTA}     0.0  optimal
# 71    944       {UDCPDPS}     0.0  optimal
# 72    669       {BMOGDS1}     0.0  optimal
# 73   2164         {DMATT}     0.0  optimal
# 74    239        {UGMDDS}     0.0  optimal
# 75    656        {APRAUR}     0.0  optimal
# 76    380         {ARGSS}     0.0  optimal
# 77   2348          {ACLS}     0.0  optimal
# 78    381          {DDPA}     0.0  optimal
# 79    299         {SADT2}     0.0  optimal
# 80    399       {MOADSUx}     0.0  optimal
# 81    297        {PRAMPC}     0.0  optimal
# 82   2248        {PRATPP}     0.0  optimal
# 83   2247          {TMDS}     0.0  optimal
# 84    406         {ACOTA}     0.0  optimal
# 85    293      {EX_cu2_e}     0.0  optimal
# 86    418         {QULNS}     0.0  optimal
# 87   2227        {DNTPPA}     0.0  optimal
# 88   2224          {METS}     0.0  optimal
# 89   2219      {DHPTDCs2}     0.0  optimal
# 90   2214        {Zn2tex}     0.0  optimal
# 91    378         {CPMPS}     0.0  optimal
# 92    431         {G3PD2}     0.0  optimal
# 93    374        {NH4tex}     0.0  optimal
# 94   2261         {PGAMT}     0.0  optimal
# 95    332         {NDPK4}     0.0  optimal
# 96    336         {RBFSa}     0.0  optimal
# 97    323        {A5PISO}     0.0  optimal
# 98   2317         {MNtex}     0.0  optimal
# 99   2291      {AGPAT161}     0.0  optimal

# %% [markdown]
# Creating a histogram of the reaction's growth-rates.

# %%
SingleReactionDeletions.growth.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Let's plot the values of the reaction growth-rates starting from zero to the largest value.

# %%
ax = SingleReactionDeletions.growth.plot.bar().axes
ax.figure.set_size_inches(16, 9)

# %% [markdown]
# The essential reactions can be found by

# %%
essentialReactions = SingleReactionDeletions.loc[SingleReactionDeletions['growth'] < 0.001]
essentialReactions = essentialReactions.reset_index() # Renumber the rows
essentialReactions.round(4)
# Out:
#      level_0  index                               ids  growth   status
# 0          0   2491                          {DPCOAK}    -0.0  optimal
# 1          1    879                            {PNTK}    -0.0  optimal
# 2          2      0                           {SHCHF}     0.0  optimal
# 3          3   2130                        {OPMEACPD}     0.0  optimal
# 4          4    731                          {EX_k_e}     0.0  optimal
# 5          5   2119                            {HMBS}     0.0  optimal
# 6          6    735                           {PSCVT}     0.0  optimal
# 7          7    737                          {UAGAAT}     0.0  optimal
# 8          8    743                           {UAPGR}     0.0  optimal
# 9          9    751                     {DM_4crsol_c}     0.0  optimal
# 10        10    728                        {EX_ca2_e}     0.0  optimal
# 11        11    755                           {DHAD2}     0.0  optimal
# 12        12    810                          {AOXSr2}     0.0  optimal
# 13        13    817                          {LPADSS}     0.0  optimal
# 14        14    826                          {OCTDPS}     0.0  optimal
# 15        15   2098                          {AICART}     0.0  optimal
# 16        16   2103                          {IPPMIb}     0.0  optimal
# 17        17   2467                           {MOAT2}     0.0  optimal
# 18        18    719                            {ASPK}     0.0  optimal
# 19        19   2141                        {EX_mg2_e}     0.0  optimal
# 20        20    670                     {K2L4Aabctex}     0.0  optimal
# 21        21    235                             {HSK}     0.0  optimal
# 22        22   2163                        {OGMEACPR}     0.0  optimal
# 23        23    676                              {CS}     0.0  optimal
# 24        24    694                           {UAMAS}     0.0  optimal
# 25        25    695                           {HPPK2}     0.0  optimal
# 26        26    696                         {MOBDtex}     0.0  optimal
# 27        27   2157                        {OPMEACPS}     0.0  optimal
# 28        28   2411                            {TYRL}     0.0  optimal
# 29        29    705                         {BMOGDS2}     0.0  optimal
# 30        30   2419                            {ALAR}     0.0  optimal
# 31        31   2426                       {EX_meoh_e}     0.0  optimal
# 32        32   2148                         {AHCYSNS}     0.0  optimal
# 33        33   2142                        {EX_nh4_e}     0.0  optimal
# 34        34   2448                        {MECDPDH5}     0.0  optimal
# 35        35   2137                           {METAT}     0.0  optimal
# 36        36    870                        {MEOHtrpp}     0.0  optimal
# 37        37    871                           {SDPDS}     0.0  optimal
# 38        38   2086                          {ACCOAC}     0.0  optimal
# 39        39   1975                           {PRAIS}     0.0  optimal
# 40        40   1969                           {ANPRT}     0.0  optimal
# 41        41   1000                          {HBZOPT}     0.0  optimal
# 42        42   1961                            {SULR}     0.0  optimal
# 43        43   1013                           {ARGSL}     0.0  optimal
# 44        44   1959                       {MOBDabcpp}     0.0  optimal
# 45        45    987                    {EX_cobalt2_e}     0.0  optimal
# 46        46   2322                         {MEOHtex}     0.0  optimal
# 47        47    161                            {ADSS}     0.0  optimal
# 48        48   1952                           {PPNDH}     0.0  optimal
# 49        49   1027                          {MTHFR2}     0.0  optimal
# 50        50   1052                           {PRAIi}     0.0  optimal
# 51        51   1935                         {GTPCII2}     0.0  optimal
# 52        52   1933                      {COBALT2tex}     0.0  optimal
# 53        53   1019                     {DM_mththf_c}     0.0  optimal
# 54        54    976                          {CU2tpp}     0.0  optimal
# 55        55   1986                            {RBFK}     0.0  optimal
# 56        56    961                           {KARA2}     0.0  optimal
# 57        57   2078                           {MOCOS}     0.0  optimal
# 58        58    193                          {CU2tex}     0.0  optimal
# 59        59    881                      {COBALT2tpp}     0.0  optimal
# 60        60    890                           {GMPS2}     0.0  optimal
# 61        61    891                         {PSSA161}     0.0  optimal
# 62        62   2050                           {OMPDC}     0.0  optimal
# 63        63   2042                           {CHRPL}     0.0  optimal
# 64        64    920                           {KDOPP}     0.0  optimal
# 65        65    927                          {AMPMS2}     0.0  optimal
# 66        66   2029                         {U23GAAT}     0.0  optimal
# 67        67   2016                            {P5CR}     0.0  optimal
# 68        68   2014                           {ASPCT}     0.0  optimal
# 69        69   2003                           {DHAD1}     0.0  optimal
# 70        70    942                           {ASPTA}     0.0  optimal
# 71        71    944                         {UDCPDPS}     0.0  optimal
# 72        72    669                         {BMOGDS1}     0.0  optimal
# 73        73   2164                           {DMATT}     0.0  optimal
# 74        74    239                          {UGMDDS}     0.0  optimal
# 75        75    656                          {APRAUR}     0.0  optimal
# 76        76    380                           {ARGSS}     0.0  optimal
# 77        77   2348                            {ACLS}     0.0  optimal
# 78        78    381                            {DDPA}     0.0  optimal
# 79        79    299                           {SADT2}     0.0  optimal
# 80        80    399                         {MOADSUx}     0.0  optimal
# 81        81    297                          {PRAMPC}     0.0  optimal
# 82        82   2248                          {PRATPP}     0.0  optimal
# 83        83   2247                            {TMDS}     0.0  optimal
# 84        84    406                           {ACOTA}     0.0  optimal
# 85        85    293                        {EX_cu2_e}     0.0  optimal
# 86        86    418                           {QULNS}     0.0  optimal
# 87        87   2227                          {DNTPPA}     0.0  optimal
# 88        88   2224                            {METS}     0.0  optimal
# 89        89   2219                        {DHPTDCs2}     0.0  optimal
# 90        90   2214                          {Zn2tex}     0.0  optimal
# 91        91    378                           {CPMPS}     0.0  optimal
# 92        92    431                           {G3PD2}     0.0  optimal
# 93        93    374                          {NH4tex}     0.0  optimal
# 94        94   2261                           {PGAMT}     0.0  optimal
# 95        95    332                           {NDPK4}     0.0  optimal
# 96        96    336                           {RBFSa}     0.0  optimal
# 97        97    323                          {A5PISO}     0.0  optimal
# 98        98   2317                           {MNtex}     0.0  optimal
# 99        99   2291                        {AGPAT161}     0.0  optimal
# 100      100   2288                           {ACODA}     0.0  optimal
# 101      101   2286                            {UMPK}     0.0  optimal
# 102      102    345                          {BMOCOS}     0.0  optimal
# 103      103    351                            {GLNS}     0.0  optimal
# 104      104   2280                          {UAMAGS}     0.0  optimal
# 105      105    357                            {PERD}     0.0  optimal
# 106      106    312                            {Ktex}     0.0  optimal
# 107      107   2266                          {CAt6pp}     0.0  optimal
# 108      108    310                          {GLUPRT}     0.0  optimal
# 109      109   2264                          {G1PACT}     0.0  optimal
# 110      110   2256                           {SDPTA}     0.0  optimal
# 111      111   1930                          {PRMICI}     0.0  optimal
# 112      112    449                         {EX_cl_e}     0.0  optimal
# 113      113   2212                          {SHK3Dr}     0.0  optimal
# 114      114   2174                           {HISTP}     0.0  optimal
# 115      115   2384                         {3OAS140}     0.0  optimal
# 116      116    539                            {DXPS}     0.0  optimal
# 117      117    546                           {NDPK2}     0.0  optimal
# 118      118    252                         {PMEACPE}     0.0  optimal
# 119      119    588                         {3OAR140}     0.0  optimal
# 120      120    602                          {GLUTRS}     0.0  optimal
# 121      121    635                            {PPND}     0.0  optimal
# 122      122    247                          {PTPATi}     0.0  optimal
# 123      123    246                            {E4PD}     0.0  optimal
# 124      124    245                          {CDPMEK}     0.0  optimal
# 125      125   2399                      {DM_5drib_c}     0.0  optimal
# 126      126    637                            {IPMD}     0.0  optimal
# 127      127    642                            {PMPK}     0.0  optimal
# 128      128    650                            {ADCS}     0.0  optimal
# 129      129   2177                           {TYRTA}     0.0  optimal
# 130      130    450                           {HISTD}     0.0  optimal
# 131      131    529                        {DASYN160}     0.0  optimal
# 132      132    520                        {EX_mn2_e}     0.0  optimal
# 133      133    469                           {NADS1}     0.0  optimal
# 134      134    472                           {NNDPR}     0.0  optimal
# 135      135    478                            {TDSK}     0.0  optimal
# 136      136   2196                          {G5SADs}     0.0  optimal
# 137      137    275                            {HSDy}     0.0  optimal
# 138      138   2182                          {PSD160}     0.0  optimal
# 139      139   2355                          {PRAGSr}     0.0  optimal
# 140      140   2181                          {MECDPS}     0.0  optimal
# 141      141   2178                           {DTMPK}     0.0  optimal
# 142      142    493                           {MPTSS}     0.0  optimal
# 143      143    500                        {DASYN161}     0.0  optimal
# 144      144    266                          {THRD_L}     0.0  optimal
# 145      145   2360                             {DPR}     0.0  optimal
# 146      146   2361                           {DAPDC}     0.0  optimal
# 147      147   2362                          {ICDHyr}     0.0  optimal
# 148      148   2371                            {MPTS}     0.0  optimal
# 149      149   1061                            {IMPC}     0.0  optimal
# 150      150   1018                           {MOHMT}     0.0  optimal
# 151      151    149                           {CYSTL}     0.0  optimal
# 152      152   1753                        {OGMEACPS}     0.0  optimal
# 153      153   2512                          {PSD161}     0.0  optimal
# 154      154     63                            {GLUR}     0.0  optimal
# 155      155   1752                          {ACONTb}     0.0  optimal
# 156      156   1420                            {MOAT}     0.0  optimal
# 157      157   2513                            {SHKK}     0.0  optimal
# 158      158   1422                           {AIRC3}     0.0  optimal
# 159      159   1746                            {ADSK}     0.0  optimal
# 160      160   1743                            {DHQS}     0.0  optimal
# 161      161   1432                           {IG3PS}     0.0  optimal
# 162      162   1449                          {LEUTAi}     0.0  optimal
# 163      163   1723                          {ACONTa}     0.0  optimal
# 164      164   1720                        {MALCOAMT}     0.0  optimal
# 165      165   1455                        {EX_zn2_e}     0.0  optimal
# 166      166   1716                           {UAGDP}     0.0  optimal
# 167      167   1755                           {KDOPS}     0.0  optimal
# 168      168   1463                           {PItex}     0.0  optimal
# 169      169   1756                         {ALAALAr}     0.0  optimal
# 170      170   1412                          {GCALDD}     0.0  optimal
# 171      171   1821                           {RBFSb}     0.0  optimal
# 172      172   1355                      {PE161abcpp}     0.0  optimal
# 173      173   1813                           {NNATr}     0.0  optimal
# 174      174   1368                          {UPP3MT}     0.0  optimal
# 175      175   1370                          {PDX5PS}     0.0  optimal
# 176      176   1801                        {AGPAT160}     0.0  optimal
# 177      177   1381                           {DHDPS}     0.0  optimal
# 178      178   1382                           {UPP3S}     0.0  optimal
# 179      179     77                            {TMPK}     0.0  optimal
# 180      180   1388                          {ICYSDS}     0.0  optimal
# 181      181   1776                            {ADCL}     0.0  optimal
# 182      182    150                         {THZPSN3}     0.0  optimal
# 183      183   1775                            {AGPR}     0.0  optimal
# 184      184   1773                            {OCBT}     0.0  optimal
# 185      185   1766                          {NH4tpp}     0.0  optimal
# 186      186   2505                           {DHPS2}     0.0  optimal
# 187      187   1824                            {IPPS}     0.0  optimal
# 188      188   1709                           {AIRC2}     0.0  optimal
# 189      189   2528                            {DHFR}     0.0  optimal
# 190      190   2556                        {MTHTHFSs}     0.0  optimal
# 191      191   1589                          {OHPBAT}     0.0  optimal
# 192      192   1592                           {SHSL1}     0.0  optimal
# 193      193   1667                       {DM_amob_c}     0.0  optimal
# 194      194   1604                            {DBTS}     0.0  optimal
# 195      195     14                          {UDCPDP}     0.0  optimal
# 196      196   1618                          {KDOCT2}     0.0  optimal
# 197      197   1623                         {PRASCSi}     0.0  optimal
# 198      198   2561                           {CHORS}     0.0  optimal
# 199      199   1648                           {KARA1}     0.0  optimal
# 200      200   1653                          {DXPRIi}     0.0  optimal
# 201      201   2562                           {RHCCE}     0.0  optimal
# 202      202   2566                          {PHETA1}     0.0  optimal
# 203      203   1655                           {HCO3E}     0.0  optimal
# 204      204   2577                           {5DOAN}     0.0  optimal
# 205      205   1578                        {MCTP1App}     0.0  optimal
# 206      206     45                          {MG2tex}     0.0  optimal
# 207      207   1671                          {UHGADA}     0.0  optimal
# 208      208   1554                           {THDPS}     0.0  optimal
# 209      209   1469                           {CLtex}     0.0  optimal
# 210      210   1708                            {MPTG}     0.0  optimal
# 211      211   2538                            {ACGK}     0.0  optimal
# 212      212   1477                            {NADK}     0.0  optimal
# 213      213   1480                         {PSSA160}     0.0  optimal
# 214      214   1512                          {MCOATA}     0.0  optimal
# 215      215   1532                          {ASP1DC}     0.0  optimal
# 216      216     34                             {ANS}     0.0  optimal
# 217      217   1696                          {UAGCVT}     0.0  optimal
# 218      218   1685                          {ADSL2r}     0.0  optimal
# 219      219   1682                        {CLt3_2pp}     0.0  optimal
# 220      220   1546                           {CHORM}     0.0  optimal
# 221      221   1547                        {OPMEACPR}     0.0  optimal
# 222      222   1677                           {TMPPP}     0.0  optimal
# 223      223     26                            {ACGS}     0.0  optimal
# 224      224   1573                        {EX_so4_e}     0.0  optimal
# 225      225   1347                        {EX_ni2_e}     0.0  optimal
# 226      226   2498                         {DHPPDA2}     0.0  optimal
# 227      227   2336                          {DHDPRy}     0.0  optimal
# 228      228   1925                           {G1SAT}     0.0  optimal
# 229      229   1079                          {AMAOTr}     0.0  optimal
# 230      230    114                            {DAPE}     0.0  optimal
# 231      231   1189                            {CYSS}     0.0  optimal
# 232      232   1175                          {PPBNGS}     0.0  optimal
# 233      233   1914                          {SO4tex}     0.0  optimal
# 234      234    141                            {ASAD}     0.0  optimal
# 235      235   1846                         {EX_pi_e}     0.0  optimal
# 236      236   1850                           {GTPCI}     0.0  optimal
# 237      237   1910                            {IGPS}     0.0  optimal
# 238      238   1093                           {MPTAT}     0.0  optimal
# 239      239    120                            {GRTT}     0.0  optimal
# 240      240   1907                           {ILETA}     0.0  optimal
# 241      241   1905                            {USHD}     0.0  optimal
# 242      242   1889                         {DHNPA2r}     0.0  optimal
# 243      243   1157                           {OMCDC}     0.0  optimal
# 244      244   1831                          {NI2tex}     0.0  optimal
# 245      245   1866                           {IGPDH}     0.0  optimal
# 246      246   1119                           {DB4PS}     0.0  optimal
# 247      247   1141                          {OPHBDC}     0.0  optimal
# 248      248   1871                            {ORPT}     0.0  optimal
# 249      249   1880                          {SHCHD2}     0.0  optimal
# 250      250   1127                          {IPPMIa}     0.0  optimal
# 251      251   1875                          {DHORTS}     0.0  optimal
# 252      252   2482                      {K2L4Aabcpp}     0.0  optimal
# 253      253   1137                          {ATPPRT}     0.0  optimal
# 254      254   1876                          {GF6PTA}     0.0  optimal
# 255      255   1129  {BIOMASS_Ec_iJO1366_core_53p95M}     0.0  optimal
# 256      256   1196                       {EX_mobd_e}     0.0  optimal
# 257      257    113                           {PRFGS}     0.0  optimal
# 258      258    145                            {FCLT}     0.0  optimal
# 259      259   1339                          {CA2tex}     0.0  optimal
# 260      260   1833                           {FMNAT}     0.0  optimal
# 261      261   1836                        {EGMEACPR}     0.0  optimal
# 262      262   1333                            {HSST}     0.0  optimal
# 263      263   1322                          {PAPPT3}     0.0  optimal
# 264      264   1317                           {CTPS2}     0.0  optimal
# 265      265   1839                             {GK1}     0.0  optimal
# 266      266   1307                          {PPNCL2}     0.0  optimal
# 267      267   1301                           {HSTPT}     0.0  optimal
# 268      268   1280                            {BPNT}     0.0  optimal
# 269      269     99                            {BTS5}     0.0  optimal
# 270      270    100                          {PMDPHT}     0.0  optimal
# 271      271   1197                      {PE160abcpp}     0.0  optimal
# 272      272    102                           {MEPCT}     0.0  optimal
# 273      273   2493                        {EPMEACPR}     0.0  optimal
# 274      274   1071                           {DHQTi}     0.0  optimal
# 275      275   1074                          {GLUTRR}     0.0  optimal
# 276      276   1215                        {OGMEACPD}     0.0  optimal
# 277      277   1262                          {UAGPT3}     0.0  optimal
# 278      278   1241                          {UPPDC1}     0.0  optimal
# 279      279   1128                           {SERAT}     0.0  optimal
# 280      280   1252                            {DHFS}     0.0  optimal
# 281      281    105                          {UAAGDS}     0.0  optimal
# 282      282   1073                           {ACHBS}     0.0  optimal
# 283      283   1246                            {THRS}     0.0  optimal
# 284      284   2104                           {PPCDC}     0.0  optimal
# 285      285      8                          {ADSL1r}     0.0  optimal
# 286      286    869                          {DNMPPA}     0.0  optimal
# 287      287   1479                           {PANTS}     0.0  optimal

# %% [markdown]
# Note their are 287 essential reactions for the default model conditions.
