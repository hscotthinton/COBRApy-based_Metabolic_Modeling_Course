# %% [markdown]
# # Nitrogen Sources in the *E.coli* Core Model

# %%
import cobra.test
from cobra.test import create_test_model
import escher
from escher import Builder
import numpy as np
import pandas as pd
from cobrapy_bigg_client import client
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)
model_orig = client.download_model('iJO1366', save=False) # Download model from the BIGG database
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %% [markdown]
# ## Exchange Reactions (Potential Nitrogen Sources) that Allow Aerobic Growth
#
# Find the exchange reactions that allow growth in an aerobic environment.

# %%
model = model_orig.copy()
exchange_ids = []
growth_rate = []
exchange_ids = [r.id for r in model.exchanges]
model.reactions.EX_o2_e.lower_bound = -1000
model.reactions.EX_nh4_e.lower_bound = -0
for i in range(len(exchange_ids)):
    temp = model.reactions.get_by_id(exchange_ids[i]).lower_bound 
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = -20
    x = model.slim_optimize()
    growth_rate.append(x)
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = temp

# %%
Aerobic_nitrogen_growth_rate = {'Exchange Reaction': exchange_ids,
                     'Aerobic Growth Rate': growth_rate}
Aerobic_df = pd.DataFrame(Aerobic_nitrogen_growth_rate, columns = ['Exchange Reaction','Aerobic Growth Rate'])
df1 = Aerobic_df
df1 = df1.round(4) # Round to 4 digits
df1 = df1.replace(0, np.nan) # Replace zeros with NaN
df1 = df1.dropna() # Remove rows with NaN values
df1 = df1.reset_index(drop=True)
df1
# Out:
#         Exchange Reaction  Aerobic Growth Rate
# 0                EX_cmp_e               2.7135
# 1             EX_gln__L_e               2.4337
# 2             EX_glu__L_e               1.8517
# 3                EX_gly_e               1.4511
# 4             EX_23camp_e               3.6313
# 5             EX_23ccmp_e               2.7135
# 6             EX_23cgmp_e               3.4969
# 7             EX_23cump_e               2.4920
# 8            EX_23dappa_e               1.7442
# 9                EX_gmp_e               3.4969
# 10               EX_gsn_e               3.4969
# 11             EX_gthrd_e               3.6986
# 12               EX_gua_e               1.7234
# 13              EX_3amp_e               3.6313
# 14              EX_3cmp_e               2.7135
# 15              EX_3gmp_e               3.4969
# 16              EX_hxan_e               1.8351
# 17              EX_3ump_e               2.4920
# 18             EX_4abut_e               1.8517
# 19          EX_LalaDglu_e               3.3800
# 20               EX_imp_e               3.6060
# 21               EX_ins_e               3.6060
# 22      EX_LalaDgluMdap_e               3.4689
# 23  EX_LalaDgluMdapDala_e               4.4600
# 24          EX_LalaLglu_e               3.3800
# 25             EX_acgam_e               1.8517
# 26               EX_csn_e               1.0206
# 27           EX_acgam1p_e               1.8517
# 28            EX_acmana_e               1.8517
# 29             EX_acmum_e               1.8517
# 30             EX_acnam_e               1.8517
# 31               EX_ade_e               1.8382
# 32               EX_adn_e               3.6313
# 33               EX_agm_e               2.6018
# 34            EX_ala__D_e               1.8517
# 35            EX_ala__L_e               1.8517
# 36            EX_alaala_e               2.8633
# 37             EX_alltn_e               1.3683
# 38               EX_amp_e               3.6313
# 39             EX_anhgm_e               3.7034
# 40              EX_cynt_e               1.0031
# 41            EX_cys__D_e               1.7017
# 42            EX_cys__L_e               1.7062
# 43            EX_arg__L_e               2.6838
# 44            EX_asn__L_e               1.9554
# 45            EX_asp__L_e               1.8517
# 46               EX_nh4_e               0.9824
# 47              EX_cytd_e               2.7135
# 48              EX_cgly_e               2.2061
# 49                EX_no_e               0.8214
# 50               EX_no2_e               0.8660
# 51               EX_no3_e               0.8492
# 52               EX_orn_e               2.6335
# 53              EX_orot_e               0.8816
# 54             EX_peamn_e               1.8517
# 55             EX_chtbs_e               3.7034
# 56             EX_dad_2_e               3.7560
# 57              EX_damp_e               3.7560
# 58              EX_dcmp_e               2.8054
# 59            EX_pro__L_e               1.8517
# 60              EX_dcyt_e               2.8054
# 61            EX_progly_e               2.9615
# 62           EX_pser__L_e               1.7634
# 63              EX_ptrc_e               2.6018
# 64              EX_dgmp_e               3.6079
# 65              EX_dgsn_e               3.6079
# 66               EX_xan_e               1.6985
# 67               EX_xmp_e               3.4660
# 68              EX_dimp_e               3.7288
# 69               EX_din_e               3.7288
# 70              EX_xtsn_e               3.4660
# 71            EX_ser__D_e               1.7634
# 72            EX_ser__L_e               1.7634
# 73              EX_dopa_e               0.9824
# 74            EX_thr__L_e               1.8517
# 75              EX_thrp_e               1.8517
# 76              EX_dump_e               2.5873
# 77              EX_duri_e               2.5873
# 78            EX_trp__L_e               1.7822
# 79              EX_etha_e               1.7237
# 80               EX_tym_e               0.9824
# 81            EX_uacgam_e               5.0263
# 82          EX_udpacgal_e               2.4920
# 83              EX_udpg_e               3.7034
# 84            EX_udpgal_e               3.7034
# 85          EX_udpglcur_e               3.7034
# 86               EX_ump_e               2.4920
# 87               EX_ura_e               0.8986
# 88               EX_uri_e               2.4920
# 89              EX_g3pe_e               1.8517
# 90              EX_g3ps_e               1.8517
# 91               EX_gam_e               1.8517
# 92             EX_gam6p_e               1.8517

# %% [markdown]
# The total number of metabolites (exhange reactions) that can grow in aerobic conditions

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exchange Reaction    93 non-null     object
#  1   Aerobic Growth Rate  93 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# A histogram of the aerobic growth rates from the different exchange reactions

# %%
df1.hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Aerobic Growth Rate'}>]],
#       dtype=object)

# %% [markdown]
# ## Exchange Reactions (Potential Nitrogen Sources) that Allow Anaerobic Growth
#
# Find the exchange reactions that allow growth in an anaerobic environment.

# %%
model = model_orig.copy()
exchange_ids = []
growth_rate = []
exchange_ids = [r.id for r in model.exchanges]
model.reactions.EX_o2_e.lower_bound = 0
model.reactions.EX_nh4_e.lower_bound = -0
for i in range(len(exchange_ids)):
    temp = model.reactions.get_by_id(exchange_ids[i]).lower_bound 
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = -20
    x = model.slim_optimize()
    growth_rate.append(x)
    model.reactions.get_by_id(exchange_ids[i]).lower_bound = temp

# %%
Anaerobic_nitrogen_growth_rate = {'Exchange Reaction': exchange_ids,
                     'Anaerobic Growth Rate': growth_rate}
Anaerobic_df = pd.DataFrame(Anaerobic_nitrogen_growth_rate, columns = ['Exchange Reaction','Anaerobic Growth Rate'])
df2 = Anaerobic_df
df2 = df2.round(4) # Round to 4 digits
df2 = df2.replace(0, np.nan) # Replace zero with NaN
df2 = df2.dropna() # Remove rows with NaN
df2 = df2.reset_index(drop=True)
df2
# Out:
#         Exchange Reaction  Anaerobic Growth Rate
# 0                EX_cmp_e                 1.0002
# 1             EX_gln__L_e                 0.5610
# 2             EX_glu__L_e                 0.5579
# 3                EX_gly_e                 0.2768
# 4             EX_23camp_e                 1.0088
# 5             EX_23ccmp_e                 1.0002
# 6             EX_23cgmp_e                 1.1252
# 7            EX_23dappa_e                 0.4073
# 8                EX_gmp_e                 1.1252
# 9                EX_gsn_e                 1.1252
# 10             EX_gthrd_e                 0.6873
# 11               EX_gua_e                 0.4611
# 12              EX_3amp_e                 1.0088
# 13              EX_3cmp_e                 1.0002
# 14              EX_3gmp_e                 1.1252
# 15              EX_hxan_e                 0.2710
# 16             EX_4abut_e                 0.2165
# 17          EX_LalaDglu_e                 0.7366
# 18               EX_imp_e                 0.9452
# 19               EX_ins_e                 0.9452
# 20      EX_LalaDgluMdap_e                 0.5658
# 21  EX_LalaDgluMdapDala_e                 0.7470
# 22          EX_LalaLglu_e                 0.7366
# 23             EX_acgam_e                 0.8503
# 24               EX_csn_e                 0.3023
# 25           EX_acgam1p_e                 0.8503
# 26            EX_acmana_e                 0.8503
# 27             EX_acmum_e                 0.9609
# 28             EX_acnam_e                 1.0163
# 29               EX_ade_e                 0.2724
# 30               EX_adn_e                 1.0088
# 31               EX_agm_e                 0.2217
# 32            EX_ala__D_e                 0.3643
# 33            EX_ala__L_e                 0.3643
# 34            EX_alaala_e                 0.5931
# 35             EX_alltn_e                 0.5455
# 36               EX_amp_e                 1.0088
# 37             EX_anhgm_e                 1.5141
# 38              EX_cynt_e                 0.2968
# 39            EX_cys__D_e                 0.2433
# 40            EX_cys__L_e                 0.2450
# 41            EX_arg__L_e                 0.3123
# 42            EX_asn__L_e                 0.4935
# 43            EX_asp__L_e                 0.4921
# 44               EX_nh4_e                 0.2415
# 45              EX_cytd_e                 1.0002
# 46              EX_cgly_e                 0.3372
# 47               EX_no2_e                 0.7551
# 48               EX_no3_e                 0.8198
# 49               EX_orn_e                 0.2774
# 50             EX_chtbs_e                 1.4588
# 51             EX_dad_2_e                 0.9306
# 52              EX_damp_e                 0.9306
# 53              EX_dcmp_e                 0.9218
# 54            EX_pro__L_e                 0.2460
# 55              EX_dcyt_e                 0.9218
# 56            EX_progly_e                 0.2512
# 57           EX_pser__L_e                 0.4189
# 58              EX_ptrc_e                 0.2217
# 59              EX_dgmp_e                 1.0471
# 60              EX_dgsn_e                 1.0471
# 61               EX_xan_e                 0.3984
# 62               EX_xmp_e                 1.0556
# 63              EX_dimp_e                 0.8674
# 64               EX_din_e                 0.8674
# 65              EX_xtsn_e                 1.0556
# 66            EX_ser__D_e                 0.4189
# 67            EX_ser__L_e                 0.4189
# 68            EX_thr__L_e                 0.3982
# 69              EX_thrp_e                 0.3982
# 70            EX_trp__L_e                 0.4653
# 71              EX_etha_e                 0.2968
# 72            EX_uacgam_e                 1.5612
# 73              EX_g3pe_e                 0.7647
# 74              EX_g3ps_e                 0.9005
# 75               EX_gam_e                 0.7950
# 76             EX_gam6p_e                 0.9609

# %% [markdown]
# The total number of metabolites (exhange reactions) that can grow in anaerobic conditions

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Exchange Reaction      77 non-null     object
#  1   Anaerobic Growth Rate  77 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# A histogram of the anaerobic growth rates from the different exchange reactions

# %%
df2.hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Anaerobic Growth Rate'}>]],
#       dtype=object)

# %% [markdown]
# ## Growth Rate Table for Exchange Reactions
# Create a table showing the growth rates of the exchange reactions in both aerobic and anaerobic conditions.

# %%
df3 = Aerobic_df.join(Anaerobic_df.set_index('Exchange Reaction'), on='Exchange Reaction')
df3 = df3.round(4) # Round to four digits
df3 = df3.replace(0, np.nan) # Replace zero with NaN
df3 = df3.dropna(how = 'all', subset=['Aerobic Growth Rate', 'Anaerobic Growth Rate']) # Remove NaN's found in both columns
df3 = df3.replace(np.nan, 0)
df3 = df3.reset_index(drop=True)
df3
# Out:
#         Exchange Reaction  Aerobic Growth Rate  Anaerobic Growth Rate
# 0                EX_cmp_e               2.7135                 1.0002
# 1             EX_gln__L_e               2.4337                 0.5610
# 2             EX_glu__L_e               1.8517                 0.5579
# 3                EX_gly_e               1.4511                 0.2768
# 4             EX_23camp_e               3.6313                 1.0088
# 5             EX_23ccmp_e               2.7135                 1.0002
# 6             EX_23cgmp_e               3.4969                 1.1252
# 7             EX_23cump_e               2.4920                 0.0000
# 8            EX_23dappa_e               1.7442                 0.4073
# 9                EX_gmp_e               3.4969                 1.1252
# 10               EX_gsn_e               3.4969                 1.1252
# 11             EX_gthrd_e               3.6986                 0.6873
# 12               EX_gua_e               1.7234                 0.4611
# 13              EX_3amp_e               3.6313                 1.0088
# 14              EX_3cmp_e               2.7135                 1.0002
# 15              EX_3gmp_e               3.4969                 1.1252
# 16              EX_hxan_e               1.8351                 0.2710
# 17              EX_3ump_e               2.4920                 0.0000
# 18             EX_4abut_e               1.8517                 0.2165
# 19          EX_LalaDglu_e               3.3800                 0.7366
# 20               EX_imp_e               3.6060                 0.9452
# 21               EX_ins_e               3.6060                 0.9452
# 22      EX_LalaDgluMdap_e               3.4689                 0.5658
# 23  EX_LalaDgluMdapDala_e               4.4600                 0.7470
# 24          EX_LalaLglu_e               3.3800                 0.7366
# 25             EX_acgam_e               1.8517                 0.8503
# 26               EX_csn_e               1.0206                 0.3023
# 27           EX_acgam1p_e               1.8517                 0.8503
# 28            EX_acmana_e               1.8517                 0.8503
# 29             EX_acmum_e               1.8517                 0.9609
# 30             EX_acnam_e               1.8517                 1.0163
# 31               EX_ade_e               1.8382                 0.2724
# 32               EX_adn_e               3.6313                 1.0088
# 33               EX_agm_e               2.6018                 0.2217
# 34            EX_ala__D_e               1.8517                 0.3643
# 35            EX_ala__L_e               1.8517                 0.3643
# 36            EX_alaala_e               2.8633                 0.5931
# 37             EX_alltn_e               1.3683                 0.5455
# 38               EX_amp_e               3.6313                 1.0088
# 39             EX_anhgm_e               3.7034                 1.5141
# 40              EX_cynt_e               1.0031                 0.2968
# 41            EX_cys__D_e               1.7017                 0.2433
# 42            EX_cys__L_e               1.7062                 0.2450
# 43            EX_arg__L_e               2.6838                 0.3123
# 44            EX_asn__L_e               1.9554                 0.4935
# 45            EX_asp__L_e               1.8517                 0.4921
# 46               EX_nh4_e               0.9824                 0.2415
# 47              EX_cytd_e               2.7135                 1.0002
# 48              EX_cgly_e               2.2061                 0.3372
# 49                EX_no_e               0.8214                 0.0000
# 50               EX_no2_e               0.8660                 0.7551
# 51               EX_no3_e               0.8492                 0.8198
# 52               EX_orn_e               2.6335                 0.2774
# 53              EX_orot_e               0.8816                 0.0000
# 54             EX_peamn_e               1.8517                 0.0000
# 55             EX_chtbs_e               3.7034                 1.4588
# 56             EX_dad_2_e               3.7560                 0.9306
# 57              EX_damp_e               3.7560                 0.9306
# 58              EX_dcmp_e               2.8054                 0.9218
# 59            EX_pro__L_e               1.8517                 0.2460
# 60              EX_dcyt_e               2.8054                 0.9218
# 61            EX_progly_e               2.9615                 0.2512
# 62           EX_pser__L_e               1.7634                 0.4189
# 63              EX_ptrc_e               2.6018                 0.2217
# 64              EX_dgmp_e               3.6079                 1.0471
# 65              EX_dgsn_e               3.6079                 1.0471
# 66               EX_xan_e               1.6985                 0.3984
# 67               EX_xmp_e               3.4660                 1.0556
# 68              EX_dimp_e               3.7288                 0.8674
# 69               EX_din_e               3.7288                 0.8674
# 70              EX_xtsn_e               3.4660                 1.0556
# 71            EX_ser__D_e               1.7634                 0.4189
# 72            EX_ser__L_e               1.7634                 0.4189
# 73              EX_dopa_e               0.9824                 0.0000
# 74            EX_thr__L_e               1.8517                 0.3982
# 75              EX_thrp_e               1.8517                 0.3982
# 76              EX_dump_e               2.5873                 0.0000
# 77              EX_duri_e               2.5873                 0.0000
# 78            EX_trp__L_e               1.7822                 0.4653
# 79              EX_etha_e               1.7237                 0.2968
# 80               EX_tym_e               0.9824                 0.0000
# 81            EX_uacgam_e               5.0263                 1.5612
# 82          EX_udpacgal_e               2.4920                 0.0000
# 83              EX_udpg_e               3.7034                 0.0000
# 84            EX_udpgal_e               3.7034                 0.0000
# 85          EX_udpglcur_e               3.7034                 0.0000
# 86               EX_ump_e               2.4920                 0.0000
# 87               EX_ura_e               0.8986                 0.0000
# 88               EX_uri_e               2.4920                 0.0000
# 89              EX_g3pe_e               1.8517                 0.7647
# 90              EX_g3ps_e               1.8517                 0.9005
# 91               EX_gam_e               1.8517                 0.7950
# 92             EX_gam6p_e               1.8517                 0.9609

# %% [markdown]
# The total number of metabolites (exhange reactions) that can grow in either aerobic or anaerobic conditions

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Exchange Reaction      93 non-null     object
#  1   Aerobic Growth Rate    93 non-null     float64
#  2   Anaerobic Growth Rate  93 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 2.3+ KB
