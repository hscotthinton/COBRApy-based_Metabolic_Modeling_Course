# %% [markdown]
# # iJO1366 Biomass Precursor Flux Comparison

# %%
import cobra.test
from pandas import DataFrame
import pandas as pd
import escher
from escher import Builder
pd.set_option('display.max_rows', 1000)

from cobrapy_bigg_client import client
model = client.download_model('iJO1366', save=False) # Download model from the BIGG database
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-10-10

# %% [markdown]
# ### Find FBA solutions for models with both the core and WT biiomass functions

# %%
with model:
    model.objective = 'BIOMASS_Ec_iJO1366_core_53p95M'
    solution_core = model.optimize()
    
with model:
    model.objective = 'BIOMASS_Ec_iJO1366_WT_53p95M'
    solution_WT = model.optimize()

# %% [markdown]
# ### Finding the difference between the fluxes of the Core and WT biomass functions

# %%
difference = solution_WT.fluxes - solution_core.fluxes
difference.round(4)[0:100]
# Out:
# EX_cm_e                           0.0000
# EX_cmp_e                          0.0000
# EX_co2_e                         -0.0182
# EX_cobalt2_e                      0.0000
# DM_4crsol_c                       0.0000
# DM_5drib_c                        0.0000
# DM_aacald_c                       0.0000
# DM_amob_c                         0.0000
# DM_mththf_c                       0.0009
# EX_colipa_e                       0.0000
# DM_oxam_c                         0.0000
# EX_glc__D_e                       0.0000
# EX_glcn_e                         0.0000
# BIOMASS_Ec_iJO1366_WT_53p95M      0.9865
# EX_glcr_e                         0.0000
# EX_colipap_e                      0.0000
# EX_glcur_e                        0.0000
# EX_glcur1p_e                      0.0000
# BIOMASS_Ec_iJO1366_core_53p95M   -0.9824
# EX_12ppd__R_e                     0.0000
# EX_gln__L_e                       0.0000
# EX_cpgn_e                         0.0000
# EX_glu__L_e                       0.0000
# EX_gly_e                          0.0000
# EX_glyald_e                       0.0000
# EX_glyb_e                         0.0000
# EX_glyc_e                         0.0000
# EX_12ppd__S_e                     0.0000
# EX_14glucan_e                     0.0000
# EX_cpgn_un_e                      0.0000
# EX_15dap_e                        0.0000
# EX_glyc__R_e                      0.0000
# EX_glyc2p_e                       0.0000
# EX_23camp_e                       0.0000
# EX_23ccmp_e                       0.0000
# EX_23cgmp_e                       0.0000
# EX_23cump_e                       0.0000
# EX_23dappa_e                      0.0000
# EX_26dap__M_e                     0.0000
# EX_glyc3p_e                       0.0000
# EX_glyclt_e                       0.0000
# EX_gmp_e                          0.0000
# EX_gsn_e                          0.0000
# EX_gthox_e                        0.0000
# EX_gthrd_e                        0.0000
# EX_gtp_e                          0.0000
# EX_gua_e                          0.0000
# EX_h_e                           -0.2733
# EX_h2_e                           0.0000
# EX_h2o_e                         -0.5228
# EX_h2o2_e                         0.0000
# EX_h2s_e                          0.0000
# EX_hacolipa_e                     0.0000
# EX_halipa_e                       0.0000
# EX_hdca_e                         0.0000
# EX_hdcea_e                        0.0000
# EX_hg2_e                          0.0000
# EX_his__L_e                       0.0000
# EX_2ddglcn_e                      0.0000
# EX_34dhpac_e                      0.0000
# EX_3amp_e                         0.0000
# EX_3cmp_e                         0.0000
# EX_3gmp_e                         0.0000
# EX_3hcinnm_e                      0.0000
# EX_3hpp_e                         0.0000
# EX_3hpppn_e                       0.0000
# EX_hom__L_e                       0.0000
# EX_hxa_e                          0.0000
# EX_hxan_e                         0.0000
# EX_idon__L_e                      0.0000
# EX_3ump_e                         0.0000
# EX_4abut_e                        0.0000
# EX_4hoxpacd_e                     0.0000
# EX_5dglcn_e                       0.0000
# EX_5mtr_e                         0.0067
# EX_LalaDglu_e                     0.0000
# EX_ile__L_e                       0.0000
# EX_imp_e                          0.0000
# EX_indole_e                       0.0000
# EX_inost_e                        0.0000
# EX_ins_e                          0.0000
# EX_isetac_e                       0.0000
# EX_k_e                            0.0086
# EX_LalaDgluMdap_e                 0.0000
# EX_LalaDgluMdapDala_e             0.0000
# EX_LalaLglu_e                     0.0000
# EX_kdo2lipid4_e                   0.0000
# EX_ac_e                           0.0000
# EX_crn_e                          0.0000
# EX_acac_e                         0.0000
# EX_acald_e                        0.0000
# EX_lac__D_e                       0.0000
# EX_lac__L_e                       0.0000
# EX_crn__D_e                       0.0000
# EX_lcts_e                         0.0000
# EX_acgal_e                        0.0000
# EX_acgal1p_e                      0.0000
# EX_acgam_e                        0.0000
# EX_leu__L_e                       0.0000
# EX_csn_e                          0.0000
# Name: fluxes, dtype: float64

# %%
print('The number of reactions that have a flux difference between the WT and Core are = ',len(difference))
# Out:
# The number of reactions that have a flux difference between the WT and Core are =  2583

# %% [markdown]
# ### Plot the flux differences on an Escher map.

# %%
builder = Builder(
    map_name='iJO1366.Central metabolism', 
    model_name='iJO1366', 
)
builder
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/iJO1366.json
# Builder()

# %%
builder.reaction_data = difference

# %% [markdown]
# ### Listing the reactions that had a flux difference greater than 0.0001

# %%
diff = difference[difference > 0.0001]
print('The number of reactions that have a flux difference greater than 0.0001 = ',len(diff))
diff
# Out:
# The number of reactions that have a flux difference greater than 0.0001 =  220
# DM_mththf_c                     0.000882
# BIOMASS_Ec_iJO1366_WT_53p95M    0.986514
# EX_5mtr_e                       0.006653
# EX_k_e                          0.008566
# EX_mg2_e                        0.000380
# EX_nh4_e                        0.245829
# EX_ca2_e                        0.000228
# EX_cl_e                         0.000228
# EX_pi_e                         0.032983
# EX_fe2_e                        0.000460
# 5MTRtpp                         0.006653
# AACPS1                          0.008041
# AACPS5                          0.047970
# ACGK                            0.032441
# ACGS                            0.032441
# ACKr                            0.011309
# ACOAD1f                         0.040645
# ACOAD2f                         0.040645
# ACOAD3f                         0.040645
# ACOAD4f                         0.040648
# ACOAD5f                         0.040648
# ACOAD6f                         0.004401
# ACODA                           0.032441
# ACONTa                          0.145434
# ACONTb                          0.145434
# AGMHE                           0.032164
# AGPAT181                        0.023985
# ACt2rpp                         0.000228
# ADCL                            0.000223
# AHCYSNS                         0.000882
# ADCS                            0.000223
# AIRC3                           0.011120
# AKGDH                           0.128200
# ALAALAabcpp                     0.003251
# ADMDC                           0.006653
# ADPT                            0.007542
# ADSK                            0.001012
# AMMQLT8                         0.000220
# ASPTA                           0.064080
# CAt6pp                          0.000228
# CBL1abcpp                       0.000220
# CBL1tonex                       0.000220
# CBLAT                           0.000220
# ATPS4rpp                        0.234170
# BPNT                            0.001012
# CDPMEK                          0.004190
# CO2tex                          0.018238
# CO2tpp                          0.018238
# CLPNS160pp                      0.002904
# CLPNS161pp                      0.002259
# COLIPAabcpp                     0.008041
# COLIPAabctex                    0.008041
# CLPNS181pp                      0.001164
# CYSS                            0.001012
# CPPPGO                          0.000221
# CYSTL                           0.002999
# CYTBO3_4pp                      0.141106
# CS                              0.145434
# CTECOAI7                        0.054701
# DALAt2pp                        0.010305
# DASYN181                        0.023985
# DHBD                            0.000660
# DHBS                            0.000660
# DHFS                            0.000223
# DNMPPA                          0.000223
# DHNAOT4                         0.000440
# DHNCOAS                         0.000440
# DNTPPA                          0.000223
# DHNCOAT                         0.000440
# DHNPA2r                         0.000223
# DHORTS                          0.008959
# DHPS2                           0.000223
# DHPTDCs2                        0.000882
# DXPRIi                          0.004190
# DXPS                            0.004192
# DMATT                           0.000661
# DMQMT                           0.000220
# ASAD                            0.018196
# ECOAH8                          0.047970
# EDTXS1                          0.008041
# EDTXS2                          0.008041
# ENTCS                           0.000220
# FCLT                            0.000221
# FRD2                            0.012340
# FACOAE140                       0.008041
# FTHFLi                          0.000230
# FUM                             0.102631
# FACOAE181                       0.047970
# G1PTT                           0.008041
# G1SAT                           0.001775
# G3PAT181                        0.023985
# GLCS1                           0.152108
# GLCTR1                          0.008041
# GLCTR2                          0.008041
# GALT1                           0.008041
# GLCTR3                          0.008041
# GALUi                           0.032164
# GLGC                            0.152108
# GLUCYS                          0.000220
# GLUDy                           0.158768
# GLUTRR                          0.001775
# GLUTRS                          0.001775
# GCALDD                          0.000223
# GLYCL                           0.001809
# H2Otex                          0.522813
# H2Otpp                          0.502907
# GLYCTO3                         0.000223
# GLYK                            0.006328
# HACD8                           0.047970
# GMHEPAT                         0.032164
# GMHEPK                          0.032164
# HEMEOS                          0.000220
# HEPK1                           0.008041
# GMHEPPA                         0.032164
# HEPK2                           0.008041
# HEPT1                           0.008041
# HEPT2                           0.008041
# HEPT3                           0.008041
# HEPT4                           0.008041
# HMBS                            0.000222
# GRTT                            0.000661
# GRXR                            0.001012
# GTHOr                           0.001012
# HPPK2                           0.000223
# HSDy                            0.009942
# GTHS                            0.000220
# GTPCI                           0.000223
# HSST                            0.002999
# IPDDI                           0.000661
# IPDPS                           0.004190
# IPPMIa                          0.010715
# IPPMIb                          0.010715
# KARA1                           0.020776
# Htex                            0.273273
# ICDHyr                          0.145434
# ICHORS_copy2                    0.001100
# ICHORT                          0.000660
# ILETA                           0.006909
# IMPC                            0.013373
# MALS                            0.000223
# MEPCT                           0.004190
# METAT                           0.007543
# METS                            0.003881
# MCTP1Bpp                        0.001327
# MCTP2App                        0.000664
# MDDCP1pp                        0.005375
# MDDCP2pp                        0.000664
# MDDCP3pp                        0.005308
# MLDCP1App                       0.000597
# MLDCP3App                       0.001327
# MLDEP1pp                        0.001327
# MDDCP4pp                        0.005308
# MDH                             0.103036
# MECDPDH5                        0.004190
# MECDPS                          0.004190
# MOAT3C                          0.008041
# MPTG2                           0.000664
# MTAN                            0.006653
# MTHFR2                          0.004101
# MTHTHFSs                        0.000882
# NADH17pp                        0.021076
# NDPK2                           0.000875
# NDPK4                           0.006807
# ORNDC                           0.039474
# ORPT                            0.008959
# O2tex                           0.070823
# O2tpp                           0.070823
# OCTDPS                          0.000441
# OHPHM                           0.000220
# OMBZLM                          0.000220
# OMMBLHX                         0.000220
# PAPSR2                          0.001012
# OMPHHX                          0.000220
# PG160abcpp                      0.010635
# PG161abcpp                      0.008272
# PE161abcpp                      0.003710
# PG181abcpp                      0.004263
# PE181abcpp                      0.012575
# PGAMT                           0.022330
# PGK                             0.327545
# PGM                             0.258770
# PGPP160                         0.016265
# PGPP161                         0.012651
# PGPP181                         0.006520
# PGSA160                         0.016265
# PGSA161                         0.012651
# PGSA181                         0.006520
# PHETA1                          0.004406
# PPBNGS                          0.000887
# PPPGO3                          0.000221
# RPI                             0.053370
# S7PI                            0.032164
# SADT2                           0.001012
# PSD181                          0.017465
# SDPTA                           0.008253
# SEPHCHCS                        0.000440
# SERASr                          0.000660
# SERAT                           0.001012
# PSSA181                         0.017465
# SHCHCS3                         0.000440
# SHSL1                           0.002999
# SO4t2pp                         0.000821
# SO4tex                          0.000821
# SPMS                            0.006653
# SUCBZL                          0.000440
# SUCBZS                          0.000440
# SUCDi                           0.141106
# SULR                            0.001012
# TALA                            0.065276
# TDPDRE                          0.008041
# TDPDRR                          0.008041
# TDPGDH                          0.008041
# TRPAS2                          0.001352
# TYRTA                           0.003278
# VALTA                           0.039333
# VPAMTr                          0.029270
# RHAT1                           0.008041
# RHCCE                           0.000882
# UPP3S                           0.000222
# UPPDC1                          0.000221
# Name: fluxes, dtype: float64

# %% [markdown]
# ### List the reaction IDs for the reactions that had a difference greater than 0.0001

# %%
diff_reactions = list(diff.index)
diff_reactions
# Out:
# ['DM_mththf_c',
#  'BIOMASS_Ec_iJO1366_WT_53p95M',
#  'EX_5mtr_e',
#  'EX_k_e',
#  'EX_mg2_e',
#  'EX_nh4_e',
#  'EX_ca2_e',
#  'EX_cl_e',
#  'EX_pi_e',
#  'EX_fe2_e',
#  '5MTRtpp',
#  'AACPS1',
#  'AACPS5',
#  'ACGK',
#  'ACGS',
#  'ACKr',
#  'ACOAD1f',
#  'ACOAD2f',
#  'ACOAD3f',
#  'ACOAD4f',
#  'ACOAD5f',
#  'ACOAD6f',
#  'ACODA',
#  'ACONTa',
#  'ACONTb',
#  'AGMHE',
#  'AGPAT181',
#  'ACt2rpp',
#  'ADCL',
#  'AHCYSNS',
#  'ADCS',
#  'AIRC3',
#  'AKGDH',
#  'ALAALAabcpp',
#  'ADMDC',
#  'ADPT',
#  'ADSK',
#  'AMMQLT8',
#  'ASPTA',
#  'CAt6pp',
#  'CBL1abcpp',
#  'CBL1tonex',
#  'CBLAT',
#  'ATPS4rpp',
#  'BPNT',
#  'CDPMEK',
#  'CO2tex',
#  'CO2tpp',
#  'CLPNS160pp',
#  'CLPNS161pp',
#  'COLIPAabcpp',
#  'COLIPAabctex',
#  'CLPNS181pp',
#  'CYSS',
#  'CPPPGO',
#  'CYSTL',
#  'CYTBO3_4pp',
#  'CS',
#  'CTECOAI7',
#  'DALAt2pp',
#  'DASYN181',
#  'DHBD',
#  'DHBS',
#  'DHFS',
#  'DNMPPA',
#  'DHNAOT4',
#  'DHNCOAS',
#  'DNTPPA',
#  'DHNCOAT',
#  'DHNPA2r',
#  'DHORTS',
#  'DHPS2',
#  'DHPTDCs2',
#  'DXPRIi',
#  'DXPS',
#  'DMATT',
#  'DMQMT',
#  'ASAD',
#  'ECOAH8',
#  'EDTXS1',
#  'EDTXS2',
#  'ENTCS',
#  'FCLT',
#  'FRD2',
#  'FACOAE140',
#  'FTHFLi',
#  'FUM',
#  'FACOAE181',
#  'G1PTT',
#  'G1SAT',
#  'G3PAT181',
#  'GLCS1',
#  'GLCTR1',
#  'GLCTR2',
#  'GALT1',
#  'GLCTR3',
#  'GALUi',
#  'GLGC',
#  'GLUCYS',
#  'GLUDy',
#  'GLUTRR',
#  'GLUTRS',
#  'GCALDD',
#  'GLYCL',
#  'H2Otex',
#  'H2Otpp',
#  'GLYCTO3',
#  'GLYK',
#  'HACD8',
#  'GMHEPAT',
#  'GMHEPK',
#  'HEMEOS',
#  'HEPK1',
#  'GMHEPPA',
#  'HEPK2',
#  'HEPT1',
#  'HEPT2',
#  'HEPT3',
#  'HEPT4',
#  'HMBS',
#  'GRTT',
#  'GRXR',
#  'GTHOr',
#  'HPPK2',
#  'HSDy',
#  'GTHS',
#  'GTPCI',
#  'HSST',
#  'IPDDI',
#  'IPDPS',
#  'IPPMIa',
#  'IPPMIb',
#  'KARA1',
#  'Htex',
#  'ICDHyr',
#  'ICHORS_copy2',
#  'ICHORT',
#  'ILETA',
#  'IMPC',
#  'MALS',
#  'MEPCT',
#  'METAT',
#  'METS',
#  'MCTP1Bpp',
#  'MCTP2App',
#  'MDDCP1pp',
#  'MDDCP2pp',
#  'MDDCP3pp',
#  'MLDCP1App',
#  'MLDCP3App',
#  'MLDEP1pp',
#  'MDDCP4pp',
#  'MDH',
#  'MECDPDH5',
#  'MECDPS',
#  'MOAT3C',
#  'MPTG2',
#  'MTAN',
#  'MTHFR2',
#  'MTHTHFSs',
#  'NADH17pp',
#  'NDPK2',
#  'NDPK4',
#  'ORNDC',
#  'ORPT',
#  'O2tex',
#  'O2tpp',
#  'OCTDPS',
#  'OHPHM',
#  'OMBZLM',
#  'OMMBLHX',
#  'PAPSR2',
#  'OMPHHX',
#  'PG160abcpp',
#  'PG161abcpp',
#  'PE161abcpp',
#  'PG181abcpp',
#  'PE181abcpp',
#  'PGAMT',
#  'PGK',
#  'PGM',
#  'PGPP160',
#  'PGPP161',
#  'PGPP181',
#  'PGSA160',
#  'PGSA161',
#  'PGSA181',
#  'PHETA1',
#  'PPBNGS',
#  'PPPGO3',
#  'RPI',
#  'S7PI',
#  'SADT2',
#  'PSD181',
#  'SDPTA',
#  'SEPHCHCS',
#  'SERASr',
#  'SERAT',
#  'PSSA181',
#  'SHCHCS3',
#  'SHSL1',
#  'SO4t2pp',
#  'SO4tex',
#  'SPMS',
#  'SUCBZL',
#  'SUCBZS',
#  'SUCDi',
#  'SULR',
#  'TALA',
#  'TDPDRE',
#  'TDPDRR',
#  'TDPGDH',
#  'TRPAS2',
#  'TYRTA',
#  'VALTA',
#  'VPAMTr',
#  'RHAT1',
#  'RHCCE',
#  'UPP3S',
#  'UPPDC1']

# %% [markdown]
# ### Create a list of the subsystems impacted by these reactions

# %%
diff_subsystem = []
for i in range(len(diff_reactions)):
    diff_subsystem.append(model.reactions.get_by_id(diff_reactions[i]).subsystem)
diff_subsystem.sort()
unique_diff_subsystems = set(diff_subsystem)
list(unique_diff_subsystems)
# Out:
# ['Arginine and Proline Metabolism',
#  'Transport, Outer Membrane Porin',
#  'Folate Metabolism',
#  'Citric Acid Cycle',
#  'Lipopolysaccharide Biosynthesis / Recycling',
#  'Cofactor and Prosthetic Group Biosynthesis',
#  'Purine and Pyrimidine Biosynthesis',
#  'Intracellular demand',
#  'Threonine and Lysine Metabolism',
#  'Nucleotide Salvage Pathway',
#  'Cysteine Metabolism',
#  'Extracellular exchange',
#  'Methionine Metabolism',
#  'Cell Envelope Biosynthesis',
#  'Murein Biosynthesis',
#  'Glycolysis/Gluconeogenesis',
#  'Alternate Carbon Metabolism',
#  'Pentose Phosphate Pathway',
#  'Valine, Leucine, and Isoleucine Metabolism',
#  'Tyrosine, Tryptophan, and Phenylalanine Metabolism',
#  'Pyruvate Metabolism',
#  'Transport, Inner Membrane',
#  'Biomass and maintenance functions',
#  'Glutamate Metabolism',
#  'Oxidative Phosphorylation',
#  'Unassigned',
#  'Glycerophospholipid Metabolism',
#  'Murein Recycling',
#  'Membrane Lipid Metabolism',
#  'Transport, Outer Membrane',
#  'Alanine and Aspartate Metabolism',
#  'Inorganic Ion Transport and Metabolism',
#  'Anaplerotic Reactions']

# %% [markdown]
# ### Create a sorted Panda DataFrame for the reactions and their subsystems

# %%
zipped = list(zip(diff_reactions, diff_subsystem))
reaction_subsystems = pd.DataFrame(zipped, columns=['Reactions','Subsystem'])
reaction_subsystems.sort_values(by=['Subsystem'], inplace=True)
reaction_subsystems = reaction_subsystems.reset_index(drop=True)
reaction_subsystems
# Out:
#                         Reactions  \
# 0                     DM_mththf_c
# 1    BIOMASS_Ec_iJO1366_WT_53p95M
# 2                       EX_5mtr_e
# 3                          EX_k_e
# 4                         5MTRtpp
# 5                        EX_fe2_e
# 6                         EX_cl_e
# 7                         EX_pi_e
# 8                        EX_nh4_e
# 9                        EX_mg2_e
# 10                       EX_ca2_e
# 11                         AACPS1
# 12                        ACOAD3f
# 13                        ACOAD6f
# 14                        ACOAD5f
# 15                        ACOAD4f
# 16                        ACOAD2f
# 17                         AACPS5
# 18                           ACKr
# 19                           ACGS
# 20                           ACGK
# 21                        ACOAD1f
# 22                        ACt2rpp
# 23                        AHCYSNS
# 24                       AGPAT181
# 25                           ADCL
# 26                         ACONTb
# 27                         ACONTa
# 28                          ACODA
# 29                          AGMHE
# 30                       DALAt2pp
# 31                       DASYN181
# 32                           DHBD
# 33                           DHBS
# 34                           DHFS
# 35                         DNMPPA
# 36                        DHNAOT4
# 37                        DHNCOAS
# 38                         DNTPPA
# 39                        DHNCOAT
# 40                        DHNPA2r
# 41                         DHORTS
# 42                       DHPTDCs2
# 43                         DXPRIi
# 44                           DXPS
# 45                          DMATT
# 46                          DMQMT
# 47                           ASAD
# 48                         ECOAH8
# 49                         EDTXS1
# 50                         EDTXS2
# 51                          ENTCS
# 52                           FCLT
# 53                           FRD2
# 54                       CTECOAI7
# 55                          DHPS2
# 56                             CS
# 57                          CYSTL
# 58                          AKGDH
# 59                     CYTBO3_4pp
# 60                           ADCS
# 61                          AIRC3
# 62                    ALAALAabcpp
# 63                          ADMDC
# 64                           ADPT
# 65                           ADSK
# 66                        AMMQLT8
# 67                          ASPTA
# 68                         CAt6pp
# 69                      CBL1abcpp
# 70                          CBLAT
# 71                      CBL1tonex
# 72                           BPNT
# 73                         CDPMEK
# 74                         CO2tex
# 75                         CO2tpp
# 76                     CLPNS160pp
# 77                     CLPNS161pp
# 78                    COLIPAabcpp
# 79                   COLIPAabctex
# 80                     CLPNS181pp
# 81                           CYSS
# 82                         CPPPGO
# 83                       ATPS4rpp
# 84                          G1SAT
# 85                       G3PAT181
# 86                          G1PTT
# 87                      FACOAE140
# 88                            FUM
# 89                         FTHFLi
# 90                      FACOAE181
# 91                         GLUCYS
# 92                           GLGC
# 93                         GLCTR3
# 94                          GALUi
# 95                         GLCTR2
# 96                         GLCTR1
# 97                          GLCS1
# 98                          GALT1
# 99                          GLUDy
# 100                        GLUTRR
# 101                        GLUTRS
# 102                        GCALDD
# 103                         GLYCL
# 104                       GMHEPPA
# 105                         HEPK2
# 106                         HEPK1
# 107                         HEPT2
# 108                         HEPT3
# 109                         HEPT1
# 110                        HEMEOS
# 111                       GMHEPAT
# 112                         HACD8
# 113                          GLYK
# 114                       GLYCTO3
# 115                        H2Otpp
# 116                        H2Otex
# 117                        GMHEPK
# 118                          GRTT
# 119                         HEPT4
# 120                          HMBS
# 121                          GRXR
# 122                          HSDy
# 123                         HPPK2
# 124                         GTHOr
# 125                          GTHS
# 126                         METAT
# 127                          MALS
# 128                          METS
# 129                         MEPCT
# 130                      MCTP2App
# 131                      MDDCP1pp
# 132                      MDDCP2pp
# 133                          IMPC
# 134                      MCTP1Bpp
# 135                         ILETA
# 136                  ICHORS_copy2
# 137                         GTPCI
# 138                        ICDHyr
# 139                          Htex
# 140                         KARA1
# 141                        IPPMIb
# 142                        IPPMIa
# 143                         IPDPS
# 144                         IPDDI
# 145                          HSST
# 146                        ICHORT
# 147                        MECDPS
# 148                      MECDPDH5
# 149                           MDH
# 150                      MDDCP4pp
# 151                     MLDCP1App
# 152                     MLDCP3App
# 153                      MDDCP3pp
# 154                        MOAT3C
# 155                      MLDEP1pp
# 156                         NDPK4
# 157                         NDPK2
# 158                          ORPT
# 159                      NADH17pp
# 160                         ORNDC
# 161                        MTHFR2
# 162                          MTAN
# 163                         MPTG2
# 164                      MTHTHFSs
# 165                    PG160abcpp
# 166                        PAPSR2
# 167                        OMPHHX
# 168                       OMMBLHX
# 169                         O2tex
# 170                         OHPHM
# 171                        OCTDPS
# 172                         O2tpp
# 173                        OMBZLM
# 174                    PG161abcpp
# 175                    PE161abcpp
# 176                    PG181abcpp
# 177                    PE181abcpp
# 178                         PGAMT
# 179                           PGK
# 180                           PGM
# 181                       PGPP160
# 182                       PGPP181
# 183                       PGPP161
# 184                       PGSA160
# 185                       PGSA161
# 186                       PGSA181
# 187                        PHETA1
# 188                        PPBNGS
# 189                        PPPGO3
# 190                           RPI
# 191                          S7PI
# 192                       SHCHCS3
# 193                          SPMS
# 194                        SO4tex
# 195                       SO4t2pp
# 196                         SHSL1
# 197                       PSSA181
# 198                         SADT2
# 199                        SERASr
# 200                      SEPHCHCS
# 201                         SDPTA
# 202                        PSD181
# 203                         SERAT
# 204                        SUCBZL
# 205                        TDPDRE
# 206                          TALA
# 207                          SULR
# 208                        SUCBZS
# 209                         SUCDi
# 210                        TDPDRR
# 211                        TDPGDH
# 212                        TRPAS2
# 213                         TYRTA
# 214                         RHCCE
# 215                         RHAT1
# 216                         UPP3S
# 217                         VALTA
# 218                        VPAMTr
# 219                        UPPDC1
#
#                                              Subsystem
# 0                     Alanine and Aspartate Metabolism
# 1                          Alternate Carbon Metabolism
# 2                          Alternate Carbon Metabolism
# 3                                Anaplerotic Reactions
# 4                      Arginine and Proline Metabolism
# 5                      Arginine and Proline Metabolism
# 6                      Arginine and Proline Metabolism
# 7                      Arginine and Proline Metabolism
# 8                      Arginine and Proline Metabolism
# 9                      Arginine and Proline Metabolism
# 10                     Arginine and Proline Metabolism
# 11                   Biomass and maintenance functions
# 12                          Cell Envelope Biosynthesis
# 13                          Cell Envelope Biosynthesis
# 14                          Cell Envelope Biosynthesis
# 15                          Cell Envelope Biosynthesis
# 16                          Cell Envelope Biosynthesis
# 17                          Cell Envelope Biosynthesis
# 18                          Cell Envelope Biosynthesis
# 19                          Cell Envelope Biosynthesis
# 20                          Cell Envelope Biosynthesis
# 21                          Cell Envelope Biosynthesis
# 22                                   Citric Acid Cycle
# 23                                   Citric Acid Cycle
# 24                                   Citric Acid Cycle
# 25                                   Citric Acid Cycle
# 26                                   Citric Acid Cycle
# 27                                   Citric Acid Cycle
# 28                                   Citric Acid Cycle
# 29                                   Citric Acid Cycle
# 30          Cofactor and Prosthetic Group Biosynthesis
# 31          Cofactor and Prosthetic Group Biosynthesis
# 32          Cofactor and Prosthetic Group Biosynthesis
# 33          Cofactor and Prosthetic Group Biosynthesis
# 34          Cofactor and Prosthetic Group Biosynthesis
# 35          Cofactor and Prosthetic Group Biosynthesis
# 36          Cofactor and Prosthetic Group Biosynthesis
# 37          Cofactor and Prosthetic Group Biosynthesis
# 38          Cofactor and Prosthetic Group Biosynthesis
# 39          Cofactor and Prosthetic Group Biosynthesis
# 40          Cofactor and Prosthetic Group Biosynthesis
# 41          Cofactor and Prosthetic Group Biosynthesis
# 42          Cofactor and Prosthetic Group Biosynthesis
# 43          Cofactor and Prosthetic Group Biosynthesis
# 44          Cofactor and Prosthetic Group Biosynthesis
# 45          Cofactor and Prosthetic Group Biosynthesis
# 46          Cofactor and Prosthetic Group Biosynthesis
# 47          Cofactor and Prosthetic Group Biosynthesis
# 48          Cofactor and Prosthetic Group Biosynthesis
# 49          Cofactor and Prosthetic Group Biosynthesis
# 50          Cofactor and Prosthetic Group Biosynthesis
# 51          Cofactor and Prosthetic Group Biosynthesis
# 52          Cofactor and Prosthetic Group Biosynthesis
# 53          Cofactor and Prosthetic Group Biosynthesis
# 54          Cofactor and Prosthetic Group Biosynthesis
# 55          Cofactor and Prosthetic Group Biosynthesis
# 56          Cofactor and Prosthetic Group Biosynthesis
# 57          Cofactor and Prosthetic Group Biosynthesis
# 58          Cofactor and Prosthetic Group Biosynthesis
# 59          Cofactor and Prosthetic Group Biosynthesis
# 60          Cofactor and Prosthetic Group Biosynthesis
# 61          Cofactor and Prosthetic Group Biosynthesis
# 62          Cofactor and Prosthetic Group Biosynthesis
# 63          Cofactor and Prosthetic Group Biosynthesis
# 64          Cofactor and Prosthetic Group Biosynthesis
# 65          Cofactor and Prosthetic Group Biosynthesis
# 66          Cofactor and Prosthetic Group Biosynthesis
# 67          Cofactor and Prosthetic Group Biosynthesis
# 68          Cofactor and Prosthetic Group Biosynthesis
# 69          Cofactor and Prosthetic Group Biosynthesis
# 70          Cofactor and Prosthetic Group Biosynthesis
# 71          Cofactor and Prosthetic Group Biosynthesis
# 72          Cofactor and Prosthetic Group Biosynthesis
# 73          Cofactor and Prosthetic Group Biosynthesis
# 74          Cofactor and Prosthetic Group Biosynthesis
# 75          Cofactor and Prosthetic Group Biosynthesis
# 76          Cofactor and Prosthetic Group Biosynthesis
# 77          Cofactor and Prosthetic Group Biosynthesis
# 78          Cofactor and Prosthetic Group Biosynthesis
# 79          Cofactor and Prosthetic Group Biosynthesis
# 80          Cofactor and Prosthetic Group Biosynthesis
# 81          Cofactor and Prosthetic Group Biosynthesis
# 82          Cofactor and Prosthetic Group Biosynthesis
# 83          Cofactor and Prosthetic Group Biosynthesis
# 84                                 Cysteine Metabolism
# 85                                 Cysteine Metabolism
# 86                                 Cysteine Metabolism
# 87                                 Cysteine Metabolism
# 88                                 Cysteine Metabolism
# 89                                 Cysteine Metabolism
# 90                                 Cysteine Metabolism
# 91                              Extracellular exchange
# 92                              Extracellular exchange
# 93                              Extracellular exchange
# 94                              Extracellular exchange
# 95                              Extracellular exchange
# 96                              Extracellular exchange
# 97                              Extracellular exchange
# 98                              Extracellular exchange
# 99                                   Folate Metabolism
# 100                                  Folate Metabolism
# 101                                  Folate Metabolism
# 102                                  Folate Metabolism
# 103                               Glutamate Metabolism
# 104                     Glycerophospholipid Metabolism
# 105                     Glycerophospholipid Metabolism
# 106                     Glycerophospholipid Metabolism
# 107                     Glycerophospholipid Metabolism
# 108                     Glycerophospholipid Metabolism
# 109                     Glycerophospholipid Metabolism
# 110                     Glycerophospholipid Metabolism
# 111                     Glycerophospholipid Metabolism
# 112                     Glycerophospholipid Metabolism
# 113                     Glycerophospholipid Metabolism
# 114                     Glycerophospholipid Metabolism
# 115                     Glycerophospholipid Metabolism
# 116                     Glycerophospholipid Metabolism
# 117                     Glycerophospholipid Metabolism
# 118                         Glycolysis/Gluconeogenesis
# 119                         Glycolysis/Gluconeogenesis
# 120                         Glycolysis/Gluconeogenesis
# 121                         Glycolysis/Gluconeogenesis
# 122             Inorganic Ion Transport and Metabolism
# 123             Inorganic Ion Transport and Metabolism
# 124             Inorganic Ion Transport and Metabolism
# 125                               Intracellular demand
# 126        Lipopolysaccharide Biosynthesis / Recycling
# 127        Lipopolysaccharide Biosynthesis / Recycling
# 128        Lipopolysaccharide Biosynthesis / Recycling
# 129        Lipopolysaccharide Biosynthesis / Recycling
# 130        Lipopolysaccharide Biosynthesis / Recycling
# 131        Lipopolysaccharide Biosynthesis / Recycling
# 132        Lipopolysaccharide Biosynthesis / Recycling
# 133        Lipopolysaccharide Biosynthesis / Recycling
# 134        Lipopolysaccharide Biosynthesis / Recycling
# 135        Lipopolysaccharide Biosynthesis / Recycling
# 136        Lipopolysaccharide Biosynthesis / Recycling
# 137        Lipopolysaccharide Biosynthesis / Recycling
# 138        Lipopolysaccharide Biosynthesis / Recycling
# 139        Lipopolysaccharide Biosynthesis / Recycling
# 140        Lipopolysaccharide Biosynthesis / Recycling
# 141        Lipopolysaccharide Biosynthesis / Recycling
# 142        Lipopolysaccharide Biosynthesis / Recycling
# 143        Lipopolysaccharide Biosynthesis / Recycling
# 144        Lipopolysaccharide Biosynthesis / Recycling
# 145        Lipopolysaccharide Biosynthesis / Recycling
# 146        Lipopolysaccharide Biosynthesis / Recycling
# 147                          Membrane Lipid Metabolism
# 148                          Membrane Lipid Metabolism
# 149                          Membrane Lipid Metabolism
# 150                          Membrane Lipid Metabolism
# 151                          Membrane Lipid Metabolism
# 152                          Membrane Lipid Metabolism
# 153                          Membrane Lipid Metabolism
# 154                          Membrane Lipid Metabolism
# 155                          Membrane Lipid Metabolism
# 156                              Methionine Metabolism
# 157                              Methionine Metabolism
# 158                              Methionine Metabolism
# 159                              Methionine Metabolism
# 160                              Methionine Metabolism
# 161                              Methionine Metabolism
# 162                              Methionine Metabolism
# 163                              Methionine Metabolism
# 164                              Methionine Metabolism
# 165                                Murein Biosynthesis
# 166                                Murein Biosynthesis
# 167                                Murein Biosynthesis
# 168                                Murein Biosynthesis
# 169                                Murein Biosynthesis
# 170                                Murein Biosynthesis
# 171                                Murein Biosynthesis
# 172                                Murein Biosynthesis
# 173                                Murein Biosynthesis
# 174                                   Murein Recycling
# 175                         Nucleotide Salvage Pathway
# 176                         Nucleotide Salvage Pathway
# 177                         Nucleotide Salvage Pathway
# 178                          Oxidative Phosphorylation
# 179                          Oxidative Phosphorylation
# 180                          Oxidative Phosphorylation
# 181                          Oxidative Phosphorylation
# 182                          Pentose Phosphate Pathway
# 183                          Pentose Phosphate Pathway
# 184                 Purine and Pyrimidine Biosynthesis
# 185                 Purine and Pyrimidine Biosynthesis
# 186                 Purine and Pyrimidine Biosynthesis
# 187                 Purine and Pyrimidine Biosynthesis
# 188                                Pyruvate Metabolism
# 189                    Threonine and Lysine Metabolism
# 190                    Threonine and Lysine Metabolism
# 191                    Threonine and Lysine Metabolism
# 192                          Transport, Inner Membrane
# 193                          Transport, Inner Membrane
# 194                          Transport, Inner Membrane
# 195                          Transport, Inner Membrane
# 196                          Transport, Inner Membrane
# 197                          Transport, Inner Membrane
# 198                          Transport, Inner Membrane
# 199                          Transport, Inner Membrane
# 200                          Transport, Inner Membrane
# 201                          Transport, Inner Membrane
# 202                          Transport, Inner Membrane
# 203                          Transport, Inner Membrane
# 204                          Transport, Outer Membrane
# 205                    Transport, Outer Membrane Porin
# 206                    Transport, Outer Membrane Porin
# 207                    Transport, Outer Membrane Porin
# 208                    Transport, Outer Membrane Porin
# 209                    Transport, Outer Membrane Porin
# 210  Tyrosine, Tryptophan, and Phenylalanine Metabo...
# 211  Tyrosine, Tryptophan, and Phenylalanine Metabo...
# 212  Tyrosine, Tryptophan, and Phenylalanine Metabo...
# 213                                         Unassigned
# 214         Valine, Leucine, and Isoleucine Metabolism
# 215         Valine, Leucine, and Isoleucine Metabolism
# 216         Valine, Leucine, and Isoleucine Metabolism
# 217         Valine, Leucine, and Isoleucine Metabolism
# 218         Valine, Leucine, and Isoleucine Metabolism
# 219         Valine, Leucine, and Isoleucine Metabolism

# %% [markdown]
# From this change it can be seen that the wild type biomass function involves many of the none metabolism subsystems while the core model focuses on the metabolic core.
#
# ### Looking at the flux differences in "Lipopolysaccharide Biosynthesis / Recycling" subsystem

# %% [markdown]
# Let's start by looking at the fluxes that are generated by the core biomass function.

# %%
builder2 = Builder(
    model_name='iJO1366', 
)
builder2.map_json = './Escher_maps/Subsystems/Lipopolysaccharide Biosynthesis-Recycling Subsystem.json'
builder2
# Out:
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/iJO1366.json
# Builder()

# %%
builder2.reaction_data = solution_core.fluxes

# %% [markdown]
# Now let's look at the wild type biomass function

# %%
builder3 = Builder(
    model_name='iJO1366', 
)
builder3.map_json = './Escher_maps/Subsystems/Lipopolysaccharide Biosynthesis-Recycling Subsystem.json'
builder3
# Out:
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/iJO1366.json
# Builder()

# %%
builder3.reaction_data = solution_WT.fluxes

# %% [markdown]
# Plotting the flux difference between the two biomass functions

# %%
builder4 = Builder(
    model_name='iJO1366', 
)
builder4.map_json = './Escher_maps/Subsystems/Lipopolysaccharide Biosynthesis-Recycling Subsystem.json'
builder4
# Out:
# Downloading Model from https://escher.github.io/1-0-0/6/models/Escherichia%20coli/iJO1366.json
# Builder()

# %%
builder4.reaction_data = difference
