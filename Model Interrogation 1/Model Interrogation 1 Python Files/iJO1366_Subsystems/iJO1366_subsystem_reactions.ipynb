# %% [markdown]
# # Biomass and Maintenance Functions Subsystem

# %% [markdown]
# Set the model environment

# %%
import cobra.test
import pandas as pd
import numpy as np
import pandas as pd
import escher
from escher import Builder
from cobra.sampling import sample
from cobrapy_bigg_client import client
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 5000)
pd.set_option('display.width',1000)
pd.set_option('display.max_colwidth',None)

# %%
model = client.download_model('iJO1366', save=False) # Loading the model to the simulation
#model.solver = 'gurobi'
model_orig = model.copy()
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %% [markdown]
# The key subsystems include:
#
#     if ((reaction_subsystem[i] == "Biomass and maintenance functions") or
#            (reaction_subsystem[i] == "Extracellular exchange") or
#            #(reaction_subsystem[i] == "Transport, Outer Membrane") or
#            (reaction_subsystem[i] == "Transport, Inner Membrane") or
#            (reaction_subsystem[i] == "Oxidative Phosphorylation") or
#            (reaction_subsystem[i] == "Intracellular demand") or
#            (reaction_subsystem[i] == "Transport, Outer Membrane Porin") or
#            (reaction_subsystem[i] == "Cell Envelope Biosynthesis") or
#            (reaction_subsystem[i] == "Murein Biosynthesis") or
#            (reaction_subsystem[i] == "Glycerophospholipid Metabolism") or
#            (reaction_subsystem[i] == "Nucleotide Salvage Pathway") or
#            (reaction_subsystem[i] == "Murein Recycling") or
#            (reaction_subsystem[i] == "Membrane Lipid Metabolism") or
#            (reaction_subsystem[i] == "Nucleotide Salvage Pathway") or
#            (reaction_subsystem[i] == "Inorganic Ion Transport and Metabolism") or
#            (reaction_subsystem[i] == "Lipopolysaccharide Biosynthesis / Recycling") or
#            (reaction_subsystem[i] == "tRNA Charging") or
#            (reaction_subsystem[i] == "Unassigned")):

# %%
reaction_names = [r.name for r in model.reactions]
reaction_ids = [r.id for r in model.reactions]
reaction_formula = [r.reaction for r in model.reactions]
reaction_subsystem = [r.subsystem for r in model.reactions]
reactionList = {'Reaction ID': reaction_ids,
                'Reaction Name': reaction_names,
                'Reaction Formula': reaction_formula,
                'Reaction Subsystem': reaction_subsystem,
               }

df = pd.DataFrame(reactionList, columns= ['Reaction ID','Reaction Name','Reaction Formula','Reaction Subsystem'])
# Select the reactions associated with the desired subsystem
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Biomass and maintenance functions':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#                          Reaction ID                                                                  Reaction Name  \
# 13      BIOMASS_Ec_iJO1366_WT_53p95M    E. coli biomass objective function (iJO1366) - WT - with 53.95 GAM estimate
# 18    BIOMASS_Ec_iJO1366_core_53p95M  E. coli biomass objective function (iJO1366) - core - with 53.95 GAM estimate
# 715                             ATPM                                                    ATP maintenance requirement
# 1905                            NTP1                                                Nucleoside-triphosphatase (ATP)
#
# ...

# %% [markdown]
# ### 'Transport, Outer Membrane' Subsystem

# %%
reaction_names = [r.name for r in model.reactions]
reaction_ids = [r.id for r in model.reactions]
reaction_formula = [r.reaction for r in model.reactions]
reaction_subsystem = [r.subsystem for r in model.reactions]
reactionList = {'Reaction ID': reaction_ids,
                'Reaction Name': reaction_names,
                'Reaction Formula': reaction_formula,
                'Reaction Subsystem': reaction_subsystem,
               }

df = pd.DataFrame(reactionList, columns= ['Reaction ID','Reaction Name','Reaction Formula','Reaction Subsystem'])
# Select the reactions associated with the desired subsystem
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Transport, Outer Membrane':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#         Reaction ID                                                                                           Reaction Name                         Reaction Formula         Reaction Subsystem
# 262    14GLUCANtexi                    1,4-alpha-D-glucan transport via diffusion (extracellular to periplasm) irreversible                14glucan_e --> 14glucan_p  Transport, Outer Membrane
# 502        ACNAMtex                                N-acetylneuraminate transport via diffusion (extracellular to periplasm)                      acnam_e <=> acnam_p  Transport, Outer Membrane
# 598          ADNtex                                          Adenosine transport via diffusion (extracellular to periplasm)                          adn_e <=> adn_p  Transport, Outer Membrane
# 608     ADOCBLtonex                                                   Adenosylcobalimin transport via ton system (extermal)        adocbl_e + h_p --> adocbl_p + h_c  Transport, Outer Membrane
# ...

# %% [markdown]
# ### 'Transport, Inner Membrane' Subsystem

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Transport, Inner Membrane':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#          Reaction ID                                                                                        Reaction Name                                                      Reaction Formula         Reaction Subsystem
# 229     12DGR120tipp                          1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C12:0)                                             12dgr120_p --> 12dgr120_c  Transport, Inner Membrane
# 230     12DGR140tipp                          1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C14:0)                                             12dgr140_p --> 12dgr140_c  Transport, Inner Membrane
# 231     12DGR141tipp                          1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C14:1)                                             12dgr141_p --> 12dgr141_c  Transport, Inner Membrane
# ...

# %% [markdown]
# ### 'Transport, Outer Membrane Porin' Subsystem

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Transport, Outer Membrane Porin':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#        Reaction ID                                                                              Reaction Name                           Reaction Formula               Reaction Subsystem
# 249      12PPDRtex                  (R)-Propane-1,2-diol transport via diffusion (extracellular to periplasm)                  12ppd__R_e <=> 12ppd__R_p  Transport, Outer Membrane Porin
# 252      12PPDStex                  (S)-Propane-1,2-diol transport via diffusion (extracellular to periplasm)                  12ppd__S_e <=> 12ppd__S_p  Transport, Outer Membrane Porin
# 263      23CAMPtex                                23cAMP transport via diffusion (extracellular to periplasm)                      23camp_e <=> 23camp_p  Transport, Outer Membrane Porin
# 264      23CCMPtex                                23cCMP transport via diffusion (extracellular to periplasm)                      23ccmp_e <=> 23ccmp_p  Transport, Outer Membrane Porin
# ...

# %% [markdown]
# ### 'Inorganic Ion Transport and Metabolism' Subsystem

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Inorganic Ion Transport and Metabolism':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#         Reaction ID                                                           Reaction Name                                                               Reaction Formula                      Reaction Subsystem
# 570            AGt3                                Silver transport out via proton antiport                                                      ag_c + h_e --> ag_e + h_c  Inorganic Ion Transport and Metabolism
# 692          CAt6pp                                       Calcium / sodium antiporter (1:1)                                                ca2_c + na1_p <=> ca2_p + na1_c  Inorganic Ion Transport and Metabolism
# 711             ASR                                                      Arsenate reductase                              aso4_c + 2.0 gthrd_c --> aso3_c + gthox_c + h2o_c  Inorganic Ion Transport and Metabolism
# ...

# %% [markdown]
# ### 'Unassigned' Subsystem

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Unassigned':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#       Reaction ID                                                           Reaction Name                                          Reaction Formula Reaction Subsystem
# 527        ACONIs                                       Aconitate isomerase (spontaneous)                                     acon_T_c <=> acon_C_c         Unassigned
# 529        ACONMT                                       Trans-aconitate methyltransferase                   acon_T_c + amet_c --> aconm_c + ahcys_c         Unassigned
# 647   ALPATE160pp  Apolipoprotein N-acyltransferase (phosphatidylethanolamine, periplasm)                   alpp_p + pe160_p --> 2agpe160_p + lpp_p         Unassigned
# 650   ALPATG160pp      Apolipoprotein N-acyltransferase (phosphatidylglycerol, periplasm)                   alpp_p + pg160_p --> 2agpg160_p + lpp_p         Unassigned
# ...

# %% [markdown]
# ### 'Extracellular exchange' Subsystem

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Extracellular exchange':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#                Reaction ID                                                               Reaction Name         Reaction Formula      Reaction Subsystem
# 0                  EX_cm_e                                                    Chloramphenicol exchange                cm_e -->   Extracellular exchange
# 1                 EX_cmp_e                                                                CMP exchange               cmp_e -->   Extracellular exchange
# 2                 EX_co2_e                                                                CO2 exchange               co2_e <=>   Extracellular exchange
# 3             EX_cobalt2_e                                                               Co2+ exchange           cobalt2_e <=>   Extracellular exchange
# 9              EX_colipa_e                                       Core oligosaccharide lipid A exchange            colipa_e -->   Extracellular exchange
# ...

# %% [markdown]
# ### 'Intracellular demand' Subsystem

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Intracellular demand':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#     Reaction ID                                                                              Reaction Name Reaction Formula    Reaction Subsystem
# 4   DM_4crsol_c                                              Sink needed to allow p-Cresol to leave system    4crsol_c -->   Intracellular demand
# 5    DM_5drib_c                                        Sink needed to allow 5'-deoxyribose to leave system     5drib_c -->   Intracellular demand
# 6   DM_aacald_c                                     Sink needed to allow aminoacetaldehyde to leave system    aacald_c -->   Intracellular demand
# 7     DM_amob_c                Sink needed to allow S-Adenosyl-4-methylthio-2-oxobutanoate to leave system      amob_c -->   Intracellular demand
# 8   DM_mththf_c  Sink needed to allow (2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran to leave system    mththf_c -->   Intracellular demand
# ...
