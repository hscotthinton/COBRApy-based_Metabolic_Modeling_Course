# %% [markdown]
# # *E.coli* Core Model Subsystems

# %% [markdown]
# Set the model environment (**Do not use the 'textbook' model it does not contain subsystems**)

# %%
import cobra
import pandas as pd
import numpy as np
import pandas as pd
import escher
from escher import Builder
from cobra.sampling import sample
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 5000)
pd.set_option('display.width',1000)
pd.set_option('display.max_colwidth',None)

# Load the model included in the directory or download the model from the BIGG database
model = cobra.io.load_json_model('e_coli_core.json') # Model must be in the same directory

# %% [markdown]
# # Introduction
# This tutorial will explore the operation of the *E.coli* core model by looking at each of the model subsystems.The different subsystems can be found to be.

# %%
reaction_subsystem = [r.subsystem for r in model.reactions]
df2 = pd.DataFrame(reaction_subsystem)
df3 = df2.drop_duplicates()
df3
# Out:
#                                          0
# 0               Glycolysis/Gluconeogenesis
# 1                      Pyruvate Metabolism
# 4                Pentose Phosphate Pathway
# 6                 Transport, Extracellular
# 8   Inorganic Ion Transport and Metabolism
# 12                   Anaplerotic reactions
# 13                       Citric Acid Cycle
# 15       Biomass and maintenance functions
# 19               Oxidative Phosphorylation
# 43                  Extracellular exchange
# 74                    Glutamate Metabolism

# %% [markdown]
# The subsystems for each of the models reactions are given below.

# %%
reaction_names = [r.name for r in model.reactions]
reaction_ids = [r.id for r in model.reactions]
reaction_formula = [r.reaction for r in model.reactions]
reaction_subsystem = [r.subsystem for r in model.reactions]
reactionList = {'Reaction ID': reaction_ids,
                'Reaction Name': reaction_names,
                'Reaction Formula': reaction_formula,
                'Reaction Subsystem': reaction_subsystem,
               }

df = pd.DataFrame(reactionList, columns= ['Reaction ID','Reaction Name','Reaction Formula','Reaction Subsystem'])
pd.set_option('display.max_rows', 500)
df
# Out:
#                  Reaction ID                                         Reaction Name                                                                                                                                                                                                                                                                                                                                          Reaction Formula                      Reaction Subsystem
# 0                        PFK                                   Phosphofructokinase                                                                                                                                                                                                                                                                                                                     atp_c + f6p_c --> adp_c + fdp_c + h_c              Glycolysis/Gluconeogenesis
# 1                        PFL                                Pyruvate formate lyase                                                                                                                                                                                                                                                                                                                         coa_c + pyr_c --> accoa_c + for_c                     Pyruvate Metabolism
# 2                        PGI                         Glucose-6-phosphate isomerase                                                                                                                                                                                                                                                                                                                                           g6p_c <=> f6p_c              Glycolysis/Gluconeogenesis
# 3                        PGK                               Phosphoglycerate kinase                                                                                                                                                                                                                                                                                                                         3pg_c + atp_c <=> 13dpg_c + adp_c              Glycolysis/Gluconeogenesis
# 4                        PGL                             6-phosphogluconolactonase                                                                                                                                                                                                                                                                                                                           6pgl_c + h2o_c --> 6pgc_c + h_c               Pentose Phosphate Pathway
# 5                      ACALD              Acetaldehyde dehydrogenase (acetylating)                                                                                                                                                                                                                                                                                                        acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c                     Pyruvate Metabolism
# 6                     AKGt2r       2 oxoglutarate reversible transport via symport                                                                                                                                                                                                                                                                                                                               akg_e + h_e <=> akg_c + h_c                Transport, Extracellular
# 7                        PGM                               Phosphoglycerate mutase                                                                                                                                                                                                                                                                                                                                           2pg_c <=> 3pg_c              Glycolysis/Gluconeogenesis
# 8                      PIt2r            Phosphate reversible transport via symport                                                                                                                                                                                                                                                                                                                                 h_e + pi_e <=> h_c + pi_c  Inorganic Ion Transport and Metabolism
# 9                     ALCD2x                       Alcohol dehydrogenase (ethanol)                                                                                                                                                                                                                                                                                                                 etoh_c + nad_c <=> acald_c + h_c + nadh_c                     Pyruvate Metabolism
# 10                    ACALDt                     Acetaldehyde reversible transport                                                                                                                                                                                                                                                                                                                                       acald_e <=> acald_c                Transport, Extracellular
# 11                      ACKr                                        Acetate kinase                                                                                                                                                                                                                                                                                                                           ac_c + atp_c <=> actp_c + adp_c                     Pyruvate Metabolism
# 12                       PPC                       Phosphoenolpyruvate carboxylase                                                                                                                                                                                                                                                                                                              co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c                   Anaplerotic reactions
# 13                    ACONTa      Aconitase (half-reaction A, Citrate hydro-lyase)                                                                                                                                                                                                                                                                                                                                cit_c <=> acon_C_c + h2o_c                       Citric Acid Cycle
# 14                    ACONTb   Aconitase (half-reaction B, Isocitrate hydro-lyase)                                                                                                                                                                                                                                                                                                                               acon_C_c + h2o_c <=> icit_c                       Citric Acid Cycle
# 15                      ATPM                           ATP maintenance requirement                                                                                                                                                                                                                                                                                                                      atp_c + h2o_c --> adp_c + h_c + pi_c       Biomass and maintenance functions
# 16                      PPCK                     Phosphoenolpyruvate carboxykinase                                                                                                                                                                                                                                                                                                                   atp_c + oaa_c --> adp_c + co2_c + pep_c                   Anaplerotic reactions
# 17                     ACt2r       Acetate reversible transport via proton symport                                                                                                                                                                                                                                                                                                                                 ac_e + h_e <=> ac_c + h_c                Transport, Extracellular
# 18                       PPS                          Phosphoenolpyruvate synthase                                                                                                                                                                                                                                                                                                  atp_c + h2o_c + pyr_c --> amp_c + 2.0 h_c + pep_c + pi_c              Glycolysis/Gluconeogenesis
# 19                      ADK1                                      Adenylate kinase                                                                                                                                                                                                                                                                                                                               amp_c + atp_c <=> 2.0 adp_c               Oxidative Phosphorylation
# 20                     AKGDH                          2-Oxogluterate dehydrogenase                                                                                                                                                                                                                                                                                                       akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c                       Citric Acid Cycle
# 21                    ATPS4r               ATP synthase (four protons for one ATP)                                                                                                                                                                                                                                                                                                        adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c               Oxidative Phosphorylation
# 22                      PTAr                                 Phosphotransacetylase                                                                                                                                                                                                                                                                                                                         accoa_c + pi_c <=> actp_c + coa_c                     Pyruvate Metabolism
# 23                       PYK                                       Pyruvate kinase                                                                                                                                                                                                                                                                                                                     adp_c + h_c + pep_c --> atp_c + pyr_c              Glycolysis/Gluconeogenesis
# 24  BIOMASS_Ecoli_core_w_GAM                   Biomass Objective Function with GAM  1.496 3pg_c + 3.7478 accoa_c + 59.81 atp_c + 0.361 e4p_c + 0.0709 f6p_c + 0.129 g3p_c + 0.205 g6p_c + 0.2557 gln__L_c + 4.9414 glu__L_c + 59.81 h2o_c + 3.547 nad_c + 13.0279 nadph_c + 1.7867 oaa_c + 0.5191 pep_c + 2.8328 pyr_c + 0.8977 r5p_c --> 59.81 adp_c + 4.1182 akg_c + 3.7478 coa_c + 59.81 h_c + 3.547 nadh_c + 13.0279 nadp_c + 59.81 pi_c       Biomass and maintenance functions
# 25                     PYRt2              Pyruvate transport in via proton symport                                                                                                                                                                                                                                                                                                                               h_e + pyr_e <=> h_c + pyr_c                Transport, Extracellular
# 26                      CO2t                         CO2 transporter via diffusion                                                                                                                                                                                                                                                                                                                                           co2_e <=> co2_c                Transport, Extracellular
# 27                       RPE                      Ribulose 5-phosphate 3-epimerase                                                                                                                                                                                                                                                                                                                                   ru5p__D_c <=> xu5p__D_c               Pentose Phosphate Pathway
# 28                        CS                                      Citrate synthase                                                                                                                                                                                                                                                                                                           accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c                       Citric Acid Cycle
# 29                       RPI                          Ribose-5-phosphate isomerase                                                                                                                                                                                                                                                                                                                                       r5p_c <=> ru5p__D_c               Pentose Phosphate Pathway
# 30                  SUCCt2_2          Succinate transport via proton symport (2 H)                                                                                                                                                                                                                                                                                                                     2.0 h_e + succ_e --> 2.0 h_c + succ_c                Transport, Extracellular
# 31                     CYTBD        Cytochrome oxidase bd (ubiquinol-8: 2 protons)                                                                                                                                                                                                                                                                                                    2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c               Oxidative Phosphorylation
# 32                   D_LACt2                D lactate transport via proton symport                                                                                                                                                                                                                                                                                                                         h_e + lac__D_e <=> h_c + lac__D_c                Transport, Extracellular
# 33                       ENO                                               Enolase                                                                                                                                                                                                                                                                                                                                   2pg_c <=> h2o_c + pep_c              Glycolysis/Gluconeogenesis
# 34                    SUCCt3           Succinate transport out via proton antiport                                                                                                                                                                                                                                                                                                                             h_e + succ_c --> h_c + succ_e                Transport, Extracellular
# 35                   ETOHt2r       Ethanol reversible transport via proton symport                                                                                                                                                                                                                                                                                                                             etoh_e + h_e <=> etoh_c + h_c                Transport, Extracellular
# 36                     SUCDi                Succinate dehydrogenase (irreversible)                                                                                                                                                                                                                                                                                                                          q8_c + succ_c --> fum_c + q8h2_c               Oxidative Phosphorylation
# 37                    SUCOAS                 Succinyl-CoA synthetase (ADP-forming)                                                                                                                                                                                                                                                                                                        atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c                       Citric Acid Cycle
# 38                      TALA                                         Transaldolase                                                                                                                                                                                                                                                                                                                           g3p_c + s7p_c <=> e4p_c + f6p_c               Pentose Phosphate Pathway
# 39                      THD2                               NAD(P) transhydrogenase                                                                                                                                                                                                                                                                                                   2.0 h_e + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c               Oxidative Phosphorylation
# 40                      TKT1                                         Transketolase                                                                                                                                                                                                                                                                                                                       r5p_c + xu5p__D_c <=> g3p_c + s7p_c               Pentose Phosphate Pathway
# 41                      TKT2                                         Transketolase                                                                                                                                                                                                                                                                                                                       e4p_c + xu5p__D_c <=> f6p_c + g3p_c               Pentose Phosphate Pathway
# 42                       TPI                            Triose-phosphate isomerase                                                                                                                                                                                                                                                                                                                                          dhap_c <=> g3p_c              Glycolysis/Gluconeogenesis
# 43                   EX_ac_e                                      Acetate exchange                                                                                                                                                                                                                                                                                                                                                 ac_e -->                   Extracellular exchange
# 44                EX_acald_e                                 Acetaldehyde exchange                                                                                                                                                                                                                                                                                                                                              acald_e -->                   Extracellular exchange
# 45                  EX_akg_e                               2-Oxoglutarate exchange                                                                                                                                                                                                                                                                                                                                                akg_e -->                   Extracellular exchange
# 46                  EX_co2_e                                          CO2 exchange                                                                                                                                                                                                                                                                                                                                                co2_e <=>                   Extracellular exchange
# 47                 EX_etoh_e                                      Ethanol exchange                                                                                                                                                                                                                                                                                                                                               etoh_e -->                   Extracellular exchange
# 48                  EX_for_e                                      Formate exchange                                                                                                                                                                                                                                                                                                                                                for_e -->                   Extracellular exchange
# 49                  EX_fru_e                                   D-Fructose exchange                                                                                                                                                                                                                                                                                                                                                fru_e -->                   Extracellular exchange
# 50                  EX_fum_e                                     Fumarate exchange                                                                                                                                                                                                                                                                                                                                                fum_e -->                   Extracellular exchange
# 51               EX_glc__D_e                                    D-Glucose exchange                                                                                                                                                                                                                                                                                                                                             glc__D_e <=>                   Extracellular exchange
# 52               EX_gln__L_e                                  L-Glutamine exchange                                                                                                                                                                                                                                                                                                                                             gln__L_e -->                   Extracellular exchange
# 53               EX_glu__L_e                                  L-Glutamate exchange                                                                                                                                                                                                                                                                                                                                             glu__L_e -->                   Extracellular exchange
# 54                    EX_h_e                                           H+ exchange                                                                                                                                                                                                                                                                                                                                                  h_e <=>                   Extracellular exchange
# 55                  EX_h2o_e                                          H2O exchange                                                                                                                                                                                                                                                                                                                                                h2o_e <=>                   Extracellular exchange
# 56               EX_lac__D_e                                    D-lactate exchange                                                                                                                                                                                                                                                                                                                                             lac__D_e -->                   Extracellular exchange
# 57               EX_mal__L_e                                     L-Malate exchange                                                                                                                                                                                                                                                                                                                                             mal__L_e -->                   Extracellular exchange
# 58                  EX_nh4_e                                      Ammonia exchange                                                                                                                                                                                                                                                                                                                                                nh4_e <=>                   Extracellular exchange
# 59                   EX_o2_e                                           O2 exchange                                                                                                                                                                                                                                                                                                                                                 o2_e <=>                   Extracellular exchange
# 60                   EX_pi_e                                    Phosphate exchange                                                                                                                                                                                                                                                                                                                                                 pi_e <=>                   Extracellular exchange
# 61                  EX_pyr_e                                     Pyruvate exchange                                                                                                                                                                                                                                                                                                                                                pyr_e -->                   Extracellular exchange
# 62                 EX_succ_e                                    Succinate exchange                                                                                                                                                                                                                                                                                                                                               succ_e -->                   Extracellular exchange
# 63                       FBA                        Fructose-bisphosphate aldolase                                                                                                                                                                                                                                                                                                                                  fdp_c <=> dhap_c + g3p_c              Glycolysis/Gluconeogenesis
# 64                       FBP                               Fructose-bisphosphatase                                                                                                                                                                                                                                                                                                                            fdp_c + h2o_c --> f6p_c + pi_c              Glycolysis/Gluconeogenesis
# 65                     FORt2               Formate transport in via proton symport                                                                                                                                                                                                                                                                                                                               for_e + h_e --> for_c + h_c                Transport, Extracellular
# 66                      FORt                       Formate transport via diffusion                                                                                                                                                                                                                                                                                                                                           for_e <-- for_c                Transport, Extracellular
# 67                      FRD7                                    Fumarate reductase                                                                                                                                                                                                                                                                                                                          fum_c + q8h2_c --> q8_c + succ_c               Oxidative Phosphorylation
# 68                   FRUpts2   Fructose transport via PEP:Pyr PTS (f6p generating)                                                                                                                                                                                                                                                                                                                           fru_e + pep_c --> f6p_c + pyr_c                Transport, Extracellular
# 69                       FUM                                              Fumarase                                                                                                                                                                                                                                                                                                                                fum_c + h2o_c <=> mal__L_c                       Citric Acid Cycle
# 70                   FUMt2_2           Fumarate transport via proton symport (2 H)                                                                                                                                                                                                                                                                                                                       fum_e + 2.0 h_e --> fum_c + 2.0 h_c                Transport, Extracellular
# 71                   G6PDH2r                     Glucose 6-phosphate dehydrogenase                                                                                                                                                                                                                                                                                                                 g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c               Pentose Phosphate Pathway
# 72                      GAPD              Glyceraldehyde-3-phosphate dehydrogenase                                                                                                                                                                                                                                                                                                           g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c              Glycolysis/Gluconeogenesis
# 73                    GLCpts                   D-glucose transport via PEP:Pyr PTS                                                                                                                                                                                                                                                                                                                        glc__D_e + pep_c --> g6p_c + pyr_c                Transport, Extracellular
# 74                      GLNS                                  Glutamine synthetase                                                                                                                                                                                                                                                                                                atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c                    Glutamate Metabolism
# 75                    GLNabc                  L-glutamine transport via ABC system                                                                                                                                                                                                                                                                                                atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c                Transport, Extracellular
# 76                     GLUDy                        Glutamate dehydrogenase (NADP)                                                                                                                                                                                                                                                                                               glu__L_c + h2o_c + nadp_c <=> akg_c + h_c + nadph_c + nh4_c                    Glutamate Metabolism
# 77                      GLUN                                           Glutaminase                                                                                                                                                                                                                                                                                                                     gln__L_c + h2o_c --> glu__L_c + nh4_c                    Glutamate Metabolism
# 78                     GLUSy                            Glutamate synthase (NADPH)                                                                                                                                                                                                                                                                                                akg_c + gln__L_c + h_c + nadph_c --> 2.0 glu__L_c + nadp_c                    Glutamate Metabolism
# 79                    GLUt2r  L glutamate transport via proton symport  reversible                                                                                                                                                                                                                                                                                                                         glu__L_e + h_e <=> glu__L_c + h_c                Transport, Extracellular
# 80                       GND                        Phosphogluconate dehydrogenase                                                                                                                                                                                                                                                                                                           6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c               Pentose Phosphate Pathway
# 81                      H2Ot                           H2O transport via diffusion                                                                                                                                                                                                                                                                                                                                           h2o_e <=> h2o_c                Transport, Extracellular
# 82                    ICDHyr                       Isocitrate dehydrogenase (NADP)                                                                                                                                                                                                                                                                                                               icit_c + nadp_c <=> akg_c + co2_c + nadph_c                       Citric Acid Cycle
# 83                       ICL                                      Isocitrate lyase                                                                                                                                                                                                                                                                                                                                 icit_c --> glx_c + succ_c                   Anaplerotic reactions
# 84                     LDH_D                               D-lactate dehydrogenase                                                                                                                                                                                                                                                                                                                 lac__D_c + nad_c <=> h_c + nadh_c + pyr_c                     Pyruvate Metabolism
# 85                      MALS                                       Malate synthase                                                                                                                                                                                                                                                                                                        accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c                   Anaplerotic reactions
# 86                   MALt2_2             Malate transport via proton symport (2 H)                                                                                                                                                                                                                                                                                                                 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c                Transport, Extracellular
# 87                       MDH                                  Malate dehydrogenase                                                                                                                                                                                                                                                                                                                 mal__L_c + nad_c <=> h_c + nadh_c + oaa_c                       Citric Acid Cycle
# 88                       ME1                                    Malic enzyme (NAD)                                                                                                                                                                                                                                                                                                               mal__L_c + nad_c --> co2_c + nadh_c + pyr_c                   Anaplerotic reactions
# 89                       ME2                                   Malic enzyme (NADP)                                                                                                                                                                                                                                                                                                             mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c                   Anaplerotic reactions
# 90                    NADH16         NADH dehydrogenase (ubiquinone-8 & 3 protons)                                                                                                                                                                                                                                                                                                      4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c               Oxidative Phosphorylation
# 91                   NADTRHD                                  NAD transhydrogenase                                                                                                                                                                                                                                                                                                                       nad_c + nadph_c --> nadh_c + nadp_c               Oxidative Phosphorylation
# 92                      NH4t                          Ammonia reversible transport                                                                                                                                                                                                                                                                                                                                           nh4_e <=> nh4_c  Inorganic Ion Transport and Metabolism
# 93                       O2t                              O2 transport  diffusion                                                                                                                                                                                                                                                                                                                                              o2_e <=> o2_c                Transport, Extracellular
# 94                       PDH                                Pyruvate dehydrogenase                                                                                                                                                                                                                                                                                                        coa_c + nad_c + pyr_c --> accoa_c + co2_c + nadh_c              Glycolysis/Gluconeogenesis

# %% [markdown]
# Ordering the 'Reaction IDs' in the table alphabetically

# %%
df.sort_values(by=['Reaction ID'], inplace = True)
df
# Out:
#                  Reaction ID                                         Reaction Name                                                                                                                                                                                                                                                                                                                                          Reaction Formula                      Reaction Subsystem
# 5                      ACALD              Acetaldehyde dehydrogenase (acetylating)                                                                                                                                                                                                                                                                                                        acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c                     Pyruvate Metabolism
# 10                    ACALDt                     Acetaldehyde reversible transport                                                                                                                                                                                                                                                                                                                                       acald_e <=> acald_c                Transport, Extracellular
# 11                      ACKr                                        Acetate kinase                                                                                                                                                                                                                                                                                                                           ac_c + atp_c <=> actp_c + adp_c                     Pyruvate Metabolism
# 13                    ACONTa      Aconitase (half-reaction A, Citrate hydro-lyase)                                                                                                                                                                                                                                                                                                                                cit_c <=> acon_C_c + h2o_c                       Citric Acid Cycle
# 14                    ACONTb   Aconitase (half-reaction B, Isocitrate hydro-lyase)                                                                                                                                                                                                                                                                                                                               acon_C_c + h2o_c <=> icit_c                       Citric Acid Cycle
# 17                     ACt2r       Acetate reversible transport via proton symport                                                                                                                                                                                                                                                                                                                                 ac_e + h_e <=> ac_c + h_c                Transport, Extracellular
# 19                      ADK1                                      Adenylate kinase                                                                                                                                                                                                                                                                                                                               amp_c + atp_c <=> 2.0 adp_c               Oxidative Phosphorylation
# 20                     AKGDH                          2-Oxogluterate dehydrogenase                                                                                                                                                                                                                                                                                                       akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c                       Citric Acid Cycle
# 6                     AKGt2r       2 oxoglutarate reversible transport via symport                                                                                                                                                                                                                                                                                                                               akg_e + h_e <=> akg_c + h_c                Transport, Extracellular
# 9                     ALCD2x                       Alcohol dehydrogenase (ethanol)                                                                                                                                                                                                                                                                                                                 etoh_c + nad_c <=> acald_c + h_c + nadh_c                     Pyruvate Metabolism
# 15                      ATPM                           ATP maintenance requirement                                                                                                                                                                                                                                                                                                                      atp_c + h2o_c --> adp_c + h_c + pi_c       Biomass and maintenance functions
# 21                    ATPS4r               ATP synthase (four protons for one ATP)                                                                                                                                                                                                                                                                                                        adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c               Oxidative Phosphorylation
# 24  BIOMASS_Ecoli_core_w_GAM                   Biomass Objective Function with GAM  1.496 3pg_c + 3.7478 accoa_c + 59.81 atp_c + 0.361 e4p_c + 0.0709 f6p_c + 0.129 g3p_c + 0.205 g6p_c + 0.2557 gln__L_c + 4.9414 glu__L_c + 59.81 h2o_c + 3.547 nad_c + 13.0279 nadph_c + 1.7867 oaa_c + 0.5191 pep_c + 2.8328 pyr_c + 0.8977 r5p_c --> 59.81 adp_c + 4.1182 akg_c + 3.7478 coa_c + 59.81 h_c + 3.547 nadh_c + 13.0279 nadp_c + 59.81 pi_c       Biomass and maintenance functions
# 26                      CO2t                         CO2 transporter via diffusion                                                                                                                                                                                                                                                                                                                                           co2_e <=> co2_c                Transport, Extracellular
# 28                        CS                                      Citrate synthase                                                                                                                                                                                                                                                                                                           accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c                       Citric Acid Cycle
# 31                     CYTBD        Cytochrome oxidase bd (ubiquinol-8: 2 protons)                                                                                                                                                                                                                                                                                                    2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c               Oxidative Phosphorylation
# 32                   D_LACt2                D lactate transport via proton symport                                                                                                                                                                                                                                                                                                                         h_e + lac__D_e <=> h_c + lac__D_c                Transport, Extracellular
# 33                       ENO                                               Enolase                                                                                                                                                                                                                                                                                                                                   2pg_c <=> h2o_c + pep_c              Glycolysis/Gluconeogenesis
# 35                   ETOHt2r       Ethanol reversible transport via proton symport                                                                                                                                                                                                                                                                                                                             etoh_e + h_e <=> etoh_c + h_c                Transport, Extracellular
# 43                   EX_ac_e                                      Acetate exchange                                                                                                                                                                                                                                                                                                                                                 ac_e -->                   Extracellular exchange
# 44                EX_acald_e                                 Acetaldehyde exchange                                                                                                                                                                                                                                                                                                                                              acald_e -->                   Extracellular exchange
# 45                  EX_akg_e                               2-Oxoglutarate exchange                                                                                                                                                                                                                                                                                                                                                akg_e -->                   Extracellular exchange
# 46                  EX_co2_e                                          CO2 exchange                                                                                                                                                                                                                                                                                                                                                co2_e <=>                   Extracellular exchange
# 47                 EX_etoh_e                                      Ethanol exchange                                                                                                                                                                                                                                                                                                                                               etoh_e -->                   Extracellular exchange
# 48                  EX_for_e                                      Formate exchange                                                                                                                                                                                                                                                                                                                                                for_e -->                   Extracellular exchange
# 49                  EX_fru_e                                   D-Fructose exchange                                                                                                                                                                                                                                                                                                                                                fru_e -->                   Extracellular exchange
# 50                  EX_fum_e                                     Fumarate exchange                                                                                                                                                                                                                                                                                                                                                fum_e -->                   Extracellular exchange
# 51               EX_glc__D_e                                    D-Glucose exchange                                                                                                                                                                                                                                                                                                                                             glc__D_e <=>                   Extracellular exchange
# 52               EX_gln__L_e                                  L-Glutamine exchange                                                                                                                                                                                                                                                                                                                                             gln__L_e -->                   Extracellular exchange
# 53               EX_glu__L_e                                  L-Glutamate exchange                                                                                                                                                                                                                                                                                                                                             glu__L_e -->                   Extracellular exchange
# 55                  EX_h2o_e                                          H2O exchange                                                                                                                                                                                                                                                                                                                                                h2o_e <=>                   Extracellular exchange
# 54                    EX_h_e                                           H+ exchange                                                                                                                                                                                                                                                                                                                                                  h_e <=>                   Extracellular exchange
# 56               EX_lac__D_e                                    D-lactate exchange                                                                                                                                                                                                                                                                                                                                             lac__D_e -->                   Extracellular exchange
# 57               EX_mal__L_e                                     L-Malate exchange                                                                                                                                                                                                                                                                                                                                             mal__L_e -->                   Extracellular exchange
# 58                  EX_nh4_e                                      Ammonia exchange                                                                                                                                                                                                                                                                                                                                                nh4_e <=>                   Extracellular exchange
# 59                   EX_o2_e                                           O2 exchange                                                                                                                                                                                                                                                                                                                                                 o2_e <=>                   Extracellular exchange
# 60                   EX_pi_e                                    Phosphate exchange                                                                                                                                                                                                                                                                                                                                                 pi_e <=>                   Extracellular exchange
# 61                  EX_pyr_e                                     Pyruvate exchange                                                                                                                                                                                                                                                                                                                                                pyr_e -->                   Extracellular exchange
# 62                 EX_succ_e                                    Succinate exchange                                                                                                                                                                                                                                                                                                                                               succ_e -->                   Extracellular exchange
# 63                       FBA                        Fructose-bisphosphate aldolase                                                                                                                                                                                                                                                                                                                                  fdp_c <=> dhap_c + g3p_c              Glycolysis/Gluconeogenesis
# 64                       FBP                               Fructose-bisphosphatase                                                                                                                                                                                                                                                                                                                            fdp_c + h2o_c --> f6p_c + pi_c              Glycolysis/Gluconeogenesis
# 66                      FORt                       Formate transport via diffusion                                                                                                                                                                                                                                                                                                                                           for_e <-- for_c                Transport, Extracellular
# 65                     FORt2               Formate transport in via proton symport                                                                                                                                                                                                                                                                                                                               for_e + h_e --> for_c + h_c                Transport, Extracellular
# 67                      FRD7                                    Fumarate reductase                                                                                                                                                                                                                                                                                                                          fum_c + q8h2_c --> q8_c + succ_c               Oxidative Phosphorylation
# 68                   FRUpts2   Fructose transport via PEP:Pyr PTS (f6p generating)                                                                                                                                                                                                                                                                                                                           fru_e + pep_c --> f6p_c + pyr_c                Transport, Extracellular
# 69                       FUM                                              Fumarase                                                                                                                                                                                                                                                                                                                                fum_c + h2o_c <=> mal__L_c                       Citric Acid Cycle
# 70                   FUMt2_2           Fumarate transport via proton symport (2 H)                                                                                                                                                                                                                                                                                                                       fum_e + 2.0 h_e --> fum_c + 2.0 h_c                Transport, Extracellular
# 71                   G6PDH2r                     Glucose 6-phosphate dehydrogenase                                                                                                                                                                                                                                                                                                                 g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c               Pentose Phosphate Pathway
# 72                      GAPD              Glyceraldehyde-3-phosphate dehydrogenase                                                                                                                                                                                                                                                                                                           g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c              Glycolysis/Gluconeogenesis
# 73                    GLCpts                   D-glucose transport via PEP:Pyr PTS                                                                                                                                                                                                                                                                                                                        glc__D_e + pep_c --> g6p_c + pyr_c                Transport, Extracellular
# 74                      GLNS                                  Glutamine synthetase                                                                                                                                                                                                                                                                                                atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c                    Glutamate Metabolism
# 75                    GLNabc                  L-glutamine transport via ABC system                                                                                                                                                                                                                                                                                                atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c                Transport, Extracellular
# 76                     GLUDy                        Glutamate dehydrogenase (NADP)                                                                                                                                                                                                                                                                                               glu__L_c + h2o_c + nadp_c <=> akg_c + h_c + nadph_c + nh4_c                    Glutamate Metabolism
# 77                      GLUN                                           Glutaminase                                                                                                                                                                                                                                                                                                                     gln__L_c + h2o_c --> glu__L_c + nh4_c                    Glutamate Metabolism
# 78                     GLUSy                            Glutamate synthase (NADPH)                                                                                                                                                                                                                                                                                                akg_c + gln__L_c + h_c + nadph_c --> 2.0 glu__L_c + nadp_c                    Glutamate Metabolism
# 79                    GLUt2r  L glutamate transport via proton symport  reversible                                                                                                                                                                                                                                                                                                                         glu__L_e + h_e <=> glu__L_c + h_c                Transport, Extracellular
# 80                       GND                        Phosphogluconate dehydrogenase                                                                                                                                                                                                                                                                                                           6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c               Pentose Phosphate Pathway
# 81                      H2Ot                           H2O transport via diffusion                                                                                                                                                                                                                                                                                                                                           h2o_e <=> h2o_c                Transport, Extracellular
# 82                    ICDHyr                       Isocitrate dehydrogenase (NADP)                                                                                                                                                                                                                                                                                                               icit_c + nadp_c <=> akg_c + co2_c + nadph_c                       Citric Acid Cycle
# 83                       ICL                                      Isocitrate lyase                                                                                                                                                                                                                                                                                                                                 icit_c --> glx_c + succ_c                   Anaplerotic reactions
# 84                     LDH_D                               D-lactate dehydrogenase                                                                                                                                                                                                                                                                                                                 lac__D_c + nad_c <=> h_c + nadh_c + pyr_c                     Pyruvate Metabolism
# 85                      MALS                                       Malate synthase                                                                                                                                                                                                                                                                                                        accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c                   Anaplerotic reactions
# 86                   MALt2_2             Malate transport via proton symport (2 H)                                                                                                                                                                                                                                                                                                                 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c                Transport, Extracellular
# 87                       MDH                                  Malate dehydrogenase                                                                                                                                                                                                                                                                                                                 mal__L_c + nad_c <=> h_c + nadh_c + oaa_c                       Citric Acid Cycle
# 88                       ME1                                    Malic enzyme (NAD)                                                                                                                                                                                                                                                                                                               mal__L_c + nad_c --> co2_c + nadh_c + pyr_c                   Anaplerotic reactions
# 89                       ME2                                   Malic enzyme (NADP)                                                                                                                                                                                                                                                                                                             mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c                   Anaplerotic reactions
# 90                    NADH16         NADH dehydrogenase (ubiquinone-8 & 3 protons)                                                                                                                                                                                                                                                                                                      4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c               Oxidative Phosphorylation
# 91                   NADTRHD                                  NAD transhydrogenase                                                                                                                                                                                                                                                                                                                       nad_c + nadph_c --> nadh_c + nadp_c               Oxidative Phosphorylation
# 92                      NH4t                          Ammonia reversible transport                                                                                                                                                                                                                                                                                                                                           nh4_e <=> nh4_c  Inorganic Ion Transport and Metabolism
# 93                       O2t                              O2 transport  diffusion                                                                                                                                                                                                                                                                                                                                              o2_e <=> o2_c                Transport, Extracellular
# 94                       PDH                                Pyruvate dehydrogenase                                                                                                                                                                                                                                                                                                        coa_c + nad_c + pyr_c --> accoa_c + co2_c + nadh_c              Glycolysis/Gluconeogenesis
# 0                        PFK                                   Phosphofructokinase                                                                                                                                                                                                                                                                                                                     atp_c + f6p_c --> adp_c + fdp_c + h_c              Glycolysis/Gluconeogenesis
# 1                        PFL                                Pyruvate formate lyase                                                                                                                                                                                                                                                                                                                         coa_c + pyr_c --> accoa_c + for_c                     Pyruvate Metabolism
# 2                        PGI                         Glucose-6-phosphate isomerase                                                                                                                                                                                                                                                                                                                                           g6p_c <=> f6p_c              Glycolysis/Gluconeogenesis
# 3                        PGK                               Phosphoglycerate kinase                                                                                                                                                                                                                                                                                                                         3pg_c + atp_c <=> 13dpg_c + adp_c              Glycolysis/Gluconeogenesis
# 4                        PGL                             6-phosphogluconolactonase                                                                                                                                                                                                                                                                                                                           6pgl_c + h2o_c --> 6pgc_c + h_c               Pentose Phosphate Pathway
# 7                        PGM                               Phosphoglycerate mutase                                                                                                                                                                                                                                                                                                                                           2pg_c <=> 3pg_c              Glycolysis/Gluconeogenesis
# 8                      PIt2r            Phosphate reversible transport via symport                                                                                                                                                                                                                                                                                                                                 h_e + pi_e <=> h_c + pi_c  Inorganic Ion Transport and Metabolism
# 12                       PPC                       Phosphoenolpyruvate carboxylase                                                                                                                                                                                                                                                                                                              co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c                   Anaplerotic reactions
# 16                      PPCK                     Phosphoenolpyruvate carboxykinase                                                                                                                                                                                                                                                                                                                   atp_c + oaa_c --> adp_c + co2_c + pep_c                   Anaplerotic reactions
# 18                       PPS                          Phosphoenolpyruvate synthase                                                                                                                                                                                                                                                                                                  atp_c + h2o_c + pyr_c --> amp_c + 2.0 h_c + pep_c + pi_c              Glycolysis/Gluconeogenesis
# 22                      PTAr                                 Phosphotransacetylase                                                                                                                                                                                                                                                                                                                         accoa_c + pi_c <=> actp_c + coa_c                     Pyruvate Metabolism
# 23                       PYK                                       Pyruvate kinase                                                                                                                                                                                                                                                                                                                     adp_c + h_c + pep_c --> atp_c + pyr_c              Glycolysis/Gluconeogenesis
# 25                     PYRt2              Pyruvate transport in via proton symport                                                                                                                                                                                                                                                                                                                               h_e + pyr_e <=> h_c + pyr_c                Transport, Extracellular
# 27                       RPE                      Ribulose 5-phosphate 3-epimerase                                                                                                                                                                                                                                                                                                                                   ru5p__D_c <=> xu5p__D_c               Pentose Phosphate Pathway
# 29                       RPI                          Ribose-5-phosphate isomerase                                                                                                                                                                                                                                                                                                                                       r5p_c <=> ru5p__D_c               Pentose Phosphate Pathway
# 30                  SUCCt2_2          Succinate transport via proton symport (2 H)                                                                                                                                                                                                                                                                                                                     2.0 h_e + succ_e --> 2.0 h_c + succ_c                Transport, Extracellular
# 34                    SUCCt3           Succinate transport out via proton antiport                                                                                                                                                                                                                                                                                                                             h_e + succ_c --> h_c + succ_e                Transport, Extracellular
# 36                     SUCDi                Succinate dehydrogenase (irreversible)                                                                                                                                                                                                                                                                                                                          q8_c + succ_c --> fum_c + q8h2_c               Oxidative Phosphorylation
# 37                    SUCOAS                 Succinyl-CoA synthetase (ADP-forming)                                                                                                                                                                                                                                                                                                        atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c                       Citric Acid Cycle
# 38                      TALA                                         Transaldolase                                                                                                                                                                                                                                                                                                                           g3p_c + s7p_c <=> e4p_c + f6p_c               Pentose Phosphate Pathway
# 39                      THD2                               NAD(P) transhydrogenase                                                                                                                                                                                                                                                                                                   2.0 h_e + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c               Oxidative Phosphorylation
# 40                      TKT1                                         Transketolase                                                                                                                                                                                                                                                                                                                       r5p_c + xu5p__D_c <=> g3p_c + s7p_c               Pentose Phosphate Pathway
# 41                      TKT2                                         Transketolase                                                                                                                                                                                                                                                                                                                       e4p_c + xu5p__D_c <=> f6p_c + g3p_c               Pentose Phosphate Pathway
# 42                       TPI                            Triose-phosphate isomerase                                                                                                                                                                                                                                                                                                                                          dhap_c <=> g3p_c              Glycolysis/Gluconeogenesis

# %% [markdown]
# The following is an example of how to list the reactions associated with a certain subsystem. This example is for the oxidative phosphorylation subsystem.

# %%
SSindex = []
for i in range(len(reaction_subsystem)):
    if reaction_subsystem[i] == 'Oxidative Phosphorylation':
        SSindex.append(i)
df.loc[SSindex]
# Out:
#    Reaction ID                                   Reaction Name                                         Reaction Formula         Reaction Subsystem
# 19        ADK1                                Adenylate kinase                              amp_c + atp_c <=> 2.0 adp_c  Oxidative Phosphorylation
# 21      ATPS4r         ATP synthase (four protons for one ATP)       adp_c + 4.0 h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c  Oxidative Phosphorylation
# 31       CYTBD  Cytochrome oxidase bd (ubiquinol-8: 2 protons)   2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_e + q8_c  Oxidative Phosphorylation
# 36       SUCDi          Succinate dehydrogenase (irreversible)                         q8_c + succ_c --> fum_c + q8h2_c  Oxidative Phosphorylation
# 39        THD2                         NAD(P) transhydrogenase  2.0 h_e + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c  Oxidative Phosphorylation
# 67        FRD7                              Fumarate reductase                         fum_c + q8h2_c --> q8_c + succ_c  Oxidative Phosphorylation
# 90      NADH16   NADH dehydrogenase (ubiquinone-8 & 3 protons)     4.0 h_c + nadh_c + q8_c --> 3.0 h_e + nad_c + q8h2_c  Oxidative Phosphorylation
# 91     NADTRHD                            NAD transhydrogenase                      nad_c + nadph_c --> nadh_c + nadp_c  Oxidative Phosphorylation

# %% [markdown]
# A map of the subsystems for the *E.coli* core model is
#
# ![Ecoli_Core_Model_Subystems_Map.JPG](attachment:Ecoli_Core_Model_Subystems_Map.JPG)
#
# where
#
# - Glyc – Glycolysis/Gluconeogenesis
# - PPP - Pentose Phosphate Pathway
# - CAC – Citric Acid Cycle
# - ANA - Anaplerotic Reactions
# - OP - Oxidative Phosphorylation
# - PM – Pyruvate Metabolism
# - GM - Glutamate Metabolism
# - BM - Biomass and Maintenance Functions
#
# Not shown on the map
# - TE - Transport, Extracellular
# - IITM - Inorganic Ion Transport and Metabolism
# - EE - Extracellular Exchange
