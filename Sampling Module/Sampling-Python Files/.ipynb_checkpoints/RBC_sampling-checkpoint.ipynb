# %% [markdown]
# # Red Blood Cell Sampling: Drugs

# %% [markdown]
# Set the environment

# %%
import cobra.test
import pandas as pd
import numpy as np
import pandas as pd
import escher
from escher import Builder
from cobra.sampling import sample
import matplotlib.pyplot as plt
from cobrapy_bigg_client import client
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width',1000)
pd.set_option('display.max_colwidth',None)

# %% [markdown]
# Load the red blood cell model iAB_RBC_283.json

# %%
model = client.download_model('iAB_RBC_283', save=False) # Loading the model to the simulation
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-10-10

# %% [markdown]
# The summary of the model using default conditions

# %% [markdown]
# EX_co2_e, EX_fum_e, EX_lac__L_e, EX_mal__L_e, CO2t, EX_pyr_e, HEX1, HEX7, FUM, FUMtr, L_LACt2r, LDH_LG, MALt, GTHOrm, GTHPi, ME2, PGI, PYRt2, SBTD_D2, SBTR

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 NaKt = 2.935561466666666</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>acnam_e</td>
#       <td>EX_acnam_e</td>
#       <td>3.74E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>adn_e</td>
#       <td>EX_adn_e</td>
#       <td>0.01</td>
#       <td>10</td>
#       <td>0.68%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>5.871</td>
#       <td>1</td>
#       <td>39.95%</td>
#     </tr>
#     <tr>
#       <td>fru_e</td>
#       <td>EX_fru_e</td>
#       <td>0.0075</td>
#       <td>6</td>
#       <td>0.31%</td>
#     </tr>
#     <tr>
#       <td>gal_e</td>
#       <td>EX_gal_e</td>
#       <td>0.3169</td>
#       <td>6</td>
#       <td>12.94%</td>
#     </tr>
#     <tr>
#       <td>gam_e</td>
#       <td>EX_gam_e</td>
#       <td>1E-05</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1.12</td>
#       <td>6</td>
#       <td>45.72%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>5.881</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>man_e</td>
#       <td>EX_man_e</td>
#       <td>0.01</td>
#       <td>6</td>
#       <td>0.41%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-3.74E-05</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ade_e</td>
#       <td>EX_ade_e</td>
#       <td>-0.01</td>
#       <td>5</td>
#       <td>0.34%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-8.797</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-5.871</td>
#       <td>1</td>
#       <td>39.95%</td>
#     </tr>
#     <tr>
#       <td>lac__L_e</td>
#       <td>EX_lac__L_e</td>
#       <td>-2.926</td>
#       <td>3</td>
#       <td>59.71%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>-4.74E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pyr_e</td>
#       <td>EX_pyr_e</td>
#       <td>-3.74E-05</td>
#       <td>3</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Sampling the default model

# %%
# %%time
RBC_samples = sample(model, 5000, processes=8) #Set this to 1000 for faster, less accurate performance
RBC_samples.head(10) # Do not list all the samples, it could overload the browser memory
# Out:
# Read LP format model from file C:\Users\hinton\AppData\Local\Temp\tmp0dgumn3w.lp
# Reading time = 0.01 seconds
# : 342 rows, 938 columns, 3344 nonzeros
# Wall time: 26.5 s
#    SK_pchol_hs_18_1_18_1_c  SK_pchol_hs_18_1_18_2_c  SK_pchol_hs_18_2_16_0_c  SK_pchol_hs_18_2_18_1_c  SK_pe_hs_16_0_16_0_c  SK_pe_hs_16_0_18_1_c  SK_pe_hs_16_0_18_2_c  SK_pe_hs_18_1_18_1_c  SK_pe_hs_18_1_18_2_c  SK_pe_hs_18_2_16_0_c  ...      XYLK   XYLTD_D     XYLUR       ARD  CEPTC_18_1_18_2  CEPTC_18_2_16_0  CEPTC_18_2_18_1  CEPTE_16_0_18_1  CEPTE_16_0_18_2  CEPTE_18_1_18_1
# They include 'EX_co2_e', 'EX_fum_e', 'EX_lac__L_e', 'EX_mal__L_e', 'CO2t', 'EX_pyr_e', 'HEX1', 'HEX7', 'FUM', 'FUMtr', 'L_LACt2r', 'LDH_L', 'MALt', 'GTHOr', 'GTHPi', 'ME2', 'PGI', 'PYRt2', 'SBTD_D2', 'SBTR'.

# %%
impacted_reactions = ['EX_co2_e', 'EX_fum_e', 'EX_lac__L_e', 'EX_mal__L_e', 'CO2t', 'EX_pyr_e', 'HEX1', 'HEX7', 
                      'FUM', 'FUMtr', 'L_LACt2r', 'LDH_L', 'MALt', 'GTHOr', 'GTHPi', 'ME2', 'PGI', 
                      'PYRt2', 'SBTD_D2', 'SBTR']

RBC_samples.hist(column = impacted_reactions, bins=100,figsize=(15,15), histtype = 'step');

# %% [markdown]
# ## Knockout the PGI reaction

# %%
model2 = client.download_model('iAB_RBC_283', save=False) # Loading the model to the simulation
model2.reactions.PGI.bounds = [0,0] # knock-out the PGI reaction

RBC_samples2 = sample(model2, 5000, processes=8) #Set this to 1000 for faster, less accurate performance
RBC_samples2.head(10) # Do not list all the samples, it could overload the browser memory
# Out:
# Read LP format model from file C:\Users\hinton\AppData\Local\Temp\tmpoj7mgmbi.lp
# Reading time = 0.01 seconds
# : 342 rows, 938 columns, 3344 nonzeros
#    SK_pchol_hs_18_1_18_1_c  SK_pchol_hs_18_1_18_2_c  SK_pchol_hs_18_2_16_0_c  SK_pchol_hs_18_2_18_1_c  SK_pe_hs_16_0_16_0_c  SK_pe_hs_16_0_18_1_c  SK_pe_hs_16_0_18_2_c  SK_pe_hs_18_1_18_1_c  SK_pe_hs_18_1_18_2_c  SK_pe_hs_18_2_16_0_c  ...      XYLK   XYLTD_D     XYLUR       ARD  CEPTC_18_1_18_2  CEPTC_18_2_16_0  CEPTC_18_2_18_1  CEPTE_16_0_18_1  CEPTE_16_0_18_2  CEPTE_18_1_18_1
# 0                 0.000004                -0.000533            -5.437506e-09                 0.000533          2.822818e-09          1.030680e-09                   0.0          4.417198e-10                   0.0          1.030680e-09  ...  0.003040  0.003040  0.003040  0.000219         0.000033         0.000014         0.002169     1.030680e-09              0.0     4.417198e-10
# 1                 0.000126                -0.001799            -1.028989e-05                 0.001685          8.514131e-07          4.694662e-06                   0.0          8.460039e-07                   0.0          4.694662e-06  ...  0.012693  0.012693  0.012693  0.009428         0.000505         0.000181         0.002389     4.694662e-06              0.0     8.460039e-07
# 2                -0.002725                -0.005353            -2.461224e-03                 0.007766          8.349993e-07          9.601002e-06                   0.0          1.328638e-04                   0.0          9.601002e-06  ...  0.028176  0.028176  0.028176  0.004854         0.000675         0.005347         0.017225     9.601002e-06              0.0     1.328638e-04
# 3                -0.002752                -0.004936            -2.214441e-03                 0.007246          5.276100e-06          2.168310e-04                   0.0          1.347564e-04                   0.0          2.168310e-04  ...  0.016657  0.016657  0.016657  0.005468         0.000064         0.002692         0.007514     2.168310e-04              0.0     1.347564e-04
# 4                -0.005013                -0.002187            -3.346470e-03                 0.006684          5.268001e-06          2.087587e-04                   0.0          2.131283e-04                   0.0          2.087587e-04  ...  0.014483  0.014483  0.014483  0.005617         0.003688         0.003698         0.009174     2.087587e-04              0.0     2.131283e-04
# 5                -0.004982                -0.000986            -3.318508e-03                 0.005495          1.131519e-04          1.372970e-04                   0.0          2.115697e-04                   0.0          1.372970e-04  ...  0.015043  0.015043  0.015043  0.008091         0.002774         0.014036         0.010843     1.372970e-04              0.0     2.115697e-04
# 6                -0.005025                 0.005391            -4.256627e-03                -0.000973          1.127456e-04          2.537982e-04                   0.0          2.087935e-04                   0.0          2.537982e-04  ...  0.033888  0.033888  0.033888  0.011157         0.013916         0.006009         0.001193     2.537982e-04              0.0     2.087935e-04
# 7                -0.005069                -0.004536            -3.263111e-03                 0.002338          3.157207e-04          2.547041e-04                   0.0          2.096396e-04                   0.0          2.547041e-04  ...  0.033453  0.033453  0.033453  0.014537         0.012664         0.007087         0.004904     2.547041e-04              0.0     2.096396e-04
# 8                -0.008988                -0.002989            -3.668077e-03                 0.006073          3.088894e-04          2.512090e-04                   0.0          4.600681e-04                   0.0          2.512090e-04  ...  0.016558  0.016558  0.016558  0.013229         0.004300         0.006992         0.011967     2.512090e-04              0.0     4.600681e-04
# 9                -0.008995                -0.006659            -3.674574e-03                 0.009881          3.283133e-04          3.509261e-04                   0.0          4.603507e-04                   0.0          3.509261e-04  ...  0.022821  0.022821  0.022821  0.014101         0.002955         0.000151         0.011982     3.509261e-04              0.0     4.603507e-04
#
# [10 rows x 469 columns]

# %%
#RBC_samples2.hist(column = ['CO2t', 'HEX1', 'HEX7', 'FUM', 'FUMtr', 'L_LACt2r', 'LDH_L', 'MALt', 'GTHOr', 
#                           'GTHPi', 'ME2', 'PGI', 'PYRt2', 'SBTD_D2', 'SBTR'], bins=100,figsize=(15,15),histtype = 'step');

RBC_samples2.hist(column = impacted_reactions, bins=100,figsize=(15,15), histtype = 'step');

# %% [markdown]
# ## Plotting the difference between the default and diseased model (TPI knocked out)
#
# Finding the impact to cell when the TPI reaction is set to zero (knocked-out). This corresponds to removing the TPI1 protein from the model. This corresponds to hemolytic anemia due to triosephosphate isomerase deficiency according to the OMIM database.

# %%
reactions = ['CO2t', 'HEX1', 'HEX7', 'FUM', 'FUMtr', 'L_LACt2r', 'LDH_L', 'MALt', 'GTHOr', 
                           'GTHPi', 'ME2', 'PGI', 'PYRt2', 'SBTD_D2', 'SBTR']
fig, axes = plt.subplots(nrows=5, ncols=4)
j=0
for i in range(len(impacted_reactions)):
    normal_data=RBC_samples[impacted_reactions[i]]
    drug_data=RBC_samples2[impacted_reactions[i]]
    temp = pd.DataFrame({impacted_reactions[i]+ ': Normal data':normal_data, "Drug_data":drug_data})
    temp.plot.hist(bins=250, histtype = 'step',ax=axes[j%5,i%4],figsize=(15,15),density=True)
    if (i != 0 and (i+1)%4 == 0):
        j += 1
