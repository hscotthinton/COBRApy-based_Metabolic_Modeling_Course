# %%
from cobra.test import create_test_model
from cobra.sampling import sample

model = create_test_model("textbook")
s = sample(model, 10000, processes=8)
s
# Out:
#          ACALD    ACALDt      ACKr     ACONTa     ACONTb     ACt2r       ADK1  \
# 0    -2.964430 -0.030758 -2.437201   7.134146   7.134146 -2.437201   6.297619
# 1    -3.275203 -0.969431 -4.631036   4.806986   4.806986 -4.631036   4.618785
# 2    -2.520361 -2.048191 -3.410558   7.312527   7.312527 -3.410558   3.912721
# 3    -1.245068 -0.802854 -2.010875   8.459635   8.459635 -2.010875   5.502452
# 4    -1.834219 -1.763996 -1.892662   5.623299   5.623299 -1.892662  13.931682
# ...        ...       ...       ...        ...        ...       ...        ...
# 9995 -6.284111 -5.876020 -1.126765   5.262127   5.262127 -1.126765  13.713837
# 9996 -5.958310 -3.949949 -0.492555   2.234127   2.234127 -0.492555   3.561316
# 9997 -2.182380 -1.844519 -0.670145   5.685815   5.685815 -0.670145   2.841172
# 9998 -1.698172 -1.031721 -0.056123  12.278877  12.278877 -0.056123  18.794312
# 9999 -0.326059 -0.190020 -0.650722   7.959497   7.959497 -0.650722  17.700252
#
# ...

# %%
s.hist(column = 'ACALD', bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'ACALD'}>]], dtype=object)

# %%
s.hist(column = ['ATPM','PGI','PFK','FBA','GAPD','PGK','PGM','ENO','PYK'], bins=50,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'ATPM'}>,
#         <AxesSubplot:title={'center':'PGI'}>,
#         <AxesSubplot:title={'center':'PFK'}>],
#        [<AxesSubplot:title={'center':'FBA'}>,
#         <AxesSubplot:title={'center':'GAPD'}>,
#         <AxesSubplot:title={'center':'PGK'}>],
#        [<AxesSubplot:title={'center':'PGM'}>,
#         <AxesSubplot:title={'center':'ENO'}>,
#         <AxesSubplot:title={'center':'PYK'}>]], dtype=object)

# %%
s.hist(column = ['NADH16','CYTBD','ATPS4r','ATPM','ADK1','NADTRHD','THD2','Biomass_Ecoli_core'], bins=50,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'NADH16'}>,
#         <AxesSubplot:title={'center':'CYTBD'}>,
#         <AxesSubplot:title={'center':'ATPS4r'}>],
#        [<AxesSubplot:title={'center':'ATPM'}>,
#         <AxesSubplot:title={'center':'ADK1'}>,
#         <AxesSubplot:title={'center':'NADTRHD'}>],
#        [<AxesSubplot:title={'center':'THD2'}>,
#         <AxesSubplot:title={'center':'Biomass_Ecoli_core'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Ecoli_core = 0.8739215069684306</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
# ...

# %%
# ?s
