# %% [markdown]
# # Robustness Analysis

# %% [markdown]
# Loading the appropriate Python and COBRApy packages

# %%
import cobra.test
import numpy as np
import pandas as pd
from cobrapy_bigg_client import client
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Set autotropic conditions

# %%
model_orig = client.download_model('iJN678', save=False) # Loading the model to the simulation
model = model_orig.copy()
model.solver = "glpk"

# Set Biomass Function
model.objective = 'BIOMASS_Ec_SynAuto'
model.reactions.BIOMASS_Ec_SynHetero.bounds = [-0,0]
model.reactions.BIOMASS_Ec_SynMixo.bounds = [-0,0]

# Autotropic Conditions
model.reactions.EX_photon_e.bounds = [-100,0]
model.reactions.EX_glc__D_e.bounds = [-0,0]
model.reactions.EX_hco3_e.bounds = [-3.7,0]
#model.reactions.EX_co2_e.bounds = [-3.7,0] # Enable for using CO2 as the carbon source

# Constraining cytochrome c6-dependent reactions.
model.reactions.CBFC2.bounds = [-0,0]
model.reactions.PSI_2.bounds = [-0,0]
model.reactions.CYO1b_syn.bounds = [-0,0]
model.reactions.CYO1b2_syn.bounds = [-0,0] # test

# Constraining NADH-dependent reactions.
model.reactions.NDH1_2u.bounds = [-0,0]
model.reactions.NDH1_2p.bounds = [-0,0]

# Constraining peryplasmatic reactions.
model.reactions.NDH1_1p.bounds = [-0,0]
model.reactions.CYO1b2pp_syn.bounds = [-0,0]
model.reactions.CYO1bpp_syn.bounds = [-0,0]
model.reactions.CBFCpp.bounds = [-0,0]
model.reactions.CYTBDpp_1.bounds = [-0,0]

# Assume irreversibility of ferredoxin NADPH reductase under autotrophic conditions.
model.reactions.FNOR.lower_bound = 0

#Assume no excretion of CO2 under autotrophic conditions
model.reactions.EX_co2_e.upper_bound = 0

# Removing AEF pathways
model.reactions.NDH1_1u.bounds = [-0,0]
model.reactions.NDH2_syn.bounds = [-0,0]
model.reactions.NDH1_3u.bounds = [-0,0] # Enable if CO2 is the carbon source
model.reactions.FQR.bounds = [-0,0]
model.reactions.CYO1b_syn.bounds = [-0,0]
model.reactions.CYTBDu.bounds = [-0,0]
model.reactions.H2ASE_syn.bounds = [-0,0]
model.reactions.MEHLER.bounds = [-0,0]

# Limit photorespiratory reactions
model.reactions.RBPC.upper_bound = 4.30987
model.reactions.RBCh.upper_bound = 0.2045310

model.reactions.SUCDu_syn.bounds = [-0,0]
model.reactions.PSI_2.bounds = [-0,0]
model.reactions.CBFC2.bounds = [-0,0]

# Save autotropic LEF model for later use
model_LEF = model.copy()

# Calculate FBA
#solution = model.optimize()
#solution = loopless_solution(model)
# Out:
# Read LP format model from file C:\Users\hinton\AppData\Local\Temp\tmp0a5va4h4.lp
# Reading time = 0.01 seconds
# : 795 rows, 1726 columns, 8316 nonzeros

# %% [markdown]
# ## Robustness Analysis Using "envelope" COBRApy Function¶

# %% [markdown]
# Robustness analysis for oxygen

# %%
from cobra.flux_analysis import production_envelope

model4 = model_orig.copy()
RA_o2 = production_envelope(
    model, ["EX_o2_e"], objective="BIOMASS_Ec_SynAuto", carbon_sources="EX_hco3_e", points=100)
RA_o2.round(5)
# Out:
# Read LP format model from file C:\Users\hinton\AppData\Local\Temp\tmpkjbr40ct.lp
# Reading time = 0.01 seconds
# : 795 rows, 1726 columns, 8316 nonzeros
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0      EX_hco3_e           0.0                   NaN                 NaN
# 1      EX_hco3_e           0.0                   0.0                 NaN
# 2      EX_hco3_e           0.0                   0.0                 NaN
# 3      EX_hco3_e           0.0                   0.0                 NaN
# 4      EX_hco3_e           0.0                   0.0                 NaN
# 5      EX_hco3_e           0.0                   0.0                 NaN
# 6      EX_hco3_e           0.0                   0.0                 NaN
# 7      EX_hco3_e           0.0                   0.0                 NaN
# 8      EX_hco3_e           0.0                   0.0                 NaN
# 9      EX_hco3_e           0.0                   0.0                 NaN
# 10     EX_hco3_e           0.0                   0.0                 NaN
# 11     EX_hco3_e           0.0                   0.0                 NaN
# 12     EX_hco3_e           0.0                   0.0                 NaN
# 13     EX_hco3_e           0.0                   0.0                 NaN
# 14     EX_hco3_e           0.0                   0.0                 NaN
# 15     EX_hco3_e           0.0                   0.0                 NaN
# 16     EX_hco3_e           0.0                   0.0                 NaN
# 17     EX_hco3_e           0.0                   0.0                 NaN
# 18     EX_hco3_e           0.0                   0.0                 NaN
# 19     EX_hco3_e           0.0                   0.0                 NaN
# 20     EX_hco3_e           0.0                   0.0                 NaN
# 21     EX_hco3_e           0.0                   0.0                 NaN
# 22     EX_hco3_e           0.0                   0.0                 NaN
# 23     EX_hco3_e           0.0                   0.0                 NaN
# 24     EX_hco3_e           0.0                   0.0                 NaN
# 25     EX_hco3_e           0.0                   0.0                 NaN
# 26     EX_hco3_e           0.0                   0.0                 NaN
# 27     EX_hco3_e           0.0                   0.0                 NaN
# 28     EX_hco3_e           0.0                   0.0                 NaN
# 29     EX_hco3_e           0.0                   0.0                 NaN
# 30     EX_hco3_e           0.0                   0.0                 NaN
# 31     EX_hco3_e           0.0                   0.0                 NaN
# 32     EX_hco3_e           0.0                   0.0                 NaN
# 33     EX_hco3_e           0.0                   0.0                 NaN
# 34     EX_hco3_e           0.0                   0.0                 NaN
# 35     EX_hco3_e           0.0                   0.0                 NaN
# 36     EX_hco3_e           0.0                   0.0                 NaN
# 37     EX_hco3_e           0.0                   0.0                 NaN
# 38     EX_hco3_e           0.0                   0.0                 NaN
# 39     EX_hco3_e           0.0                   0.0                 NaN
# 40     EX_hco3_e           0.0                   0.0                 NaN
# 41     EX_hco3_e           0.0                   0.0                 NaN
# 42     EX_hco3_e           0.0                   0.0                 NaN
# 43     EX_hco3_e           0.0                   0.0                 NaN
# 44     EX_hco3_e           0.0                   0.0                 NaN
# 45     EX_hco3_e           0.0                   0.0                 NaN
# 46     EX_hco3_e           0.0                   0.0                 NaN
# 47     EX_hco3_e           0.0                   0.0                 NaN
# 48     EX_hco3_e           0.0                   0.0                 NaN
# 49     EX_hco3_e           0.0                   0.0                 NaN
# 50     EX_hco3_e           0.0                   0.0                 NaN
# 51     EX_hco3_e           0.0                   0.0                 NaN
# 52     EX_hco3_e           0.0                   0.0                 NaN
# 53     EX_hco3_e           0.0                   0.0                 NaN
# 54     EX_hco3_e           0.0                   0.0                 NaN
# 55     EX_hco3_e           0.0                   0.0                 NaN
# 56     EX_hco3_e           0.0                   0.0                 NaN
# 57     EX_hco3_e           0.0                   0.0                 NaN
# 58     EX_hco3_e           0.0                   0.0                 NaN
# 59     EX_hco3_e           0.0                   0.0                 NaN
# 60     EX_hco3_e           0.0                   0.0                 NaN
# 61     EX_hco3_e           0.0                   0.0                 NaN
# 62     EX_hco3_e           0.0                   0.0                 NaN
# 63     EX_hco3_e           0.0                   0.0                 NaN
# 64     EX_hco3_e           0.0                   0.0                 NaN
# 65     EX_hco3_e           0.0                   0.0                 NaN
# 66     EX_hco3_e           0.0                   0.0                 NaN
# 67     EX_hco3_e           0.0                   0.0                 NaN
# 68     EX_hco3_e           0.0                   0.0                 NaN
# 69     EX_hco3_e           0.0                   0.0                 NaN
# 70     EX_hco3_e           0.0                   0.0                 NaN
# 71     EX_hco3_e           0.0                   0.0                 NaN
# 72     EX_hco3_e           0.0                   0.0                 NaN
# 73     EX_hco3_e           0.0                   0.0                 NaN
# 74     EX_hco3_e           0.0                   0.0                 NaN
# 75     EX_hco3_e           0.0                   0.0                 NaN
# 76     EX_hco3_e           0.0                   0.0                 NaN
# 77     EX_hco3_e           0.0                   0.0                 NaN
# 78     EX_hco3_e           0.0                   0.0                 NaN
# 79     EX_hco3_e           0.0                   0.0                 NaN
# 80     EX_hco3_e           0.0                   0.0                 NaN
# 81     EX_hco3_e           0.0                   0.0                 NaN
# 82     EX_hco3_e           0.0                   0.0                 NaN
# 83     EX_hco3_e           0.0                   0.0                 NaN
# 84     EX_hco3_e           0.0                   0.0                 NaN
# 85     EX_hco3_e           0.0                   0.0                 NaN
# 86     EX_hco3_e           0.0                   0.0                 NaN
# 87     EX_hco3_e           0.0                   0.0                 NaN
# 88     EX_hco3_e           0.0                   0.0                 NaN
# 89     EX_hco3_e           0.0                   0.0                 NaN
# 90     EX_hco3_e           0.0                   0.0                 NaN
# 91     EX_hco3_e           0.0                   0.0                 NaN
# 92     EX_hco3_e           0.0                   0.0                 NaN
# 93     EX_hco3_e           0.0                   0.0                 NaN
# 94     EX_hco3_e           0.0                   0.0                 NaN
# 95     EX_hco3_e           0.0                   0.0                 NaN
# 96     EX_hco3_e           0.0                   0.0                 NaN
# 97     EX_hco3_e           0.0                   0.0                 NaN
# 98     EX_hco3_e           0.0                   0.0                 NaN
# 99     EX_hco3_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_o2_e
# 0        0.00000                   NaN                 NaN  0.00000
# 1        0.00064               8.69828                 NaN  0.06914
# 2        0.00128               8.69828                 NaN  0.13828
# 3        0.00192               8.69828                 NaN  0.20742
# 4        0.00256               8.69828                 NaN  0.27657
# 5        0.00320               8.69828                 NaN  0.34571
# 6        0.00384               8.69828                 NaN  0.41485
# 7        0.00448               8.69828                 NaN  0.48399
# 8        0.00512               8.69828                 NaN  0.55313
# 9        0.00576               8.69828                 NaN  0.62227
# 10       0.00640               8.69828                 NaN  0.69141
# 11       0.00704               8.69828                 NaN  0.76056
# 12       0.00768               8.69828                 NaN  0.82970
# 13       0.00831               8.69828                 NaN  0.89884
# 14       0.00895               8.69828                 NaN  0.96798
# 15       0.00959               8.69828                 NaN  1.03712
# 16       0.01023               8.69828                 NaN  1.10626
# 17       0.01087               8.69828                 NaN  1.17540
# 18       0.01151               8.69828                 NaN  1.24455
# 19       0.01215               8.69828                 NaN  1.31369
# 20       0.01279               8.69828                 NaN  1.38283
# 21       0.01343               8.69828                 NaN  1.45197
# 22       0.01407               8.69828                 NaN  1.52111
# 23       0.01471               8.69828                 NaN  1.59025
# 24       0.01535               8.69828                 NaN  1.65939
# 25       0.01599               8.69828                 NaN  1.72854
# 26       0.01663               8.69828                 NaN  1.79768
# 27       0.01727               8.69828                 NaN  1.86682
# 28       0.01791               8.69828                 NaN  1.93596
# 29       0.01855               8.69828                 NaN  2.00510
# 30       0.01919               8.69828                 NaN  2.07424
# 31       0.01983               8.69828                 NaN  2.14338
# 32       0.02047               8.69828                 NaN  2.21253
# 33       0.02111               8.69828                 NaN  2.28167
# 34       0.02175               8.69828                 NaN  2.35081
# 35       0.02239               8.69828                 NaN  2.41995
# 36       0.02303               8.69828                 NaN  2.48909
# 37       0.02367               8.69828                 NaN  2.55823
# 38       0.02430               8.69828                 NaN  2.62737
# 39       0.02494               8.69828                 NaN  2.69652
# 40       0.02558               8.69828                 NaN  2.76566
# 41       0.02622               8.69828                 NaN  2.83480
# 42       0.02686               8.69828                 NaN  2.90394
# 43       0.02750               8.69828                 NaN  2.97308
# 44       0.02814               8.69828                 NaN  3.04222
# 45       0.02878               8.69828                 NaN  3.11136
# 46       0.02942               8.69828                 NaN  3.18051
# 47       0.03006               8.69828                 NaN  3.24965
# 48       0.03070               8.69828                 NaN  3.31879
# 49       0.03134               8.69828                 NaN  3.38793
# 50       0.03198               8.69828                 NaN  3.45707
# 51       0.03262               8.69828                 NaN  3.52621
# 52       0.03326               8.69828                 NaN  3.59535
# 53       0.03390               8.69828                 NaN  3.66449
# 54       0.03454               8.69828                 NaN  3.73364
# 55       0.03518               8.69828                 NaN  3.80278
# 56       0.03582               8.69828                 NaN  3.87192
# 57       0.03646               8.69828                 NaN  3.94106
# 58       0.03710               8.69828                 NaN  4.01020
# 59       0.03774               8.69828                 NaN  4.07934
# 60       0.03838               8.69828                 NaN  4.14848
# 61       0.03902               8.69828                 NaN  4.21763
# 62       0.03966               8.69828                 NaN  4.28677
# 63       0.04029               8.69828                 NaN  4.35591
# 64       0.04093               8.69828                 NaN  4.42505
# 65       0.04157               8.69828                 NaN  4.49419
# 66       0.04221               8.69828                 NaN  4.56333
# 67       0.04285               8.69828                 NaN  4.63247
# 68       0.04349               8.69828                 NaN  4.70162
# 69       0.04413               8.69828                 NaN  4.77076
# 70       0.04477               8.69828                 NaN  4.83990
# 71       0.04541               8.69828                 NaN  4.90904
# 72       0.04605               8.69828                 NaN  4.97818
# 73       0.04669               8.69828                 NaN  5.04732
# 74       0.04733               8.69828                 NaN  5.11646
# 75       0.04797               8.69828                 NaN  5.18561
# 76       0.04861               8.69828                 NaN  5.25475
# 77       0.04925               8.69828                 NaN  5.32389
# 78       0.04989               8.69828                 NaN  5.39303
# 79       0.05053               8.69828                 NaN  5.46217
# 80       0.05117               8.69828                 NaN  5.53131
# 81       0.05181               8.69828                 NaN  5.60045
# 82       0.05245               8.69828                 NaN  5.66960
# 83       0.05307               8.69514                 NaN  5.73874
# 84       0.05368               8.69150                 NaN  5.80788
# 85       0.05429               8.68795                 NaN  5.87702
# 86       0.05491               8.68448                 NaN  5.94616
# 87       0.05552               8.68109                 NaN  6.01530
# 88       0.05331               8.29022                 NaN  6.08444
# 89       0.04847               7.53656                 NaN  6.15359
# 90       0.04362               6.78291                 NaN  6.22273
# 91       0.03877               6.02925                 NaN  6.29187
# 92       0.03393               5.27559                 NaN  6.36101
# 93       0.02908               4.52194                 NaN  6.43015
# 94       0.02423               3.76828                 NaN  6.49929
# 95       0.01939               3.01463                 NaN  6.56843
# 96       0.01454               2.26097                 NaN  6.63758
# 97       0.00969               1.50731                 NaN  6.70672
# 98       0.00485               0.75366                 NaN  6.77586
# 99       0.00000               0.00000                 NaN  6.84500

# %%
RA_o2.plot(kind='line', x='EX_o2_e', y='flux_maximum',figsize=(10,7),fontsize=16)
# Out:
# <AxesSubplot:xlabel='EX_o2_e'>

# %% [markdown]
# Robustness analysis for glucose

# %%
model4.reactions.EX_o2_e.lower_bound = -20
model4.reactions.EX_glc__D_e.lower_bound = -30
RA_glc = production_envelope(
    model4, ["EX_glc__D_e"], objective="BIOMASS_Ecoli_core_w_GAM", carbon_sources="EX_glc__D_e", points=100)
RA_glc.round(5)

# %%
RA_glc.plot(kind='line', x='EX_glc__D_e', y='flux_maximum',figsize=(10,7))
